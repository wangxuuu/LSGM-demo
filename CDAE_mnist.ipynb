# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from utils import *
from models.scorenetwork import *
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from scipy.ndimage import rotate
from itertools import chain
from torchvision import transforms
from torchvision.utils import save_image

from IPython.display import HTML
from IPython.display import clear_output

# %%
# initialize random seed
SEED = 0
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
np.random.seed(SEED)

CUDA_VISIBLE_DEVICES = 0
# cuda = True if torch.cuda.is_available() else False
# FloatTensor = torch.cuda.FloatTensor if cuda else torch.FloatTensor
# torch.set_default_tensor_type(FloatTensor)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

sample_dir = './results/MNIST_CDAE'
model_dir = './results/checkpoints/CDAE_MNIST'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

if not os.path.exists(model_dir):
    os.makedirs(model_dir)

# %%
joint_training = True
load_available = True
image_size = 784
h_dim = 400
z_dim = 20
num_epochs = 100
batch_size = 128
learning_rate = 1e-3

eps = 1e-6
sigma_min = 0.001
sigma_max = 10
n_steps = 10
annealed_step = 100

select_t = 0.3

# %%
# MNIST dataset
dataset = torchvision.datasets.MNIST(root='../../Data/MNIST/',
                                     train=True,
                                     transform=transforms.ToTensor(),
                                     download=True)

# Data loader
data_loader = torch.utils.data.DataLoader(dataset=dataset,
                                          batch_size=batch_size,
                                          shuffle=True)

sigma =  5.0#@param {'type':'number'}
marginal_prob_std_fn = functools.partial(marginal_prob_std, sigma=sigma)
diffusion_coeff_fn = functools.partial(diffusion_coeff, sigma=sigma)

# %%
vae = VAE(input_size=image_size, h_dim=h_dim, z_dim=z_dim, type='ce').to(device)
vae_optimizer = torch.optim.Adam(vae.parameters(), lr=learning_rate)

# sn = SN_Model(device, n_steps, sigma_min, sigma_max, dim=z_dim, p = 0.3)
sn = SN_Model(marginal_prob_std=marginal_prob_std_fn, embed_dim=20, dim=z_dim, drop_p=0.3, num_classes=10, device=device)
sn_optim = torch.optim.Adam(sn.parameters(), lr = 0.005)
# dynamic = AnnealedLangevinDynamic(sigma_min, sigma_max, n_steps, annealed_step, sn, device, eps=eps)

joint_optim = torch.optim.Adam(params=chain(vae.parameters(), sn.parameters()))

# Start training
for epoch in range(num_epochs):
    for i, (x, y) in enumerate(data_loader):
        x = x.to(device).view(-1, image_size)
        y = y.to(device)
        if joint_training:
            mu, log_var = vae.encode(x)
            z = vae.reparameterize(mu, log_var)
            x_reconst = vae.decode(z)
            # Compute reconstruction loss and kl divergence
            reconst_loss = F.binary_cross_entropy(x_reconst, x, size_average=False)
            kl_div = - 0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
            loss_sn = sn.loss(z, y)
            loss = loss_sn + reconst_loss + kl_div

            joint_optim.zero_grad()
            loss.backward()
            joint_optim.step()
        else:
            #============= First Stage: Update VAE ==============#
            # Forward pass
            x_reconst, mu, log_var = vae(x)
            # Compute reconstruction loss and kl divergence
            # For KL divergence, see Appendix B in VAE paper or http://yunjey47.tistory.com/43
            reconst_loss = F.binary_cross_entropy(x_reconst, x, size_average=False)
            kl_div = - 0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
            
            # Backprop and optimize
            vae_loss = reconst_loss + kl_div
            vae_optimizer.zero_grad()
            vae_loss.backward()
            vae_optimizer.step()

            #============= Second Stage: Update SN ==============#
            mu, log_var = vae.encode(x)
            z = vae.reparameterize(mu, log_var)

            loss_sn = sn.loss(z)
            vae_optimizer.zero_grad()
            sn_optim.zero_grad()
            loss_sn.backward()
            sn_optim.step()

        if (i+1) % 100 == 0:
            print ("Epoch[{}/{}], Step [{}/{}], Reconst Loss: {:.4f}, KL Div: {:.4f}, Diffuse loss: {:.4f}"
                   .format(epoch+1, num_epochs, i+1, len(data_loader), reconst_loss.item(), kl_div.item(), loss_sn.item()))

    with torch.no_grad():
        # Save the sampled images
        z = torch.randn(x.shape[0], z_dim).to(device)
        out = vae.decode(z).view(-1, 1, 28, 28)
        x_concat = torch.cat([x.view(-1, 1, 28, 28), out], dim=3)
        save_image(x_concat, os.path.join(sample_dir, 'sampled-{}.png'.format(epoch+1)))

        # Save the reconstructed images
        out, _, _ = vae(x)
        x_concat = torch.cat([x.view(-1, 1, 28, 28), out.view(-1, 1, 28, 28)], dim=3)
        save_image(x_concat, os.path.join(sample_dir, 'reconst-{}.png'.format(epoch+1)))

        # Save the diffused ima ges
        # dynamic = AnnealedLangevinDynamic(sigma_min, sigma_max, n_steps, annealed_step, sn, device, eps=eps)
        # z_ = forward_proc(z, sigma_min, sigma_max, n_steps, device=device, only_final=True)
        # sample = dynamic.sampling(x.shape[0], z_dim, sample=z_, only_final=True)

        z_ = forward_process(z, marginal_prob_std_fn, 100, device=device, end_t=select_t, only_final=True)
        sample = Euler_Maruyama_sampler(sn, marginal_prob_std_fn, diffusion_coeff_fn, dim=z_dim, batch_size=x.shape[0], y=y, num_steps=500, device=device)

        # sample = dynamic.sampling(x.shape[0], z_dim, only_final=True)
        out = vae.decode(sample).view(-1, 1, 28, 28)
        x_concat = torch.cat([x.view(-1, 1, 28, 28), out], dim=3)
        save_image(x_concat, os.path.join(sample_dir, 'diffuse-{}.png'.format(epoch+1)))
torch.save({'sn_state':sn.state_dict(), 'vae_state':vae.state_dict()}, model_dir+'ckpt.pth')
# Out:
# Epoch[1/100], Step [100/469], Reconst Loss: 22073.3086, KL Div: 1416.1350, Diffuse loss: 12.3915
# Epoch[1/100], Step [200/469], Reconst Loss: 17949.5078, KL Div: 1905.5697, Diffuse loss: 11.3102
# Epoch[1/100], Step [300/469], Reconst Loss: 15726.6836, KL Div: 2308.1890, Diffuse loss: 11.4896
# Epoch[1/100], Step [400/469], Reconst Loss: 14376.2031, KL Div: 2496.7517, Diffuse loss: 11.5833
# /home/oem/Documents/wangxu/LSGM-demo/models/scorenetwork.py:134: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(sigma**t, device=device)
# Epoch[2/100], Step [100/469], Reconst Loss: 12582.8330, KL Div: 2791.3477, Diffuse loss: 10.7618
# Epoch[2/100], Step [200/469], Reconst Loss: 12699.4268, KL Div: 2822.2637, Diffuse loss: 10.2450
# Epoch[2/100], Step [300/469], Reconst Loss: 11971.5508, KL Div: 3026.7778, Diffuse loss: 11.1576
# Epoch[2/100], Step [400/469], Reconst Loss: 12084.2695, KL Div: 2964.9736, Diffuse loss: 10.7537
# Epoch[3/100], Step [100/469], Reconst Loss: 11985.0049, KL Div: 3063.5923, Diffuse loss: 10.3906
# Epoch[3/100], Step [200/469], Reconst Loss: 11717.7188, KL Div: 2982.0059, Diffuse loss: 11.7134
# Epoch[3/100], Step [300/469], Reconst Loss: 11542.3594, KL Div: 3023.2617, Diffuse loss: 9.9633
# Epoch[3/100], Step [400/469], Reconst Loss: 11246.9277, KL Div: 3084.7117, Diffuse loss: 9.9917
# Epoch[4/100], Step [100/469], Reconst Loss: 10949.4785, KL Div: 3043.8918, Diffuse loss: 9.8120
# Epoch[4/100], Step [200/469], Reconst Loss: 11381.9375, KL Div: 3130.6362, Diffuse loss: 10.3189
# Epoch[4/100], Step [300/469], Reconst Loss: 11116.8301, KL Div: 3102.5176, Diffuse loss: 10.0081
# Epoch[4/100], Step [400/469], Reconst Loss: 10930.8633, KL Div: 3001.5459, Diffuse loss: 9.8795
# Epoch[5/100], Step [100/469], Reconst Loss: 11102.8721, KL Div: 3118.1426, Diffuse loss: 9.3757
# Epoch[5/100], Step [200/469], Reconst Loss: 10980.3955, KL Div: 3144.4861, Diffuse loss: 9.9538
# Epoch[5/100], Step [300/469], Reconst Loss: 10697.9961, KL Div: 3232.5947, Diffuse loss: 10.1897
# Epoch[5/100], Step [400/469], Reconst Loss: 10899.7051, KL Div: 3099.6069, Diffuse loss: 10.7301
# Epoch[6/100], Step [100/469], Reconst Loss: 10934.0703, KL Div: 3242.0244, Diffuse loss: 9.7593
# Epoch[6/100], Step [200/469], Reconst Loss: 11202.2480, KL Div: 3155.3777, Diffuse loss: 10.1169
# Epoch[6/100], Step [300/469], Reconst Loss: 10467.0059, KL Div: 3137.5276, Diffuse loss: 9.9422
# Epoch[6/100], Step [400/469], Reconst Loss: 10124.4648, KL Div: 3085.9146, Diffuse loss: 9.8816
# Epoch[7/100], Step [100/469], Reconst Loss: 10159.0000, KL Div: 3048.0513, Diffuse loss: 10.2276
# Epoch[7/100], Step [200/469], Reconst Loss: 10746.4209, KL Div: 3198.1912, Diffuse loss: 9.8693
# Epoch[7/100], Step [300/469], Reconst Loss: 11160.9824, KL Div: 3306.0789, Diffuse loss: 8.9781
# Epoch[7/100], Step [400/469], Reconst Loss: 10630.6846, KL Div: 3263.7458, Diffuse loss: 9.9787
# Epoch[8/100], Step [100/469], Reconst Loss: 10337.5449, KL Div: 3203.5039, Diffuse loss: 10.3340
# Epoch[8/100], Step [200/469], Reconst Loss: 10620.2119, KL Div: 3247.9155, Diffuse loss: 10.2331
# Epoch[8/100], Step [300/469], Reconst Loss: 10143.9570, KL Div: 3242.1477, Diffuse loss: 9.4501
# Epoch[8/100], Step [400/469], Reconst Loss: 10552.0762, KL Div: 3255.2612, Diffuse loss: 9.8424
# Epoch[9/100], Step [100/469], Reconst Loss: 10267.6172, KL Div: 3082.0156, Diffuse loss: 9.4599
# Epoch[9/100], Step [200/469], Reconst Loss: 10552.9199, KL Div: 3268.1208, Diffuse loss: 10.0005
# Epoch[9/100], Step [300/469], Reconst Loss: 10172.4941, KL Div: 3153.8789, Diffuse loss: 10.1629
# Epoch[9/100], Step [400/469], Reconst Loss: 10279.7041, KL Div: 3209.6606, Diffuse loss: 9.8890
# Epoch[10/100], Step [100/469], Reconst Loss: 10360.7715, KL Div: 3168.3813, Diffuse loss: 9.9960
# Epoch[10/100], Step [200/469], Reconst Loss: 10617.0264, KL Div: 3203.8054, Diffuse loss: 10.4297
# Epoch[10/100], Step [300/469], Reconst Loss: 10321.3652, KL Div: 3269.5339, Diffuse loss: 9.7899
# Epoch[10/100], Step [400/469], Reconst Loss: 10830.1270, KL Div: 3327.9431, Diffuse loss: 9.6675
# Epoch[11/100], Step [100/469], Reconst Loss: 10788.6426, KL Div: 3294.3369, Diffuse loss: 9.8851
# Epoch[11/100], Step [200/469], Reconst Loss: 10759.2988, KL Div: 3239.6934, Diffuse loss: 9.4074
# Epoch[11/100], Step [300/469], Reconst Loss: 10618.9102, KL Div: 3205.0942, Diffuse loss: 8.9926
# Epoch[11/100], Step [400/469], Reconst Loss: 10018.2861, KL Div: 3279.7419, Diffuse loss: 9.5649
# Epoch[12/100], Step [100/469], Reconst Loss: 10360.9639, KL Div: 3279.0952, Diffuse loss: 9.4789
# Epoch[12/100], Step [200/469], Reconst Loss: 9918.4834, KL Div: 3080.0508, Diffuse loss: 8.9584
# Epoch[12/100], Step [300/469], Reconst Loss: 9995.5361, KL Div: 3126.9172, Diffuse loss: 10.0984
# Epoch[12/100], Step [400/469], Reconst Loss: 10292.1543, KL Div: 3272.5149, Diffuse loss: 9.5870
# Epoch[13/100], Step [100/469], Reconst Loss: 10414.1621, KL Div: 3266.7627, Diffuse loss: 10.1453
# Epoch[13/100], Step [200/469], Reconst Loss: 10128.2969, KL Div: 3196.6733, Diffuse loss: 9.4376
# Epoch[13/100], Step [300/469], Reconst Loss: 10096.4014, KL Div: 3204.5537, Diffuse loss: 9.8406
# Epoch[13/100], Step [400/469], Reconst Loss: 10148.6064, KL Div: 3219.2446, Diffuse loss: 9.7232
# Epoch[14/100], Step [100/469], Reconst Loss: 10085.9707, KL Div: 3234.1499, Diffuse loss: 9.5031
# Epoch[14/100], Step [200/469], Reconst Loss: 10301.8262, KL Div: 3263.2832, Diffuse loss: 9.1277
# Epoch[14/100], Step [300/469], Reconst Loss: 10204.4316, KL Div: 3328.8433, Diffuse loss: 9.1224
# Epoch[14/100], Step [400/469], Reconst Loss: 10105.9316, KL Div: 3169.4783, Diffuse loss: 10.0046
# Epoch[15/100], Step [100/469], Reconst Loss: 10313.5908, KL Div: 3195.8120, Diffuse loss: 9.5365
# Epoch[15/100], Step [200/469], Reconst Loss: 10524.2344, KL Div: 3260.9302, Diffuse loss: 9.1746
# Epoch[15/100], Step [300/469], Reconst Loss: 10352.0586, KL Div: 3315.9976, Diffuse loss: 9.6730
# Epoch[15/100], Step [400/469], Reconst Loss: 9653.7920, KL Div: 3033.9946, Diffuse loss: 8.9243
# Epoch[16/100], Step [100/469], Reconst Loss: 10193.3018, KL Div: 3233.9888, Diffuse loss: 10.4404
# Epoch[16/100], Step [200/469], Reconst Loss: 10696.5918, KL Div: 3327.9229, Diffuse loss: 10.8991
# Epoch[16/100], Step [300/469], Reconst Loss: 9793.8906, KL Div: 3266.6416, Diffuse loss: 9.3480
# Epoch[16/100], Step [400/469], Reconst Loss: 10174.9111, KL Div: 3263.0715, Diffuse loss: 10.0703
# Epoch[17/100], Step [100/469], Reconst Loss: 10608.8711, KL Div: 3252.5171, Diffuse loss: 9.1525
# Epoch[17/100], Step [200/469], Reconst Loss: 10189.7354, KL Div: 3299.5342, Diffuse loss: 10.0865
# Epoch[17/100], Step [300/469], Reconst Loss: 10134.7246, KL Div: 3309.8999, Diffuse loss: 9.8602
# Epoch[17/100], Step [400/469], Reconst Loss: 9803.5078, KL Div: 3150.7004, Diffuse loss: 8.7825
# Epoch[18/100], Step [100/469], Reconst Loss: 10251.5488, KL Div: 3240.7441, Diffuse loss: 10.0643
# Epoch[18/100], Step [200/469], Reconst Loss: 10320.6865, KL Div: 3299.4053, Diffuse loss: 9.1526
# Epoch[18/100], Step [300/469], Reconst Loss: 10085.7578, KL Div: 3310.6460, Diffuse loss: 9.6576
# Epoch[18/100], Step [400/469], Reconst Loss: 9989.2715, KL Div: 3272.0220, Diffuse loss: 8.9211
# Epoch[19/100], Step [100/469], Reconst Loss: 10621.2031, KL Div: 3240.5586, Diffuse loss: 9.9587
# Epoch[19/100], Step [200/469], Reconst Loss: 10065.2695, KL Div: 3309.5869, Diffuse loss: 9.0472
# Epoch[19/100], Step [300/469], Reconst Loss: 10353.4209, KL Div: 3212.3574, Diffuse loss: 9.5727
# Epoch[19/100], Step [400/469], Reconst Loss: 9715.4287, KL Div: 3195.3577, Diffuse loss: 9.9000
# Epoch[20/100], Step [100/469], Reconst Loss: 9967.0127, KL Div: 3245.2134, Diffuse loss: 9.9033
# Epoch[20/100], Step [200/469], Reconst Loss: 10252.0713, KL Div: 3353.8003, Diffuse loss: 10.0639
# Epoch[20/100], Step [300/469], Reconst Loss: 10488.8545, KL Div: 3387.3210, Diffuse loss: 9.3075
# Epoch[20/100], Step [400/469], Reconst Loss: 9406.4678, KL Div: 3211.5205, Diffuse loss: 9.7870
# Epoch[21/100], Step [100/469], Reconst Loss: 10434.0781, KL Div: 3240.1030, Diffuse loss: 10.1077
# Epoch[21/100], Step [200/469], Reconst Loss: 9970.3047, KL Div: 3185.8699, Diffuse loss: 9.3591
# Epoch[21/100], Step [300/469], Reconst Loss: 9993.0195, KL Div: 3214.0225, Diffuse loss: 9.4849
# Epoch[21/100], Step [400/469], Reconst Loss: 10148.3125, KL Div: 3211.0337, Diffuse loss: 10.2339
# Epoch[22/100], Step [100/469], Reconst Loss: 9837.8252, KL Div: 3250.3645, Diffuse loss: 9.3412
# Epoch[22/100], Step [200/469], Reconst Loss: 9867.7715, KL Div: 3244.4282, Diffuse loss: 10.0686
# Epoch[22/100], Step [300/469], Reconst Loss: 10182.3418, KL Div: 3316.8701, Diffuse loss: 10.0180
# Epoch[22/100], Step [400/469], Reconst Loss: 10296.0986, KL Div: 3367.6387, Diffuse loss: 9.8681
# Epoch[23/100], Step [100/469], Reconst Loss: 10014.5215, KL Div: 3224.4055, Diffuse loss: 9.2045
# Epoch[23/100], Step [200/469], Reconst Loss: 10110.8223, KL Div: 3299.3750, Diffuse loss: 9.7068
# Epoch[23/100], Step [300/469], Reconst Loss: 9939.3887, KL Div: 3254.1377, Diffuse loss: 9.7765
# Epoch[23/100], Step [400/469], Reconst Loss: 10145.4609, KL Div: 3253.3857, Diffuse loss: 10.4070
# Epoch[24/100], Step [100/469], Reconst Loss: 9636.4883, KL Div: 3223.6450, Diffuse loss: 9.6638
# Epoch[24/100], Step [200/469], Reconst Loss: 9782.0508, KL Div: 3150.2146, Diffuse loss: 9.5130
# Epoch[24/100], Step [300/469], Reconst Loss: 9840.4727, KL Div: 3291.4062, Diffuse loss: 8.9254
# Epoch[24/100], Step [400/469], Reconst Loss: 10032.2285, KL Div: 3285.3574, Diffuse loss: 10.3426
# Epoch[25/100], Step [100/469], Reconst Loss: 9784.9902, KL Div: 3183.0881, Diffuse loss: 9.4944
# Epoch[25/100], Step [200/469], Reconst Loss: 10201.2598, KL Div: 3360.9424, Diffuse loss: 10.0473
# Epoch[25/100], Step [300/469], Reconst Loss: 9863.8057, KL Div: 3313.1675, Diffuse loss: 9.7552
# Epoch[25/100], Step [400/469], Reconst Loss: 9585.3154, KL Div: 3300.0005, Diffuse loss: 9.9268
# Epoch[26/100], Step [100/469], Reconst Loss: 9426.0342, KL Div: 3155.4058, Diffuse loss: 9.7092
# Epoch[26/100], Step [200/469], Reconst Loss: 9716.5488, KL Div: 3326.5671, Diffuse loss: 9.7303
# Epoch[26/100], Step [300/469], Reconst Loss: 9655.7578, KL Div: 3114.7104, Diffuse loss: 9.5004
# Epoch[26/100], Step [400/469], Reconst Loss: 9805.0332, KL Div: 3227.3945, Diffuse loss: 10.2515
# Epoch[27/100], Step [100/469], Reconst Loss: 10037.0820, KL Div: 3251.2495, Diffuse loss: 9.5559
# Epoch[27/100], Step [200/469], Reconst Loss: 10148.7236, KL Div: 3327.4214, Diffuse loss: 10.3843
# Epoch[27/100], Step [300/469], Reconst Loss: 9634.3320, KL Div: 3171.7627, Diffuse loss: 10.5699
# Epoch[27/100], Step [400/469], Reconst Loss: 9963.4229, KL Div: 3203.8735, Diffuse loss: 10.0287
# Epoch[28/100], Step [100/469], Reconst Loss: 9884.9707, KL Div: 3217.5105, Diffuse loss: 9.9206
# Epoch[28/100], Step [200/469], Reconst Loss: 9639.5479, KL Div: 3228.6208, Diffuse loss: 9.7227
# Epoch[28/100], Step [300/469], Reconst Loss: 9854.3809, KL Div: 3199.1179, Diffuse loss: 9.3516
# Epoch[28/100], Step [400/469], Reconst Loss: 10147.7090, KL Div: 3211.6396, Diffuse loss: 9.8891
# Epoch[29/100], Step [100/469], Reconst Loss: 9686.5791, KL Div: 3236.0039, Diffuse loss: 9.5245
# Epoch[29/100], Step [200/469], Reconst Loss: 9884.9199, KL Div: 3209.5894, Diffuse loss: 8.9923
# Epoch[29/100], Step [300/469], Reconst Loss: 10003.3066, KL Div: 3182.4263, Diffuse loss: 9.3405
# Epoch[29/100], Step [400/469], Reconst Loss: 9796.3301, KL Div: 3375.8945, Diffuse loss: 9.2303
# Epoch[30/100], Step [100/469], Reconst Loss: 9364.2080, KL Div: 3186.5437, Diffuse loss: 9.5020
# Epoch[30/100], Step [200/469], Reconst Loss: 9930.5967, KL Div: 3259.0303, Diffuse loss: 9.4199
# Epoch[30/100], Step [300/469], Reconst Loss: 9588.6172, KL Div: 3223.5574, Diffuse loss: 9.5380
# Epoch[30/100], Step [400/469], Reconst Loss: 9769.8398, KL Div: 3337.3228, Diffuse loss: 11.1875
# Epoch[31/100], Step [100/469], Reconst Loss: 9773.0586, KL Div: 3190.6504, Diffuse loss: 9.2915
# Epoch[31/100], Step [200/469], Reconst Loss: 10156.1621, KL Div: 3303.1365, Diffuse loss: 9.5372
# Epoch[31/100], Step [300/469], Reconst Loss: 10172.4492, KL Div: 3207.7744, Diffuse loss: 9.2751
# Epoch[31/100], Step [400/469], Reconst Loss: 10099.2285, KL Div: 3277.6121, Diffuse loss: 9.5691
# Epoch[32/100], Step [100/469], Reconst Loss: 10271.3467, KL Div: 3284.7559, Diffuse loss: 9.5299
# Epoch[32/100], Step [200/469], Reconst Loss: 10420.5762, KL Div: 3286.3579, Diffuse loss: 8.9361
# Epoch[32/100], Step [300/469], Reconst Loss: 9716.1602, KL Div: 3244.3389, Diffuse loss: 9.2967
# Epoch[32/100], Step [400/469], Reconst Loss: 10096.4580, KL Div: 3363.3784, Diffuse loss: 9.9264
# Epoch[33/100], Step [100/469], Reconst Loss: 9347.4180, KL Div: 3235.6106, Diffuse loss: 9.7047
# Epoch[33/100], Step [200/469], Reconst Loss: 10365.8711, KL Div: 3219.7832, Diffuse loss: 9.0346
# Epoch[33/100], Step [300/469], Reconst Loss: 9778.9209, KL Div: 3252.2168, Diffuse loss: 9.3052
# Epoch[33/100], Step [400/469], Reconst Loss: 9795.7451, KL Div: 3210.1680, Diffuse loss: 9.3338
# Epoch[34/100], Step [100/469], Reconst Loss: 10014.7402, KL Div: 3272.8379, Diffuse loss: 10.6994
# Epoch[34/100], Step [200/469], Reconst Loss: 10083.3809, KL Div: 3291.0959, Diffuse loss: 10.2290
# Epoch[34/100], Step [300/469], Reconst Loss: 9736.6270, KL Div: 3255.0339, Diffuse loss: 9.8010
# Epoch[34/100], Step [400/469], Reconst Loss: 10016.1504, KL Div: 3188.2007, Diffuse loss: 9.6134
# Epoch[35/100], Step [100/469], Reconst Loss: 10040.0234, KL Div: 3234.2617, Diffuse loss: 10.1799
# Epoch[35/100], Step [200/469], Reconst Loss: 9786.9883, KL Div: 3220.9492, Diffuse loss: 9.4420
# Epoch[35/100], Step [300/469], Reconst Loss: 10162.6465, KL Div: 3346.0425, Diffuse loss: 9.4010
# Epoch[35/100], Step [400/469], Reconst Loss: 9739.2012, KL Div: 3223.7173, Diffuse loss: 9.1901
# Epoch[36/100], Step [100/469], Reconst Loss: 9978.9941, KL Div: 3173.5256, Diffuse loss: 9.6326
# Epoch[36/100], Step [200/469], Reconst Loss: 9728.9824, KL Div: 3207.3115, Diffuse loss: 9.4967
# Epoch[36/100], Step [300/469], Reconst Loss: 9628.3613, KL Div: 3230.5952, Diffuse loss: 9.6701
# Epoch[36/100], Step [400/469], Reconst Loss: 9853.9678, KL Div: 3167.7935, Diffuse loss: 8.6167
# Epoch[37/100], Step [100/469], Reconst Loss: 9934.7344, KL Div: 3380.8223, Diffuse loss: 10.0848
# Epoch[37/100], Step [200/469], Reconst Loss: 10067.1914, KL Div: 3289.9128, Diffuse loss: 9.0733
# Epoch[37/100], Step [300/469], Reconst Loss: 9811.0996, KL Div: 3300.1836, Diffuse loss: 9.2366
# Epoch[37/100], Step [400/469], Reconst Loss: 9638.1494, KL Div: 3278.1890, Diffuse loss: 8.3437
# Epoch[38/100], Step [100/469], Reconst Loss: 9754.1504, KL Div: 3313.5107, Diffuse loss: 9.6098
# Epoch[38/100], Step [200/469], Reconst Loss: 9951.2129, KL Div: 3260.9236, Diffuse loss: 9.0842
# Epoch[38/100], Step [300/469], Reconst Loss: 9952.1982, KL Div: 3378.6738, Diffuse loss: 10.0094
# Epoch[38/100], Step [400/469], Reconst Loss: 9915.3877, KL Div: 3177.8467, Diffuse loss: 10.2506
# Epoch[39/100], Step [100/469], Reconst Loss: 9585.3076, KL Div: 3179.7422, Diffuse loss: 9.2201
# Epoch[39/100], Step [200/469], Reconst Loss: 9665.7773, KL Div: 3214.2358, Diffuse loss: 9.6848
# Epoch[39/100], Step [300/469], Reconst Loss: 9742.3281, KL Div: 3287.9009, Diffuse loss: 8.9687
# Epoch[39/100], Step [400/469], Reconst Loss: 9753.3037, KL Div: 3203.4670, Diffuse loss: 9.1281
# Epoch[40/100], Step [100/469], Reconst Loss: 9767.6025, KL Div: 3192.9727, Diffuse loss: 9.6986
# Epoch[40/100], Step [200/469], Reconst Loss: 10476.0449, KL Div: 3248.1003, Diffuse loss: 10.3210
# Epoch[40/100], Step [300/469], Reconst Loss: 10139.3477, KL Div: 3287.3955, Diffuse loss: 9.9396
# Epoch[40/100], Step [400/469], Reconst Loss: 9774.1553, KL Div: 3257.2397, Diffuse loss: 10.2369
# Epoch[41/100], Step [100/469], Reconst Loss: 9935.7285, KL Div: 3275.2002, Diffuse loss: 9.6835
# Epoch[41/100], Step [200/469], Reconst Loss: 9843.4688, KL Div: 3291.0740, Diffuse loss: 9.7898
# Epoch[41/100], Step [300/469], Reconst Loss: 9734.0312, KL Div: 3174.4004, Diffuse loss: 10.4588
# Epoch[41/100], Step [400/469], Reconst Loss: 9727.4492, KL Div: 3279.6875, Diffuse loss: 9.0878
# Epoch[42/100], Step [100/469], Reconst Loss: 9798.8369, KL Div: 3213.1147, Diffuse loss: 10.5317
# Epoch[42/100], Step [200/469], Reconst Loss: 9671.5449, KL Div: 3295.8989, Diffuse loss: 10.1626
# Epoch[42/100], Step [300/469], Reconst Loss: 9726.4365, KL Div: 3186.1104, Diffuse loss: 8.8968
# Epoch[42/100], Step [400/469], Reconst Loss: 9957.0508, KL Div: 3350.6294, Diffuse loss: 9.7758
# Epoch[43/100], Step [100/469], Reconst Loss: 9463.3398, KL Div: 3148.2549, Diffuse loss: 8.8892
# Epoch[43/100], Step [200/469], Reconst Loss: 10027.2959, KL Div: 3249.3813, Diffuse loss: 10.5891
# Epoch[43/100], Step [300/469], Reconst Loss: 10175.7344, KL Div: 3207.1846, Diffuse loss: 10.3933
# Epoch[43/100], Step [400/469], Reconst Loss: 9632.9697, KL Div: 3226.4541, Diffuse loss: 10.4207
# Epoch[44/100], Step [100/469], Reconst Loss: 9220.4473, KL Div: 3084.2771, Diffuse loss: 10.2521
# Epoch[44/100], Step [200/469], Reconst Loss: 9760.2822, KL Div: 3226.7195, Diffuse loss: 11.1413
# Epoch[44/100], Step [300/469], Reconst Loss: 10102.3271, KL Div: 3227.8669, Diffuse loss: 9.7365
# Epoch[44/100], Step [400/469], Reconst Loss: 9672.3115, KL Div: 3187.8652, Diffuse loss: 9.5109
# Epoch[45/100], Step [100/469], Reconst Loss: 9729.7861, KL Div: 3165.8665, Diffuse loss: 9.4185
# Epoch[45/100], Step [200/469], Reconst Loss: 9899.1709, KL Div: 3213.1172, Diffuse loss: 9.2459
# Epoch[45/100], Step [300/469], Reconst Loss: 9444.1523, KL Div: 3180.0742, Diffuse loss: 10.0424
# Epoch[45/100], Step [400/469], Reconst Loss: 9980.6748, KL Div: 3281.3596, Diffuse loss: 9.2904
# Epoch[46/100], Step [100/469], Reconst Loss: 9686.5312, KL Div: 3160.9795, Diffuse loss: 8.7055
# Epoch[46/100], Step [200/469], Reconst Loss: 10130.9336, KL Div: 3241.1919, Diffuse loss: 9.7156
# Epoch[46/100], Step [300/469], Reconst Loss: 9773.1152, KL Div: 3196.5051, Diffuse loss: 9.2507
# Epoch[46/100], Step [400/469], Reconst Loss: 9687.0146, KL Div: 3175.5164, Diffuse loss: 9.9036
# Epoch[47/100], Step [100/469], Reconst Loss: 9589.3711, KL Div: 3282.5398, Diffuse loss: 9.1282
# Epoch[47/100], Step [200/469], Reconst Loss: 9687.3848, KL Div: 3210.8784, Diffuse loss: 9.6392
# Epoch[47/100], Step [300/469], Reconst Loss: 9977.4746, KL Div: 3240.5483, Diffuse loss: 10.3773
# Epoch[47/100], Step [400/469], Reconst Loss: 9952.9355, KL Div: 3360.6460, Diffuse loss: 10.2714
# Epoch[48/100], Step [100/469], Reconst Loss: 10005.4551, KL Div: 3286.8071, Diffuse loss: 9.6710
# Epoch[48/100], Step [200/469], Reconst Loss: 9996.5283, KL Div: 3159.8608, Diffuse loss: 10.1653
# Epoch[48/100], Step [300/469], Reconst Loss: 9749.5527, KL Div: 3180.7964, Diffuse loss: 10.0285
# Epoch[48/100], Step [400/469], Reconst Loss: 9609.5947, KL Div: 3176.4768, Diffuse loss: 9.5266
# Epoch[49/100], Step [100/469], Reconst Loss: 9587.1240, KL Div: 3291.7803, Diffuse loss: 10.4642
# Epoch[49/100], Step [200/469], Reconst Loss: 10076.2939, KL Div: 3278.2485, Diffuse loss: 8.2848
# Epoch[49/100], Step [300/469], Reconst Loss: 9497.1738, KL Div: 3181.7373, Diffuse loss: 9.9352
# Epoch[49/100], Step [400/469], Reconst Loss: 9422.7520, KL Div: 3204.1831, Diffuse loss: 9.4397
# Epoch[50/100], Step [100/469], Reconst Loss: 9589.0791, KL Div: 3218.8154, Diffuse loss: 9.7940
# Epoch[50/100], Step [200/469], Reconst Loss: 9560.6592, KL Div: 3188.8376, Diffuse loss: 9.9774
# Epoch[50/100], Step [300/469], Reconst Loss: 9722.8242, KL Div: 3202.1641, Diffuse loss: 9.4846
# Epoch[50/100], Step [400/469], Reconst Loss: 9731.9355, KL Div: 3286.4294, Diffuse loss: 9.5501
# Epoch[51/100], Step [100/469], Reconst Loss: 10115.3066, KL Div: 3245.2710, Diffuse loss: 9.2926
# Epoch[51/100], Step [200/469], Reconst Loss: 9575.1426, KL Div: 3196.8381, Diffuse loss: 9.2144
# Epoch[51/100], Step [300/469], Reconst Loss: 9532.4668, KL Div: 3225.7148, Diffuse loss: 9.8816
# Epoch[51/100], Step [400/469], Reconst Loss: 10097.1055, KL Div: 3273.6372, Diffuse loss: 9.4192
# Epoch[52/100], Step [100/469], Reconst Loss: 9740.5957, KL Div: 3130.5181, Diffuse loss: 9.9205
# Epoch[52/100], Step [200/469], Reconst Loss: 10281.1699, KL Div: 3269.3691, Diffuse loss: 9.7446
# Epoch[52/100], Step [300/469], Reconst Loss: 9113.6553, KL Div: 3249.3198, Diffuse loss: 9.4396
# Epoch[52/100], Step [400/469], Reconst Loss: 10414.0254, KL Div: 3305.4702, Diffuse loss: 10.0859
# Epoch[53/100], Step [100/469], Reconst Loss: 9850.1445, KL Div: 3233.8179, Diffuse loss: 10.2393
# Epoch[53/100], Step [200/469], Reconst Loss: 9218.5156, KL Div: 3162.4016, Diffuse loss: 9.8582
# Epoch[53/100], Step [300/469], Reconst Loss: 10197.3555, KL Div: 3259.6187, Diffuse loss: 8.6592
# Epoch[53/100], Step [400/469], Reconst Loss: 9513.1035, KL Div: 3318.1128, Diffuse loss: 9.5941
# Epoch[54/100], Step [100/469], Reconst Loss: 9726.1494, KL Div: 3268.5505, Diffuse loss: 10.0256
# Epoch[54/100], Step [200/469], Reconst Loss: 9750.8965, KL Div: 3153.0967, Diffuse loss: 9.8424
# Epoch[54/100], Step [300/469], Reconst Loss: 9646.2461, KL Div: 3234.8062, Diffuse loss: 9.4999
# Epoch[54/100], Step [400/469], Reconst Loss: 9434.1816, KL Div: 3191.8481, Diffuse loss: 9.1173
# Epoch[55/100], Step [100/469], Reconst Loss: 9762.3750, KL Div: 3148.4456, Diffuse loss: 9.3483
# Epoch[55/100], Step [200/469], Reconst Loss: 9860.0283, KL Div: 3326.8438, Diffuse loss: 9.2766
# Epoch[55/100], Step [300/469], Reconst Loss: 9670.3516, KL Div: 3188.1729, Diffuse loss: 9.1993
# Epoch[55/100], Step [400/469], Reconst Loss: 9726.4902, KL Div: 3296.6013, Diffuse loss: 9.9196
# Epoch[56/100], Step [100/469], Reconst Loss: 9846.4238, KL Div: 3309.7349, Diffuse loss: 10.3040
# Epoch[56/100], Step [200/469], Reconst Loss: 9372.0938, KL Div: 3118.1814, Diffuse loss: 9.7486
# Epoch[56/100], Step [300/469], Reconst Loss: 9500.3848, KL Div: 3168.3555, Diffuse loss: 9.5891
# Epoch[56/100], Step [400/469], Reconst Loss: 10379.4805, KL Div: 3372.5107, Diffuse loss: 10.1674
# Epoch[57/100], Step [100/469], Reconst Loss: 9553.3398, KL Div: 3209.6465, Diffuse loss: 9.3227
# Epoch[57/100], Step [200/469], Reconst Loss: 9850.4307, KL Div: 3250.5940, Diffuse loss: 8.9351
# Epoch[57/100], Step [300/469], Reconst Loss: 10100.3906, KL Div: 3337.6729, Diffuse loss: 9.6926
# Epoch[57/100], Step [400/469], Reconst Loss: 9982.4873, KL Div: 3349.3052, Diffuse loss: 10.1916
# Epoch[58/100], Step [100/469], Reconst Loss: 9728.1328, KL Div: 3209.4849, Diffuse loss: 9.9217
# Epoch[58/100], Step [200/469], Reconst Loss: 9584.8926, KL Div: 3188.8281, Diffuse loss: 9.6201
# Epoch[58/100], Step [300/469], Reconst Loss: 10162.9658, KL Div: 3327.7539, Diffuse loss: 10.5968
# Epoch[58/100], Step [400/469], Reconst Loss: 9558.8730, KL Div: 3164.9248, Diffuse loss: 9.6582
# Epoch[59/100], Step [100/469], Reconst Loss: 9583.5557, KL Div: 3285.9272, Diffuse loss: 9.9402
# Epoch[59/100], Step [200/469], Reconst Loss: 9410.0039, KL Div: 3151.6860, Diffuse loss: 10.1363
# Epoch[59/100], Step [300/469], Reconst Loss: 9397.0049, KL Div: 3257.6152, Diffuse loss: 9.8943
# Epoch[59/100], Step [400/469], Reconst Loss: 9843.6201, KL Div: 3215.2412, Diffuse loss: 10.0576
# Epoch[60/100], Step [100/469], Reconst Loss: 9779.5127, KL Div: 3242.7632, Diffuse loss: 8.1855
# Epoch[60/100], Step [200/469], Reconst Loss: 9487.4238, KL Div: 3318.2051, Diffuse loss: 10.5795
# Epoch[60/100], Step [300/469], Reconst Loss: 9709.4248, KL Div: 3259.4778, Diffuse loss: 10.0731
# Epoch[60/100], Step [400/469], Reconst Loss: 9648.2773, KL Div: 3249.9346, Diffuse loss: 10.0970
# Epoch[61/100], Step [100/469], Reconst Loss: 10062.5254, KL Div: 3318.6187, Diffuse loss: 11.0345
# Epoch[61/100], Step [200/469], Reconst Loss: 9388.5830, KL Div: 3233.9685, Diffuse loss: 10.0815
# Epoch[61/100], Step [300/469], Reconst Loss: 9758.2520, KL Div: 3285.5615, Diffuse loss: 10.5793
# Epoch[61/100], Step [400/469], Reconst Loss: 10014.8574, KL Div: 3187.5642, Diffuse loss: 9.4622
# Epoch[62/100], Step [100/469], Reconst Loss: 9764.6992, KL Div: 3276.1248, Diffuse loss: 10.5200
# Epoch[62/100], Step [200/469], Reconst Loss: 9580.4648, KL Div: 3236.1067, Diffuse loss: 9.9484
# Epoch[62/100], Step [300/469], Reconst Loss: 9603.0557, KL Div: 3222.3083, Diffuse loss: 9.5759
# Epoch[62/100], Step [400/469], Reconst Loss: 9792.1279, KL Div: 3241.3652, Diffuse loss: 9.2007
# Epoch[63/100], Step [100/469], Reconst Loss: 9772.3799, KL Div: 3318.0903, Diffuse loss: 9.6218
# Epoch[63/100], Step [200/469], Reconst Loss: 9776.4053, KL Div: 3308.2004, Diffuse loss: 9.6677
# Epoch[63/100], Step [300/469], Reconst Loss: 10039.3301, KL Div: 3207.6641, Diffuse loss: 9.0821
# Epoch[63/100], Step [400/469], Reconst Loss: 9748.7461, KL Div: 3207.5798, Diffuse loss: 9.2187
# Epoch[64/100], Step [100/469], Reconst Loss: 9695.4141, KL Div: 3230.0823, Diffuse loss: 10.2233
# Epoch[64/100], Step [200/469], Reconst Loss: 9799.1592, KL Div: 3204.9214, Diffuse loss: 9.7336
# Epoch[64/100], Step [300/469], Reconst Loss: 9752.7188, KL Div: 3216.4429, Diffuse loss: 9.4092
# Epoch[64/100], Step [400/469], Reconst Loss: 9567.1904, KL Div: 3190.3975, Diffuse loss: 9.7611
# Epoch[65/100], Step [100/469], Reconst Loss: 9342.8984, KL Div: 3166.3328, Diffuse loss: 9.8674
# Epoch[65/100], Step [200/469], Reconst Loss: 9966.4629, KL Div: 3295.5850, Diffuse loss: 9.8059
# Epoch[65/100], Step [300/469], Reconst Loss: 9422.6191, KL Div: 3158.9873, Diffuse loss: 9.6463
# Epoch[65/100], Step [400/469], Reconst Loss: 9446.8096, KL Div: 3148.4561, Diffuse loss: 9.4420
# Epoch[66/100], Step [100/469], Reconst Loss: 9376.1387, KL Div: 3240.1272, Diffuse loss: 10.4964
# Epoch[66/100], Step [200/469], Reconst Loss: 10018.2832, KL Div: 3236.3965, Diffuse loss: 9.5179
# Epoch[66/100], Step [300/469], Reconst Loss: 10037.2432, KL Div: 3296.1643, Diffuse loss: 9.4943
# Epoch[66/100], Step [400/469], Reconst Loss: 9970.3164, KL Div: 3250.3945, Diffuse loss: 9.4332
# Epoch[67/100], Step [100/469], Reconst Loss: 9441.5156, KL Div: 3227.5703, Diffuse loss: 9.9736
# Epoch[67/100], Step [200/469], Reconst Loss: 9833.1963, KL Div: 3253.5317, Diffuse loss: 10.2019
# Epoch[67/100], Step [300/469], Reconst Loss: 9845.5664, KL Div: 3127.0815, Diffuse loss: 9.5363
# Epoch[67/100], Step [400/469], Reconst Loss: 10097.3623, KL Div: 3257.5005, Diffuse loss: 10.1092
# Epoch[68/100], Step [100/469], Reconst Loss: 9520.2422, KL Div: 3154.9019, Diffuse loss: 10.3773
# Epoch[68/100], Step [200/469], Reconst Loss: 10118.0098, KL Div: 3248.8276, Diffuse loss: 9.3569
# Epoch[68/100], Step [300/469], Reconst Loss: 9473.0586, KL Div: 3202.0461, Diffuse loss: 9.8263
# Epoch[68/100], Step [400/469], Reconst Loss: 9387.4219, KL Div: 3282.0439, Diffuse loss: 10.7549
# Epoch[69/100], Step [100/469], Reconst Loss: 9746.0195, KL Div: 3229.9297, Diffuse loss: 9.9120
# Epoch[69/100], Step [200/469], Reconst Loss: 10003.9492, KL Div: 3315.0767, Diffuse loss: 10.6041
# Epoch[69/100], Step [300/469], Reconst Loss: 9623.3115, KL Div: 3225.0098, Diffuse loss: 9.9726
# Epoch[69/100], Step [400/469], Reconst Loss: 9636.3223, KL Div: 3234.5210, Diffuse loss: 10.0975
# Epoch[70/100], Step [100/469], Reconst Loss: 9746.1562, KL Div: 3234.7234, Diffuse loss: 10.6410
# Epoch[70/100], Step [200/469], Reconst Loss: 9965.6387, KL Div: 3143.4087, Diffuse loss: 9.7719
# Epoch[70/100], Step [300/469], Reconst Loss: 10025.7266, KL Div: 3269.0298, Diffuse loss: 10.0829
# Epoch[70/100], Step [400/469], Reconst Loss: 9449.6523, KL Div: 3147.7561, Diffuse loss: 9.4027
# Epoch[71/100], Step [100/469], Reconst Loss: 9341.8398, KL Div: 3132.1094, Diffuse loss: 10.5730
# Epoch[71/100], Step [200/469], Reconst Loss: 9598.1650, KL Div: 3247.1887, Diffuse loss: 9.4598
# Epoch[71/100], Step [300/469], Reconst Loss: 9098.8154, KL Div: 3274.6609, Diffuse loss: 9.4669
# Epoch[71/100], Step [400/469], Reconst Loss: 9833.5039, KL Div: 3243.1311, Diffuse loss: 10.6766
# Epoch[72/100], Step [100/469], Reconst Loss: 10118.4717, KL Div: 3328.1836, Diffuse loss: 11.1398
# Epoch[72/100], Step [200/469], Reconst Loss: 9924.9570, KL Div: 3141.4612, Diffuse loss: 9.4507
# Epoch[72/100], Step [300/469], Reconst Loss: 9795.4473, KL Div: 3242.8945, Diffuse loss: 9.3569
# Epoch[72/100], Step [400/469], Reconst Loss: 9014.3242, KL Div: 3107.3228, Diffuse loss: 9.2237
# Epoch[73/100], Step [100/469], Reconst Loss: 9478.0586, KL Div: 3171.0576, Diffuse loss: 9.2743
# Epoch[73/100], Step [200/469], Reconst Loss: 9874.3584, KL Div: 3328.4932, Diffuse loss: 8.7068
# Epoch[73/100], Step [300/469], Reconst Loss: 9625.8936, KL Div: 3200.3140, Diffuse loss: 9.5855
# Epoch[73/100], Step [400/469], Reconst Loss: 9799.8496, KL Div: 3148.9775, Diffuse loss: 9.6528
# Epoch[74/100], Step [100/469], Reconst Loss: 9881.8213, KL Div: 3206.3198, Diffuse loss: 9.7825
# Epoch[74/100], Step [200/469], Reconst Loss: 9773.3564, KL Div: 3263.6638, Diffuse loss: 9.9883
# Epoch[74/100], Step [300/469], Reconst Loss: 9685.0723, KL Div: 3306.1279, Diffuse loss: 10.1650
# Epoch[74/100], Step [400/469], Reconst Loss: 9618.2598, KL Div: 3168.1357, Diffuse loss: 9.6298
# Epoch[75/100], Step [100/469], Reconst Loss: 9717.8691, KL Div: 3204.1091, Diffuse loss: 9.3118
# Epoch[75/100], Step [200/469], Reconst Loss: 9737.8223, KL Div: 3190.5845, Diffuse loss: 9.6707
# Epoch[75/100], Step [300/469], Reconst Loss: 9328.8320, KL Div: 3227.5115, Diffuse loss: 9.6197
# Epoch[75/100], Step [400/469], Reconst Loss: 9531.4375, KL Div: 3028.5342, Diffuse loss: 9.5018
# Epoch[76/100], Step [100/469], Reconst Loss: 9585.7354, KL Div: 3278.4072, Diffuse loss: 9.9048
# Epoch[76/100], Step [200/469], Reconst Loss: 9474.5625, KL Div: 3341.1389, Diffuse loss: 9.0453
# Epoch[76/100], Step [300/469], Reconst Loss: 9720.1426, KL Div: 3248.5942, Diffuse loss: 8.9990
# Epoch[76/100], Step [400/469], Reconst Loss: 9821.7559, KL Div: 3273.5308, Diffuse loss: 9.7708
# Epoch[77/100], Step [100/469], Reconst Loss: 9810.4141, KL Div: 3356.2043, Diffuse loss: 10.0032
# Epoch[77/100], Step [200/469], Reconst Loss: 10064.9238, KL Div: 3176.4019, Diffuse loss: 9.7202
# Epoch[77/100], Step [300/469], Reconst Loss: 9706.8135, KL Div: 3193.0835, Diffuse loss: 9.6008
# Epoch[77/100], Step [400/469], Reconst Loss: 9731.3711, KL Div: 3169.3936, Diffuse loss: 9.6466
# Epoch[78/100], Step [100/469], Reconst Loss: 9738.0342, KL Div: 3300.8040, Diffuse loss: 9.9539
# Epoch[78/100], Step [200/469], Reconst Loss: 9754.5566, KL Div: 3219.4258, Diffuse loss: 10.3809
# Epoch[78/100], Step [300/469], Reconst Loss: 9964.7578, KL Div: 3302.2979, Diffuse loss: 8.9139
# Epoch[78/100], Step [400/469], Reconst Loss: 10076.7012, KL Div: 3223.4888, Diffuse loss: 9.6192
# Epoch[79/100], Step [100/469], Reconst Loss: 9972.8750, KL Div: 3302.7336, Diffuse loss: 9.0737
# Epoch[79/100], Step [200/469], Reconst Loss: 9552.3750, KL Div: 3215.9473, Diffuse loss: 8.5884
# Epoch[79/100], Step [300/469], Reconst Loss: 9423.1836, KL Div: 3129.6235, Diffuse loss: 9.5800
# Epoch[79/100], Step [400/469], Reconst Loss: 10005.9873, KL Div: 3274.1760, Diffuse loss: 8.9862
# Epoch[80/100], Step [100/469], Reconst Loss: 9775.8066, KL Div: 3194.1716, Diffuse loss: 10.1429
# Epoch[80/100], Step [200/469], Reconst Loss: 9827.5996, KL Div: 3249.1406, Diffuse loss: 9.6521
# Epoch[80/100], Step [300/469], Reconst Loss: 9919.0625, KL Div: 3311.6521, Diffuse loss: 9.6996
# Epoch[80/100], Step [400/469], Reconst Loss: 9571.6152, KL Div: 3139.6592, Diffuse loss: 9.2732
# Epoch[81/100], Step [100/469], Reconst Loss: 9738.2734, KL Div: 3301.4336, Diffuse loss: 9.5235
# Epoch[81/100], Step [200/469], Reconst Loss: 9958.2266, KL Div: 3378.8398, Diffuse loss: 9.6190
# Epoch[81/100], Step [300/469], Reconst Loss: 9938.3867, KL Div: 3322.9639, Diffuse loss: 10.0568
# Epoch[81/100], Step [400/469], Reconst Loss: 9957.4512, KL Div: 3292.9236, Diffuse loss: 9.8933
# Epoch[82/100], Step [100/469], Reconst Loss: 9769.2285, KL Div: 3162.9438, Diffuse loss: 9.8040
# Epoch[82/100], Step [200/469], Reconst Loss: 9959.2461, KL Div: 3343.4395, Diffuse loss: 10.2955
# Epoch[82/100], Step [300/469], Reconst Loss: 10006.9629, KL Div: 3297.2327, Diffuse loss: 9.4732
# Epoch[82/100], Step [400/469], Reconst Loss: 9782.5459, KL Div: 3206.4277, Diffuse loss: 10.0667
# Epoch[83/100], Step [100/469], Reconst Loss: 9977.9463, KL Div: 3297.1860, Diffuse loss: 10.0624
# Epoch[83/100], Step [200/469], Reconst Loss: 9673.6562, KL Div: 3223.2783, Diffuse loss: 9.7710
# Epoch[83/100], Step [300/469], Reconst Loss: 9610.2051, KL Div: 3232.2083, Diffuse loss: 9.8275
# Epoch[83/100], Step [400/469], Reconst Loss: 9345.5684, KL Div: 3256.1775, Diffuse loss: 9.8281
# Epoch[84/100], Step [100/469], Reconst Loss: 9471.6211, KL Div: 3255.5908, Diffuse loss: 9.6249
# Epoch[84/100], Step [200/469], Reconst Loss: 9832.4902, KL Div: 3170.8032, Diffuse loss: 9.3638
# Epoch[84/100], Step [300/469], Reconst Loss: 9644.9873, KL Div: 3325.3618, Diffuse loss: 9.7464
# Epoch[84/100], Step [400/469], Reconst Loss: 9820.2246, KL Div: 3291.2559, Diffuse loss: 8.9884
# Epoch[85/100], Step [100/469], Reconst Loss: 9515.2451, KL Div: 3202.6191, Diffuse loss: 9.9318
# Epoch[85/100], Step [200/469], Reconst Loss: 9731.9062, KL Div: 3261.8340, Diffuse loss: 8.8959
# Epoch[85/100], Step [300/469], Reconst Loss: 10042.3301, KL Div: 3293.4329, Diffuse loss: 8.8544
# Epoch[85/100], Step [400/469], Reconst Loss: 9698.1553, KL Div: 3302.1599, Diffuse loss: 9.2610
# Epoch[86/100], Step [100/469], Reconst Loss: 9855.7500, KL Div: 3291.9766, Diffuse loss: 9.3632
# Epoch[86/100], Step [200/469], Reconst Loss: 9324.2461, KL Div: 3266.1790, Diffuse loss: 8.9629
# Epoch[86/100], Step [300/469], Reconst Loss: 9904.0781, KL Div: 3316.9067, Diffuse loss: 9.5492
# Epoch[86/100], Step [400/469], Reconst Loss: 9581.3262, KL Div: 3194.7629, Diffuse loss: 8.3326
# Epoch[87/100], Step [100/469], Reconst Loss: 9349.7930, KL Div: 3054.8247, Diffuse loss: 8.8638
# Epoch[87/100], Step [200/469], Reconst Loss: 9694.0576, KL Div: 3206.5171, Diffuse loss: 9.9704
# Epoch[87/100], Step [300/469], Reconst Loss: 9647.6299, KL Div: 3286.9009, Diffuse loss: 9.7422
# Epoch[87/100], Step [400/469], Reconst Loss: 9566.2402, KL Div: 3202.4685, Diffuse loss: 8.7247
# Epoch[88/100], Step [100/469], Reconst Loss: 9543.5195, KL Div: 3129.6650, Diffuse loss: 9.1151
# Epoch[88/100], Step [200/469], Reconst Loss: 9348.6934, KL Div: 3150.3828, Diffuse loss: 10.2730
# Epoch[88/100], Step [300/469], Reconst Loss: 9409.0537, KL Div: 3198.2939, Diffuse loss: 9.5916
# Epoch[88/100], Step [400/469], Reconst Loss: 9898.7969, KL Div: 3185.1387, Diffuse loss: 9.6564
# Epoch[89/100], Step [100/469], Reconst Loss: 9845.5303, KL Div: 3192.3337, Diffuse loss: 10.2310
# Epoch[89/100], Step [200/469], Reconst Loss: 9789.9883, KL Div: 3215.5503, Diffuse loss: 8.9867
# Epoch[89/100], Step [300/469], Reconst Loss: 9421.1104, KL Div: 3273.3530, Diffuse loss: 9.5662
# Epoch[89/100], Step [400/469], Reconst Loss: 10136.3867, KL Div: 3340.5005, Diffuse loss: 9.6370
# Epoch[90/100], Step [100/469], Reconst Loss: 9459.2119, KL Div: 3195.9087, Diffuse loss: 9.0879
# Epoch[90/100], Step [200/469], Reconst Loss: 9884.9277, KL Div: 3209.2930, Diffuse loss: 9.4513
# Epoch[90/100], Step [300/469], Reconst Loss: 9890.6641, KL Div: 3323.5403, Diffuse loss: 9.1242
# Epoch[90/100], Step [400/469], Reconst Loss: 9546.9395, KL Div: 3199.8022, Diffuse loss: 10.4760
# Epoch[91/100], Step [100/469], Reconst Loss: 9436.2715, KL Div: 3203.2627, Diffuse loss: 9.8821
# Epoch[91/100], Step [200/469], Reconst Loss: 9274.3340, KL Div: 3231.6260, Diffuse loss: 8.4921
# Epoch[91/100], Step [300/469], Reconst Loss: 9598.4277, KL Div: 3153.5427, Diffuse loss: 8.7773
# Epoch[91/100], Step [400/469], Reconst Loss: 9536.2773, KL Div: 3174.9575, Diffuse loss: 9.8686
# Epoch[92/100], Step [100/469], Reconst Loss: 9399.8076, KL Div: 3204.6968, Diffuse loss: 9.2835
# Epoch[92/100], Step [200/469], Reconst Loss: 9507.5371, KL Div: 3193.0298, Diffuse loss: 8.8827
# Epoch[92/100], Step [300/469], Reconst Loss: 10020.7432, KL Div: 3274.7251, Diffuse loss: 10.3253
# Epoch[92/100], Step [400/469], Reconst Loss: 9681.4326, KL Div: 3176.2288, Diffuse loss: 9.1454
# Epoch[93/100], Step [100/469], Reconst Loss: 9955.0000, KL Div: 3282.6614, Diffuse loss: 9.7410
# Epoch[93/100], Step [200/469], Reconst Loss: 9681.8613, KL Div: 3285.4690, Diffuse loss: 9.5593
# Epoch[93/100], Step [300/469], Reconst Loss: 9972.8496, KL Div: 3222.7944, Diffuse loss: 9.4850
# Epoch[93/100], Step [400/469], Reconst Loss: 9508.6113, KL Div: 3269.0640, Diffuse loss: 9.5028
# Epoch[94/100], Step [100/469], Reconst Loss: 9278.2891, KL Div: 3141.3740, Diffuse loss: 9.7918
# Epoch[94/100], Step [200/469], Reconst Loss: 9979.8271, KL Div: 3348.9932, Diffuse loss: 9.9952
# Epoch[94/100], Step [300/469], Reconst Loss: 9787.9980, KL Div: 3232.9888, Diffuse loss: 10.3165
# Epoch[94/100], Step [400/469], Reconst Loss: 10122.5127, KL Div: 3328.6909, Diffuse loss: 9.7421
# Epoch[95/100], Step [100/469], Reconst Loss: 9363.0771, KL Div: 3191.1768, Diffuse loss: 9.8133
# Epoch[95/100], Step [200/469], Reconst Loss: 9523.3516, KL Div: 3120.9912, Diffuse loss: 9.5046
# Epoch[95/100], Step [300/469], Reconst Loss: 9897.6865, KL Div: 3243.4075, Diffuse loss: 9.3862
# Epoch[95/100], Step [400/469], Reconst Loss: 9283.6523, KL Div: 3151.6689, Diffuse loss: 9.4388
# Epoch[96/100], Step [100/469], Reconst Loss: 9932.8086, KL Div: 3203.8538, Diffuse loss: 10.4872
# Epoch[96/100], Step [200/469], Reconst Loss: 9521.3496, KL Div: 3212.8901, Diffuse loss: 10.2192
# Epoch[96/100], Step [300/469], Reconst Loss: 10301.8398, KL Div: 3283.1855, Diffuse loss: 9.6916
# Epoch[96/100], Step [400/469], Reconst Loss: 9356.9219, KL Div: 3185.4473, Diffuse loss: 9.9766
# Epoch[97/100], Step [100/469], Reconst Loss: 9713.3301, KL Div: 3215.1702, Diffuse loss: 9.8062
# Epoch[97/100], Step [200/469], Reconst Loss: 9406.3633, KL Div: 3173.0830, Diffuse loss: 9.7316
# Epoch[97/100], Step [300/469], Reconst Loss: 9625.4121, KL Div: 3200.8071, Diffuse loss: 9.6957
# Epoch[97/100], Step [400/469], Reconst Loss: 9198.5625, KL Div: 3191.8723, Diffuse loss: 9.4917
# Epoch[98/100], Step [100/469], Reconst Loss: 9705.6621, KL Div: 3236.2158, Diffuse loss: 9.2321
# Epoch[98/100], Step [200/469], Reconst Loss: 9517.6797, KL Div: 3132.2065, Diffuse loss: 10.5376
# Epoch[98/100], Step [300/469], Reconst Loss: 9296.4004, KL Div: 3208.3030, Diffuse loss: 9.9791
# Epoch[98/100], Step [400/469], Reconst Loss: 9855.3662, KL Div: 3277.4902, Diffuse loss: 10.6823
# Epoch[99/100], Step [100/469], Reconst Loss: 10100.1230, KL Div: 3341.3997, Diffuse loss: 10.6682
# Epoch[99/100], Step [200/469], Reconst Loss: 9632.1328, KL Div: 3257.7090, Diffuse loss: 10.0141
# Epoch[99/100], Step [300/469], Reconst Loss: 9678.4385, KL Div: 3302.9817, Diffuse loss: 10.1452
# Epoch[99/100], Step [400/469], Reconst Loss: 9979.0225, KL Div: 3387.9316, Diffuse loss: 10.7390
# Epoch[100/100], Step [100/469], Reconst Loss: 9105.9541, KL Div: 3143.9724, Diffuse loss: 9.2761
# Epoch[100/100], Step [200/469], Reconst Loss: 9462.7949, KL Div: 3168.4229, Diffuse loss: 9.3351
# Epoch[100/100], Step [300/469], Reconst Loss: 9894.7637, KL Div: 3253.8640, Diffuse loss: 9.7412
# Epoch[100/100], Step [400/469], Reconst Loss: 9678.2158, KL Div: 3177.8198, Diffuse loss: 9.9001

# %%
if load_available:
    ckpt = torch.load(model_dir+'ckpt.pth', map_location=device)
    vae = VAE(input_size=image_size, h_dim=h_dim, z_dim=z_dim, type='ce').to(device)
    sn = SN_Model(marginal_prob_std=marginal_prob_std_fn, embed_dim=20, dim=z_dim, drop_p=0.3, num_classes=10, device=device)
    vae.load_state_dict(ckpt['vae_state'])
    sn.load_state_dict(ckpt['sn_state'])

# %%
_, (x, y) = next(enumerate(data_loader))
x = x.to(device)
y = y.to(device)

# %%
def ani_imshow(sample, sampling_number = 64):

    row_number = int(math.sqrt(sampling_number))
    col_number = int(math.sqrt(sampling_number))
    sample = sample[:sampling_number].detach().cpu().numpy()
    shape = sample.shape
    show_sample = np.zeros([row_number * shape[2], col_number * shape[3] ]).astype(np.float32)
    for row in range(row_number):
        for col in range(col_number):
            sample_ = sample[row + col * row_number][0]
            show_sample[ row * shape[2] : (row+1) * shape[2], col * shape[3] : (col+1) * shape[3] ] = (sample_ - sample_.min()) / (sample_.max() - sample_.min()) * 255

    show_sample = show_sample.astype(np.uint8)

    return show_sample

# %%
only_final = False
n_steps = 8
test_size = 36
# dynamic = AnnealedLangevinDynamic(sigma_min, sigma_max, n_steps, annealed_step, sn, device, eps=eps)
# sample = dynamic.sampling(test_size, z_dim, only_final=False)
sample = Euler_Maruyama_sampler(sn, marginal_prob_std_fn, diffusion_coeff_fn, dim=z_dim, batch_size=test_size, num_steps=500, device=device, only_final=False)
diffuse_data = vae.decode(sample)

step_size = sample.size(0)
fig, axs = plt.subplots(1, step_size, figsize=(step_size * 6, 6), constrained_layout = True)
for i in range(step_size):
    diff_data = diffuse_data[i].view(-1, 1, 28, 28)
    axs[i].imshow(ani_imshow(diff_data, sampling_number = test_size), animated=True, cmap = 'gray')
    # plt.show()

# %%
from torchvision.utils import make_grid

sample_grid = make_grid(x.view(-1, 1, 28, 28), nrow=int(np.sqrt(x.shape[0])))

select_t = 0.3

plt.figure(figsize=(6,6))
plt.axis('off')
plt.imshow(sample_grid.permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
plt.show()

# %%
mu, log_var = vae.encode(x.view(-1, image_size))
z = vae.reparameterize(mu, log_var)
z_ = forward_process(z, marginal_prob_std_fn, 100, device=device, end_t=select_t, only_final=True)

# %%
sample = Euler_Maruyama_sampler(sn, marginal_prob_std_fn, diffusion_coeff_fn, dim=z_dim, batch_size=z_.shape[0], y=y, num_steps=100, device=device, start_t=select_t, only_final=True, init_x=z_)

diffuse_data = vae.decode(sample)

from torchvision.utils import make_grid

sample_grid = make_grid(diffuse_data.view(-1, 1, 28, 28), nrow=int(np.sqrt(x.shape[0])))

plt.figure(figsize=(6,6))
plt.axis('off')
plt.imshow(sample_grid.permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
plt.show()

# %%
## ODE sampler

sampler = ode_sampler #@param ['Euler_Maruyama_sampler', 'pc_sampler', 'ode_sampler'] {'type': 'raw'}

## Generate samples using the specified sampler.
z_ode = sampler(sn,
            marginal_prob_std_fn,
            diffusion_coeff_fn,
            batch_size=128,
            device=device,
            z=z_,
            y=y,
            start_t=select_t)
samples = vae.decode(z_ode.float()).view(-1, 1, 28, 28)
## Sample visualization.
samples = samples.clamp(0.0, 1.0)
# %matplotlib inline
import matplotlib.pyplot as plt
sample_grid = make_grid(samples, nrow=int(np.sqrt(batch_size)))

plt.figure(figsize=(6,6))
plt.axis('off')
plt.imshow(sample_grid.permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
plt.show()
# Out:
# Number of function evaluations: 5072

# %% [markdown]
# ### The changes of one sample

# %%
recon_x, _, _ = vae(x.view(-1, image_size)[0])

# %%
fig, axs = plt.subplots(1, 2, figsize=(2 * 2, 2), constrained_layout = True)
axs[0].imshow(ani_imshow(x[0].view(-1, 1, 28, 28), sampling_number = 1), animated=True, cmap = 'gray')
axs[1].imshow(ani_imshow(recon_x.view(-1, 1, 28, 28), sampling_number = 1), animated=True, cmap = 'gray')

# %%
mu, log_var = vae.encode(x.view(-1, image_size)[0])
z = vae.reparameterize(mu, log_var)

z_ = forward_process(z, marginal_prob_std_fn, num_steps=10, device=device, end_t=1., only_final=False)
recon_x_seq = vae.decode(z_).clamp(0.0, 1.0)

# %%
fig, axs = plt.subplots(1, recon_x_seq.shape[0], figsize=(recon_x_seq.shape[0] * 6, 6), constrained_layout = True)
for i in range(recon_x_seq.shape[0]):
    diff_data = recon_x_seq[i].view(-1, 1, 28, 28)
    axs[i].imshow(ani_imshow(diff_data, sampling_number = 1), animated=True, cmap = 'gray')
plt.title('Forward process in latent space and its reconstruction')
# Out:
# Text(0.5, 1.0, 'Forward process in latent space and its reconstruction')

# %%
sample = Euler_Maruyama_sampler(sn, marginal_prob_std_fn, diffusion_coeff_fn, dim=z_dim, batch_size=1, num_steps=500, device=device, save_times=10, start_t=1., only_final=False, init_x=z_[-1], y=torch.tensor([9]).to(device))
# sample = Euler_Maruyama_sampler(sn, marginal_prob_std_fn, diffusion_coeff_fn, dim=z_dim, batch_size=1, num_steps=500, device=device, save_times=10, start_t=1., only_final=False)0
diffuse_data = vae.decode(sample)

# %%
step_size = diffuse_data.shape[0]
fig, axs = plt.subplots(1, step_size, figsize=(step_size * 6, 6), constrained_layout = True)
for i in range(step_size):
    diff_data = diffuse_data[i].view(-1, 1, 28, 28)
    axs[i].imshow(ani_imshow(diff_data, sampling_number = 1), animated=True, cmap = 'gray')
plt.title('Reverse process in latent space and its reconstruction')
# Out:
# Text(0.5, 1.0, 'Reverse process in latent space and its reconstruction')

# %%
_, (x, y) = next(enumerate(data_loader))
x = x.to(device)
y = y.to(device)

mu, log_var = vae.encode(x.view(-1, image_size))
z = vae.reparameterize(mu, log_var)

# %%
# FID 
from piq import FID, ssim, psnr, MSID, LPIPS

metrics = ['FID', 'SSIM', 'PSNR', 'MSID']
fig, axs = plt.subplots(1, len(metrics), figsize=(len(metrics) * 6, 6), constrained_layout = True)
i = 0
for metric in metrics:
    if metric == 'FID':
        metric_fn = FID()
    elif metric == 'SSIM':
        metric_fn = ssim
    elif metric == 'PSNR':
        metric_fn = psnr
    elif metric == 'MSID':
        metric_fn = MSID()
    
    idx_list = []


    for t in np.linspace(0.01, 1, 100):
        z_ = forward_process(z, marginal_prob_std_fn, num_steps=10, device=device, end_t=t, only_final=True)
        sample = Euler_Maruyama_sampler(sn, marginal_prob_std_fn, diffusion_coeff_fn, dim=z_dim, batch_size=x.shape[0], num_steps=500, device=device, save_times=10, start_t=t, only_final=True, init_x=z_, y=y)
        data_sample = vae.decode(sample).view(-1, 1, 28, 28).detach()
        if metric in ['MSID', 'FID']:
            idx_list.append(metric_fn(x.view(-1, 28*28), data_sample.view(-1, 28*28)).item())
        else:
            idx_list.append(metric_fn(x, data_sample).item())
    
    axs[i].plot(idx_list)
    axs[i].set_title(metric)
    i = i + 1
plt.xlabel('timestep')
plt.show()
# Out:
# /home/oem/Documents/wangxu/LSGM-demo/models/scorenetwork.py:134: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(sigma**t, device=device)
