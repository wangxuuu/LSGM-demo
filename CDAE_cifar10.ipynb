# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from utils import *
from models.scorenetwork import *
from models.cnnvae import *
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from scipy.ndimage import rotate
from itertools import chain
from torchvision import transforms
from torchvision.utils import save_image, make_grid 

from IPython.display import HTML
from IPython.display import clear_output

# %%
CUDA_VISIBLE_DEVICES = 0

# initialize random seed
SEED = 0
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
np.random.seed(SEED)

# cuda = True if torch.cuda.is_available() else False
# FloatTensor = torch.cuda.FloatTensor if cuda else torch.FloatTensor
# torch.set_default_tensor_type(FloatTensor)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

sample_dir = './results/CIFAR_CDAE'
model_dir = './results/checkpoints/CIFAR_CDAE'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# if not os.path.exists(model_dir):
#     os.makedirs(model_dir)

# %%
joint_training = True
load_available = True

z_dim = 128
num_epochs = 100
batch_size = 64
learning_rate = 0.005
kl_weight = 0.00025

eps = 1e-6
sigma_min = 0.001
sigma_max = 10
n_steps = 10
annealed_step = 100

select_t = 0.3

# %%
# MNIST dataset
dataset = torchvision.datasets.CIFAR10(root='../../Data/cifar10/',
                                     train=True,
                                     transform=transforms.ToTensor(),
                                     download=True)

# Data loader
data_loader = torch.utils.data.DataLoader(dataset=dataset,
                                          batch_size=batch_size,
                                          shuffle=True)

sigma =  5.0#@param {'type':'number'}
marginal_prob_std_fn = functools.partial(marginal_prob_std, sigma=sigma)
diffusion_coeff_fn = functools.partial(diffusion_coeff, sigma=sigma)
# Out:
# Files already downloaded and verified

# %%
vae = CnnVAE(in_channels=3, latent_dim=z_dim).to(device)
vae_optimizer = torch.optim.Adam(vae.parameters(), lr=learning_rate)

# sn = SN_Model(device, n_steps, sigma_min, sigma_max, dim=z_dim, p = 0.3)
sn = SN_Model(marginal_prob_std=marginal_prob_std_fn, embed_dim=20, dim=z_dim, drop_p=0.3, num_classes=10, device=device)
sn_optim = torch.optim.Adam(sn.parameters(), lr = 0.005)
# dynamic = AnnealedLangevinDynamic(sigma_min, sigma_max, n_steps, annealed_step, sn, device, eps=eps)

joint_optim = torch.optim.Adam(params=chain(vae.parameters(), sn.parameters()))

# Start training
for epoch in range(num_epochs):
    for i, (x, y) in enumerate(data_loader):
        x = x.to(device)
        y = y.to(device)
        if joint_training:
            mu, log_var = vae.encode(x)
            z = vae.reparameterize(mu, log_var)
            x_reconst = vae.decode(z)
            # Compute reconstruction loss and kl divergence
            reconst_loss = F.binary_cross_entropy(x_reconst, x, reduction='sum')
            # reconst_loss = F.mse_loss(x_reconst, x)
            # reconst_loss = F.cross_entropy(x_reconst, x)
            # kl_div = - 0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
            kl_div = torch.mean(-0.5 * torch.sum(1 + log_var - mu ** 2 - log_var.exp(), dim = 1), dim = 0)
            
            loss_sn = sn.loss(z, y)
            loss = loss_sn + reconst_loss + kl_weight*kl_div

            joint_optim.zero_grad()
            loss.backward()
            joint_optim.step()
        else:
            #============= First Stage: Update VAE ==============#
            # Forward pass
            x_reconst, _, mu, log_var = vae(x)
            # Compute reconstruction loss and kl divergence
            reconst_loss = F.mse_loss(x_reconst, x)
            # kl_div = - 0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
            kl_div = torch.mean(-0.5 * torch.sum(1 + log_var - mu ** 2 - log_var.exp(), dim = 1), dim = 0)
            
            # Backprop and optimize
            vae_loss = reconst_loss + kl_div
            vae_optimizer.zero_grad()
            vae_loss.backward()
            vae_optimizer.step()

            #============= Second Stage: Update SN ==============#
            mu, log_var = vae.encode(x)
            z = vae.reparameterize(mu, log_var)

            loss_sn = sn.loss(z)
            vae_optimizer.zero_grad()
            sn_optim.zero_grad()
            loss_sn.backward()
            sn_optim.step()

        if (i+1) % 100 == 0:
            print ("Epoch[{}/{}], Step [{}/{}], Reconst Loss: {:.4f}, KL Div: {:.4f}, Diffuse loss: {:.4f}"
                   .format(epoch+1, num_epochs, i+1, len(data_loader), reconst_loss.item(), kl_div.item(), loss_sn.item()))

    with torch.no_grad():
        # Save the sampled images
        z = torch.randn(x.shape[0], z_dim).to(device)
        out = vae.decode(z)
        x_concat = torch.cat([x, out], dim=3)
        save_image(x_concat, os.path.join(sample_dir, 'sampled-{}.png'.format(epoch+1)), nrow=4)

        # Save the reconstructed images
        out, _, _, _ = vae(x)
        x_concat = torch.cat([x, out], dim=3)
        save_image(x_concat, os.path.join(sample_dir, 'reconst-{}.png'.format(epoch+1)), nrow=4)

        # Save the diffused ima ges
        # dynamic = AnnealedLangevinDynamic(sigma_min, sigma_max, n_steps, annealed_step, sn, device, eps=eps)
        # z_ = forward_proc(z, sigma_min, sigma_max, n_steps, device=device, only_final=True)
        # sample = dynamic.sampling(x.shape[0], z_dim, sample=z_, only_final=True)
        z_ = forward_process(z, marginal_prob_std_fn, 100, device=device, end_t=select_t, only_final=True)
        sample = Euler_Maruyama_sampler(sn, marginal_prob_std_fn, diffusion_coeff_fn, dim=z_dim, batch_size=x.shape[0], num_steps=500, device=device, init_x=z_, start_t=select_t, only_final=True)

        # sample = dynamic.sampling(x.shape[0], z_dim, only_final=True)
        out = vae.decode(sample)
        x_concat = torch.cat([x, out], dim=3)
        save_image(x_concat, os.path.join(sample_dir, 'diffuse-{}.png'.format(epoch+1)), nrow=4)
torch.save({'sn_state':sn.state_dict(), 'vae_state':vae.state_dict()}, model_dir+'ckpt.pth')
# Out:
# Epoch[1/100], Step [100/782], Reconst Loss: 123347.2969, KL Div: 283.8516, Diffuse loss: 108.7753
# Epoch[1/100], Step [200/782], Reconst Loss: 120325.3281, KL Div: 369.0085, Diffuse loss: 100.1437
# Epoch[1/100], Step [300/782], Reconst Loss: 119594.5938, KL Div: 433.1311, Diffuse loss: 93.9849
# Epoch[1/100], Step [400/782], Reconst Loss: 117399.5938, KL Div: 482.6812, Diffuse loss: 89.7641
# Epoch[1/100], Step [500/782], Reconst Loss: 118156.7188, KL Div: 524.3258, Diffuse loss: 91.7642
# Epoch[1/100], Step [600/782], Reconst Loss: 120729.4375, KL Div: 551.4482, Diffuse loss: 92.4540
# Epoch[1/100], Step [700/782], Reconst Loss: 115556.4688, KL Div: 587.8135, Diffuse loss: 90.0320
# /home/oem/Documents/wangxu/LSGM-demo/models/scorenetwork.py:134: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(sigma**t, device=device)
# Epoch[2/100], Step [100/782], Reconst Loss: 115427.0312, KL Div: 645.6195, Diffuse loss: 89.9581
# Epoch[2/100], Step [200/782], Reconst Loss: 119037.8906, KL Div: 680.9718, Diffuse loss: 91.3350
# Epoch[2/100], Step [300/782], Reconst Loss: 114786.5859, KL Div: 694.3947, Diffuse loss: 86.7589
# Epoch[2/100], Step [400/782], Reconst Loss: 118002.2266, KL Div: 714.4917, Diffuse loss: 86.9640
# Epoch[2/100], Step [500/782], Reconst Loss: 116030.7266, KL Div: 737.8608, Diffuse loss: 92.7700
# Epoch[2/100], Step [600/782], Reconst Loss: 115393.0781, KL Div: 773.7518, Diffuse loss: 84.7254
# Epoch[2/100], Step [700/782], Reconst Loss: 116056.3750, KL Div: 790.1454, Diffuse loss: 86.1661
# Epoch[3/100], Step [100/782], Reconst Loss: 116034.1875, KL Div: 819.2422, Diffuse loss: 85.3911
# Epoch[3/100], Step [200/782], Reconst Loss: 115177.8516, KL Div: 846.9357, Diffuse loss: 89.0221
# Epoch[3/100], Step [300/782], Reconst Loss: 117630.6250, KL Div: 854.4843, Diffuse loss: 85.5905
# Epoch[3/100], Step [400/782], Reconst Loss: 117957.3828, KL Div: 869.7183, Diffuse loss: 86.5618
# Epoch[3/100], Step [500/782], Reconst Loss: 116221.7188, KL Div: 887.4055, Diffuse loss: 85.7924
# Epoch[3/100], Step [600/782], Reconst Loss: 111557.6719, KL Div: 904.2954, Diffuse loss: 84.8170
# Epoch[3/100], Step [700/782], Reconst Loss: 115506.7344, KL Div: 916.7778, Diffuse loss: 87.2971
# Epoch[4/100], Step [100/782], Reconst Loss: 115986.3906, KL Div: 949.2069, Diffuse loss: 85.3295
# Epoch[4/100], Step [200/782], Reconst Loss: 114456.9844, KL Div: 967.1908, Diffuse loss: 84.7634
# Epoch[4/100], Step [300/782], Reconst Loss: 114776.0781, KL Div: 983.0359, Diffuse loss: 87.1307
# Epoch[4/100], Step [400/782], Reconst Loss: 114215.7812, KL Div: 1001.9727, Diffuse loss: 83.8022
# Epoch[4/100], Step [500/782], Reconst Loss: 114133.4531, KL Div: 1023.5756, Diffuse loss: 87.2280
# Epoch[4/100], Step [600/782], Reconst Loss: 111672.8281, KL Div: 1031.1537, Diffuse loss: 82.3735
# Epoch[4/100], Step [700/782], Reconst Loss: 113933.9688, KL Div: 1048.6670, Diffuse loss: 82.8858
# Epoch[5/100], Step [100/782], Reconst Loss: 112460.8594, KL Div: 1070.6006, Diffuse loss: 83.9323
# Epoch[5/100], Step [200/782], Reconst Loss: 116603.4766, KL Div: 1089.4557, Diffuse loss: 84.4979
# Epoch[5/100], Step [300/782], Reconst Loss: 113833.5000, KL Div: 1099.0513, Diffuse loss: 87.2173
# Epoch[5/100], Step [400/782], Reconst Loss: 114411.2422, KL Div: 1107.2296, Diffuse loss: 81.8945
# Epoch[5/100], Step [500/782], Reconst Loss: 115911.8594, KL Div: 1135.9424, Diffuse loss: 88.6258
# Epoch[5/100], Step [600/782], Reconst Loss: 115925.4219, KL Div: 1135.3354, Diffuse loss: 83.8144
# Epoch[5/100], Step [700/782], Reconst Loss: 117695.3594, KL Div: 1169.7151, Diffuse loss: 82.8556
# Epoch[6/100], Step [100/782], Reconst Loss: 113916.3438, KL Div: 1182.6470, Diffuse loss: 82.0210
# Epoch[6/100], Step [200/782], Reconst Loss: 115190.2422, KL Div: 1170.9954, Diffuse loss: 86.9597
# Epoch[6/100], Step [300/782], Reconst Loss: 113361.4844, KL Div: 1182.4539, Diffuse loss: 83.3181
# Epoch[6/100], Step [400/782], Reconst Loss: 113526.3516, KL Div: 1191.4803, Diffuse loss: 84.7652
# Epoch[6/100], Step [500/782], Reconst Loss: 114202.5625, KL Div: 1226.8765, Diffuse loss: 82.8799
# Epoch[6/100], Step [600/782], Reconst Loss: 113214.7656, KL Div: 1239.7460, Diffuse loss: 81.5789
# Epoch[6/100], Step [700/782], Reconst Loss: 114305.4219, KL Div: 1236.4342, Diffuse loss: 84.9222
# Epoch[7/100], Step [100/782], Reconst Loss: 111564.9609, KL Div: 1254.5813, Diffuse loss: 84.4318
# Epoch[7/100], Step [200/782], Reconst Loss: 114390.4922, KL Div: 1273.1748, Diffuse loss: 85.2497
# Epoch[7/100], Step [300/782], Reconst Loss: 115905.5156, KL Div: 1284.8640, Diffuse loss: 81.5968
# Epoch[7/100], Step [400/782], Reconst Loss: 112954.7969, KL Div: 1274.7408, Diffuse loss: 82.1585
# Epoch[7/100], Step [500/782], Reconst Loss: 115397.0703, KL Div: 1290.1760, Diffuse loss: 78.7741
# Epoch[7/100], Step [600/782], Reconst Loss: 114639.5781, KL Div: 1324.6672, Diffuse loss: 83.9935
# Epoch[7/100], Step [700/782], Reconst Loss: 115977.7656, KL Div: 1324.9756, Diffuse loss: 84.0950
# Epoch[8/100], Step [100/782], Reconst Loss: 111518.9141, KL Div: 1336.4302, Diffuse loss: 82.5733
# Epoch[8/100], Step [200/782], Reconst Loss: 114349.8594, KL Div: 1337.4315, Diffuse loss: 77.8868
# Epoch[8/100], Step [300/782], Reconst Loss: 114484.5781, KL Div: 1356.8000, Diffuse loss: 81.2792
# Epoch[8/100], Step [400/782], Reconst Loss: 115112.3516, KL Div: 1372.4305, Diffuse loss: 79.7402
# Epoch[8/100], Step [500/782], Reconst Loss: 114724.2188, KL Div: 1377.9973, Diffuse loss: 77.7473
# Epoch[8/100], Step [600/782], Reconst Loss: 111145.1094, KL Div: 1395.3185, Diffuse loss: 85.9780
# Epoch[8/100], Step [700/782], Reconst Loss: 113068.8516, KL Div: 1392.1561, Diffuse loss: 79.8395
# Epoch[9/100], Step [100/782], Reconst Loss: 116259.6562, KL Div: 1393.2903, Diffuse loss: 82.8483
# Epoch[9/100], Step [200/782], Reconst Loss: 113074.8438, KL Div: 1406.2538, Diffuse loss: 82.9188
# Epoch[9/100], Step [300/782], Reconst Loss: 115740.0078, KL Div: 1425.6089, Diffuse loss: 82.3978
# Epoch[9/100], Step [400/782], Reconst Loss: 115001.2891, KL Div: 1444.8888, Diffuse loss: 78.3013
# Epoch[9/100], Step [500/782], Reconst Loss: 110719.6406, KL Div: 1443.3766, Diffuse loss: 82.8139
# Epoch[9/100], Step [600/782], Reconst Loss: 112816.6719, KL Div: 1442.3796, Diffuse loss: 81.4487
# Epoch[9/100], Step [700/782], Reconst Loss: 116071.1719, KL Div: 1454.6526, Diffuse loss: 81.5244
# Epoch[10/100], Step [100/782], Reconst Loss: 112220.6172, KL Div: 1465.0591, Diffuse loss: 78.3051
# Epoch[10/100], Step [200/782], Reconst Loss: 116464.8750, KL Div: 1473.3428, Diffuse loss: 79.9353
# Epoch[10/100], Step [300/782], Reconst Loss: 113103.8438, KL Div: 1488.3743, Diffuse loss: 81.0441
# Epoch[10/100], Step [400/782], Reconst Loss: 112080.5469, KL Div: 1483.7178, Diffuse loss: 79.9100
# Epoch[10/100], Step [500/782], Reconst Loss: 113753.6641, KL Div: 1486.5582, Diffuse loss: 80.7090
# Epoch[10/100], Step [600/782], Reconst Loss: 113676.9062, KL Div: 1494.4435, Diffuse loss: 79.0506
# Epoch[10/100], Step [700/782], Reconst Loss: 116807.4453, KL Div: 1502.2522, Diffuse loss: 81.8036
# Epoch[11/100], Step [100/782], Reconst Loss: 113705.1094, KL Div: 1517.7797, Diffuse loss: 77.7126
# Epoch[11/100], Step [200/782], Reconst Loss: 116271.3438, KL Div: 1534.7192, Diffuse loss: 82.2747
# Epoch[11/100], Step [300/782], Reconst Loss: 115469.7891, KL Div: 1558.3760, Diffuse loss: 83.5865
# Epoch[11/100], Step [400/782], Reconst Loss: 111876.2891, KL Div: 1551.1140, Diffuse loss: 83.4614
# Epoch[11/100], Step [500/782], Reconst Loss: 116763.3984, KL Div: 1555.5204, Diffuse loss: 83.1206
# Epoch[11/100], Step [600/782], Reconst Loss: 114277.4688, KL Div: 1567.7168, Diffuse loss: 79.9089
# Epoch[11/100], Step [700/782], Reconst Loss: 114723.7188, KL Div: 1560.4642, Diffuse loss: 85.0747
# Epoch[12/100], Step [100/782], Reconst Loss: 113931.5078, KL Div: 1565.7363, Diffuse loss: 80.5521
# Epoch[12/100], Step [200/782], Reconst Loss: 114339.7656, KL Div: 1614.7795, Diffuse loss: 82.7978
# Epoch[12/100], Step [300/782], Reconst Loss: 112197.7969, KL Div: 1573.7136, Diffuse loss: 84.2368
# Epoch[12/100], Step [400/782], Reconst Loss: 112236.8984, KL Div: 1567.6147, Diffuse loss: 82.0303
# Epoch[12/100], Step [500/782], Reconst Loss: 115161.4688, KL Div: 1595.3389, Diffuse loss: 79.6676
# Epoch[12/100], Step [600/782], Reconst Loss: 117036.6953, KL Div: 1601.1803, Diffuse loss: 78.5760
# Epoch[12/100], Step [700/782], Reconst Loss: 112215.9297, KL Div: 1613.0166, Diffuse loss: 81.7200
# Epoch[13/100], Step [100/782], Reconst Loss: 111392.9844, KL Div: 1631.5203, Diffuse loss: 82.3714
# Epoch[13/100], Step [200/782], Reconst Loss: 116808.0391, KL Div: 1595.2642, Diffuse loss: 81.3332
# Epoch[13/100], Step [300/782], Reconst Loss: 111531.5469, KL Div: 1629.6555, Diffuse loss: 80.2996
# Epoch[13/100], Step [400/782], Reconst Loss: 111929.4766, KL Div: 1661.7693, Diffuse loss: 80.6235
# Epoch[13/100], Step [500/782], Reconst Loss: 110528.3281, KL Div: 1628.6174, Diffuse loss: 82.8167
# Epoch[13/100], Step [600/782], Reconst Loss: 113882.1016, KL Div: 1660.5452, Diffuse loss: 84.3941
# Epoch[13/100], Step [700/782], Reconst Loss: 115868.5547, KL Div: 1671.2690, Diffuse loss: 84.0430
# Epoch[14/100], Step [100/782], Reconst Loss: 113501.5547, KL Div: 1633.0056, Diffuse loss: 81.9867
# Epoch[14/100], Step [200/782], Reconst Loss: 115832.4688, KL Div: 1665.5426, Diffuse loss: 82.5106
# Epoch[14/100], Step [300/782], Reconst Loss: 115672.2109, KL Div: 1697.9001, Diffuse loss: 79.4107
# Epoch[14/100], Step [400/782], Reconst Loss: 110881.0000, KL Div: 1698.4283, Diffuse loss: 77.7987
# Epoch[14/100], Step [500/782], Reconst Loss: 114764.6406, KL Div: 1689.4038, Diffuse loss: 77.9740
# Epoch[14/100], Step [600/782], Reconst Loss: 113871.3203, KL Div: 1688.5078, Diffuse loss: 80.6262
# Epoch[14/100], Step [700/782], Reconst Loss: 114558.2031, KL Div: 1680.3788, Diffuse loss: 81.2083
# Epoch[15/100], Step [100/782], Reconst Loss: 112422.1719, KL Div: 1734.0286, Diffuse loss: 79.6912
# Epoch[15/100], Step [200/782], Reconst Loss: 112849.5938, KL Div: 1745.1805, Diffuse loss: 78.7064
# Epoch[15/100], Step [300/782], Reconst Loss: 118076.5156, KL Div: 1719.5474, Diffuse loss: 81.4284
# Epoch[15/100], Step [400/782], Reconst Loss: 111163.6016, KL Div: 1726.1602, Diffuse loss: 78.8403
# Epoch[15/100], Step [500/782], Reconst Loss: 115440.0156, KL Div: 1722.3807, Diffuse loss: 80.6082
# Epoch[15/100], Step [600/782], Reconst Loss: 110343.8125, KL Div: 1702.4714, Diffuse loss: 80.9147
# Epoch[15/100], Step [700/782], Reconst Loss: 109793.6406, KL Div: 1719.5725, Diffuse loss: 83.1267
# Epoch[16/100], Step [100/782], Reconst Loss: 116678.0312, KL Div: 1748.9917, Diffuse loss: 80.7518
# Epoch[16/100], Step [200/782], Reconst Loss: 111703.5391, KL Div: 1744.0624, Diffuse loss: 80.1926
# Epoch[16/100], Step [300/782], Reconst Loss: 112406.3125, KL Div: 1761.2887, Diffuse loss: 79.5200
# Epoch[16/100], Step [400/782], Reconst Loss: 116853.1953, KL Div: 1773.7639, Diffuse loss: 81.2709
# Epoch[16/100], Step [500/782], Reconst Loss: 113319.1562, KL Div: 1764.8748, Diffuse loss: 84.1388
# Epoch[16/100], Step [600/782], Reconst Loss: 115471.9375, KL Div: 1802.1075, Diffuse loss: 84.4025
# Epoch[16/100], Step [700/782], Reconst Loss: 111092.4688, KL Div: 1777.0759, Diffuse loss: 80.2772
# Epoch[17/100], Step [100/782], Reconst Loss: 115374.8906, KL Div: 1807.4805, Diffuse loss: 80.2544
# Epoch[17/100], Step [200/782], Reconst Loss: 113435.3438, KL Div: 1830.7566, Diffuse loss: 82.8965
# Epoch[17/100], Step [300/782], Reconst Loss: 110906.1406, KL Div: 1805.8105, Diffuse loss: 80.8504
# Epoch[17/100], Step [400/782], Reconst Loss: 117236.1875, KL Div: 1825.6024, Diffuse loss: 75.4023
# Epoch[17/100], Step [500/782], Reconst Loss: 113609.9453, KL Div: 1826.8065, Diffuse loss: 81.5122
# Epoch[17/100], Step [600/782], Reconst Loss: 112597.7422, KL Div: 1832.9563, Diffuse loss: 82.2430
# Epoch[17/100], Step [700/782], Reconst Loss: 112346.7969, KL Div: 1816.1213, Diffuse loss: 80.8980
# Epoch[18/100], Step [100/782], Reconst Loss: 112568.9453, KL Div: 1872.0244, Diffuse loss: 78.9214
# Epoch[18/100], Step [200/782], Reconst Loss: 114776.6250, KL Div: 1833.0865, Diffuse loss: 78.8244
# Epoch[18/100], Step [300/782], Reconst Loss: 114223.2734, KL Div: 1884.7227, Diffuse loss: 85.3848
# Epoch[18/100], Step [400/782], Reconst Loss: 114480.7969, KL Div: 1886.6934, Diffuse loss: 80.5820
# Epoch[18/100], Step [500/782], Reconst Loss: 114094.7422, KL Div: 1887.8021, Diffuse loss: 80.7595
# Epoch[18/100], Step [600/782], Reconst Loss: 112571.2031, KL Div: 1836.7554, Diffuse loss: 81.5588
# Epoch[18/100], Step [700/782], Reconst Loss: 112440.5156, KL Div: 1855.5352, Diffuse loss: 75.6263
# Epoch[19/100], Step [100/782], Reconst Loss: 113231.0625, KL Div: 1889.3722, Diffuse loss: 78.4158
# Epoch[19/100], Step [200/782], Reconst Loss: 113733.3750, KL Div: 1915.8352, Diffuse loss: 79.2981
# Epoch[19/100], Step [300/782], Reconst Loss: 114711.1484, KL Div: 1883.4576, Diffuse loss: 81.5932
# Epoch[19/100], Step [400/782], Reconst Loss: 112626.9062, KL Div: 1901.8811, Diffuse loss: 79.3224
# Epoch[19/100], Step [500/782], Reconst Loss: 114145.5312, KL Div: 1931.2866, Diffuse loss: 82.4488
# Epoch[19/100], Step [600/782], Reconst Loss: 112640.2422, KL Div: 1917.9497, Diffuse loss: 80.4329
# Epoch[19/100], Step [700/782], Reconst Loss: 114926.2031, KL Div: 1902.1368, Diffuse loss: 85.0511
# Epoch[20/100], Step [100/782], Reconst Loss: 111862.2969, KL Div: 1891.5681, Diffuse loss: 83.2908
# Epoch[20/100], Step [200/782], Reconst Loss: 111725.8594, KL Div: 1891.7212, Diffuse loss: 84.0879
# Epoch[20/100], Step [300/782], Reconst Loss: 114607.0938, KL Div: 1914.7847, Diffuse loss: 81.7852
# Epoch[20/100], Step [400/782], Reconst Loss: 111384.8828, KL Div: 1957.6998, Diffuse loss: 82.0052
# Epoch[20/100], Step [500/782], Reconst Loss: 116426.0859, KL Div: 1974.0999, Diffuse loss: 83.0481
# Epoch[20/100], Step [600/782], Reconst Loss: 110885.0938, KL Div: 1940.4314, Diffuse loss: 83.6579
# Epoch[20/100], Step [700/782], Reconst Loss: 114977.2422, KL Div: 1956.6106, Diffuse loss: 84.5260
# Epoch[21/100], Step [100/782], Reconst Loss: 112237.6094, KL Div: 1940.6035, Diffuse loss: 81.4153
# Epoch[21/100], Step [200/782], Reconst Loss: 115161.2422, KL Div: 1950.4751, Diffuse loss: 78.2368
# Epoch[21/100], Step [300/782], Reconst Loss: 113535.5781, KL Div: 1948.2109, Diffuse loss: 79.8266
# Epoch[21/100], Step [400/782], Reconst Loss: 111263.0234, KL Div: 1962.6721, Diffuse loss: 82.4600
# Epoch[21/100], Step [500/782], Reconst Loss: 110775.6172, KL Div: 1946.7285, Diffuse loss: 85.3115
# Epoch[21/100], Step [600/782], Reconst Loss: 110746.8125, KL Div: 1994.9281, Diffuse loss: 81.4528
# Epoch[21/100], Step [700/782], Reconst Loss: 118197.3516, KL Div: 1994.3904, Diffuse loss: 82.7577
# Epoch[22/100], Step [100/782], Reconst Loss: 111755.6250, KL Div: 1988.6246, Diffuse loss: 77.7882
# Epoch[22/100], Step [200/782], Reconst Loss: 113292.4688, KL Div: 2013.4946, Diffuse loss: 83.5084
# Epoch[22/100], Step [300/782], Reconst Loss: 110739.1406, KL Div: 2027.5430, Diffuse loss: 85.2109
# Epoch[22/100], Step [400/782], Reconst Loss: 108052.6953, KL Div: 2019.3174, Diffuse loss: 82.0706
# Epoch[22/100], Step [500/782], Reconst Loss: 113887.0547, KL Div: 2036.6085, Diffuse loss: 81.0974
# Epoch[22/100], Step [600/782], Reconst Loss: 113650.9062, KL Div: 2044.8815, Diffuse loss: 80.8069
# Epoch[22/100], Step [700/782], Reconst Loss: 114649.2891, KL Div: 1986.1583, Diffuse loss: 81.6646
# Epoch[23/100], Step [100/782], Reconst Loss: 113077.3750, KL Div: 2041.2172, Diffuse loss: 84.9356
# Epoch[23/100], Step [200/782], Reconst Loss: 112809.0859, KL Div: 2072.5635, Diffuse loss: 80.1047
# Epoch[23/100], Step [300/782], Reconst Loss: 112517.7266, KL Div: 2054.3433, Diffuse loss: 79.3825
# Epoch[23/100], Step [400/782], Reconst Loss: 116017.7891, KL Div: 2077.7329, Diffuse loss: 81.2468
# Epoch[23/100], Step [500/782], Reconst Loss: 113134.1094, KL Div: 2084.6865, Diffuse loss: 82.8422
# Epoch[23/100], Step [600/782], Reconst Loss: 114521.5156, KL Div: 2097.8486, Diffuse loss: 82.8573
# Epoch[23/100], Step [700/782], Reconst Loss: 114796.3359, KL Div: 2089.2139, Diffuse loss: 79.6020
# Epoch[24/100], Step [100/782], Reconst Loss: 112565.5156, KL Div: 2107.9434, Diffuse loss: 84.1781
# Epoch[24/100], Step [200/782], Reconst Loss: 111563.8594, KL Div: 2098.0015, Diffuse loss: 80.7757
# Epoch[24/100], Step [300/782], Reconst Loss: 114542.7578, KL Div: 2071.8010, Diffuse loss: 83.5135
# Epoch[24/100], Step [400/782], Reconst Loss: 113955.0625, KL Div: 2103.6367, Diffuse loss: 80.5607
# Epoch[24/100], Step [500/782], Reconst Loss: 112984.7578, KL Div: 2079.8018, Diffuse loss: 78.2117
# Epoch[24/100], Step [600/782], Reconst Loss: 114573.1641, KL Div: 2136.1296, Diffuse loss: 80.5498
# Epoch[24/100], Step [700/782], Reconst Loss: 112904.8281, KL Div: 2103.5593, Diffuse loss: 83.7887
# Epoch[25/100], Step [100/782], Reconst Loss: 112018.2969, KL Div: 2099.8479, Diffuse loss: 82.1845
# Epoch[25/100], Step [200/782], Reconst Loss: 114686.4297, KL Div: 2123.1655, Diffuse loss: 82.1385
# Epoch[25/100], Step [300/782], Reconst Loss: 114544.7734, KL Div: 2127.4702, Diffuse loss: 82.3124
# Epoch[25/100], Step [400/782], Reconst Loss: 112839.4297, KL Div: 2088.2280, Diffuse loss: 82.0994
# Epoch[25/100], Step [500/782], Reconst Loss: 109660.7422, KL Div: 2118.9592, Diffuse loss: 81.6143
# Epoch[25/100], Step [600/782], Reconst Loss: 111428.6484, KL Div: 2168.1589, Diffuse loss: 81.9382
# Epoch[25/100], Step [700/782], Reconst Loss: 116439.7812, KL Div: 2167.6177, Diffuse loss: 82.3266
# Epoch[26/100], Step [100/782], Reconst Loss: 113830.3125, KL Div: 2162.8140, Diffuse loss: 82.7199
# Epoch[26/100], Step [200/782], Reconst Loss: 114549.5000, KL Div: 2180.7063, Diffuse loss: 81.9410
# Epoch[26/100], Step [300/782], Reconst Loss: 113452.8672, KL Div: 2175.4731, Diffuse loss: 79.3574
# Epoch[26/100], Step [400/782], Reconst Loss: 113706.5469, KL Div: 2167.5300, Diffuse loss: 82.6351
# Epoch[26/100], Step [500/782], Reconst Loss: 111549.9297, KL Div: 2137.4575, Diffuse loss: 81.5298
# Epoch[26/100], Step [600/782], Reconst Loss: 113306.6562, KL Div: 2170.0073, Diffuse loss: 82.4492
# Epoch[26/100], Step [700/782], Reconst Loss: 112204.5234, KL Div: 2161.1846, Diffuse loss: 82.8310
# Epoch[27/100], Step [100/782], Reconst Loss: 111932.8281, KL Div: 2179.4519, Diffuse loss: 81.0915
# Epoch[27/100], Step [200/782], Reconst Loss: 114993.5703, KL Div: 2223.2646, Diffuse loss: 84.4110
# Epoch[27/100], Step [300/782], Reconst Loss: 113277.0000, KL Div: 2196.6497, Diffuse loss: 81.8312
# Epoch[27/100], Step [400/782], Reconst Loss: 113850.4844, KL Div: 2214.8823, Diffuse loss: 81.9092
# Epoch[27/100], Step [500/782], Reconst Loss: 114235.1719, KL Div: 2187.2461, Diffuse loss: 81.4413
# Epoch[27/100], Step [600/782], Reconst Loss: 113425.7031, KL Div: 2222.0151, Diffuse loss: 80.9746
# Epoch[27/100], Step [700/782], Reconst Loss: 111996.3125, KL Div: 2223.7725, Diffuse loss: 79.9205
# Epoch[28/100], Step [100/782], Reconst Loss: 111712.9688, KL Div: 2243.5667, Diffuse loss: 80.7673
# Epoch[28/100], Step [200/782], Reconst Loss: 113439.2344, KL Div: 2230.9868, Diffuse loss: 80.5768
# Epoch[28/100], Step [300/782], Reconst Loss: 113739.5859, KL Div: 2230.2705, Diffuse loss: 79.7204
# Epoch[28/100], Step [400/782], Reconst Loss: 113795.5000, KL Div: 2294.2241, Diffuse loss: 83.1367
# Epoch[28/100], Step [500/782], Reconst Loss: 113132.2734, KL Div: 2255.4299, Diffuse loss: 80.1042
# Epoch[28/100], Step [600/782], Reconst Loss: 114536.8438, KL Div: 2258.3984, Diffuse loss: 79.8113
# Epoch[28/100], Step [700/782], Reconst Loss: 112206.7578, KL Div: 2233.5264, Diffuse loss: 82.5108
# Epoch[29/100], Step [100/782], Reconst Loss: 113848.2969, KL Div: 2272.9771, Diffuse loss: 85.0951
# Epoch[29/100], Step [200/782], Reconst Loss: 113372.4922, KL Div: 2243.3125, Diffuse loss: 83.6764
# Epoch[29/100], Step [300/782], Reconst Loss: 113357.9297, KL Div: 2262.0820, Diffuse loss: 84.8100
# Epoch[29/100], Step [400/782], Reconst Loss: 111335.8438, KL Div: 2312.5042, Diffuse loss: 85.4666
# Epoch[29/100], Step [500/782], Reconst Loss: 109931.7812, KL Div: 2226.2434, Diffuse loss: 85.3919
# Epoch[29/100], Step [600/782], Reconst Loss: 111538.1406, KL Div: 2300.0859, Diffuse loss: 84.1753
# Epoch[29/100], Step [700/782], Reconst Loss: 111042.0859, KL Div: 2285.4194, Diffuse loss: 85.6326
# Epoch[30/100], Step [100/782], Reconst Loss: 110152.6875, KL Div: 2302.6565, Diffuse loss: 86.2766
# Epoch[30/100], Step [200/782], Reconst Loss: 113041.0156, KL Div: 2334.5608, Diffuse loss: 84.5962
# Epoch[30/100], Step [300/782], Reconst Loss: 114170.4375, KL Div: 2301.6538, Diffuse loss: 85.1200
# Epoch[30/100], Step [400/782], Reconst Loss: 115149.5234, KL Div: 2291.0112, Diffuse loss: 83.1072
# Epoch[30/100], Step [500/782], Reconst Loss: 112694.6328, KL Div: 2294.0491, Diffuse loss: 83.1840
# Epoch[30/100], Step [600/782], Reconst Loss: 112346.2891, KL Div: 2309.0981, Diffuse loss: 79.1791
# Epoch[30/100], Step [700/782], Reconst Loss: 109773.1406, KL Div: 2364.6055, Diffuse loss: 80.0101
# Epoch[31/100], Step [100/782], Reconst Loss: 114268.1094, KL Div: 2306.5925, Diffuse loss: 83.8068
# Epoch[31/100], Step [200/782], Reconst Loss: 112543.8906, KL Div: 2330.9436, Diffuse loss: 82.7605
# Epoch[31/100], Step [300/782], Reconst Loss: 112542.2266, KL Div: 2315.0181, Diffuse loss: 82.8915
# Epoch[31/100], Step [400/782], Reconst Loss: 106561.9219, KL Div: 2328.9448, Diffuse loss: 83.3376
# Epoch[31/100], Step [500/782], Reconst Loss: 115016.1875, KL Div: 2305.6829, Diffuse loss: 81.8765
# Epoch[31/100], Step [600/782], Reconst Loss: 113479.0703, KL Div: 2369.2583, Diffuse loss: 83.9659
# Epoch[31/100], Step [700/782], Reconst Loss: 113040.2031, KL Div: 2314.1548, Diffuse loss: 80.9042
# Epoch[32/100], Step [100/782], Reconst Loss: 112127.2812, KL Div: 2367.4585, Diffuse loss: 81.4956
# Epoch[32/100], Step [200/782], Reconst Loss: 117192.1094, KL Div: 2374.8335, Diffuse loss: 81.9541
# Epoch[32/100], Step [300/782], Reconst Loss: 110612.3672, KL Div: 2285.9434, Diffuse loss: 84.6824
# Epoch[32/100], Step [400/782], Reconst Loss: 112507.0312, KL Div: 2410.3721, Diffuse loss: 83.9264
# Epoch[32/100], Step [500/782], Reconst Loss: 112943.0469, KL Div: 2357.9868, Diffuse loss: 79.3040
# Epoch[32/100], Step [600/782], Reconst Loss: 110068.9531, KL Div: 2376.5923, Diffuse loss: 83.8877
# Epoch[32/100], Step [700/782], Reconst Loss: 110662.5000, KL Div: 2394.8689, Diffuse loss: 78.7461
# Epoch[33/100], Step [100/782], Reconst Loss: 115556.2969, KL Div: 2438.4363, Diffuse loss: 79.5258
# Epoch[33/100], Step [200/782], Reconst Loss: 111500.3203, KL Div: 2417.7495, Diffuse loss: 84.7766
# Epoch[33/100], Step [300/782], Reconst Loss: 111543.4297, KL Div: 2414.2324, Diffuse loss: 85.8498
# Epoch[33/100], Step [400/782], Reconst Loss: 112374.5000, KL Div: 2343.3657, Diffuse loss: 84.4730
# Epoch[33/100], Step [500/782], Reconst Loss: 113727.6719, KL Div: 2359.0742, Diffuse loss: 80.5769
# Epoch[33/100], Step [600/782], Reconst Loss: 112582.9453, KL Div: 2383.4536, Diffuse loss: 83.0537
# Epoch[33/100], Step [700/782], Reconst Loss: 112554.3203, KL Div: 2446.5256, Diffuse loss: 82.9569
# Epoch[34/100], Step [100/782], Reconst Loss: 110215.2188, KL Div: 2440.6855, Diffuse loss: 82.1833
# Epoch[34/100], Step [200/782], Reconst Loss: 112813.4531, KL Div: 2464.3301, Diffuse loss: 83.9234
# Epoch[34/100], Step [300/782], Reconst Loss: 113633.3125, KL Div: 2429.9473, Diffuse loss: 86.7949
# Epoch[34/100], Step [400/782], Reconst Loss: 112334.0781, KL Div: 2421.8091, Diffuse loss: 84.5054
# Epoch[34/100], Step [500/782], Reconst Loss: 111677.7188, KL Div: 2509.0371, Diffuse loss: 81.2013
# Epoch[34/100], Step [600/782], Reconst Loss: 112361.4219, KL Div: 2465.3738, Diffuse loss: 83.3925
# Epoch[34/100], Step [700/782], Reconst Loss: 112139.1562, KL Div: 2468.2988, Diffuse loss: 82.0676
# Epoch[35/100], Step [100/782], Reconst Loss: 112680.7656, KL Div: 2428.6348, Diffuse loss: 80.5413
# Epoch[35/100], Step [200/782], Reconst Loss: 114778.3750, KL Div: 2450.3149, Diffuse loss: 85.3573
# Epoch[35/100], Step [300/782], Reconst Loss: 111528.2188, KL Div: 2439.0879, Diffuse loss: 84.5665
# Epoch[35/100], Step [400/782], Reconst Loss: 112551.5000, KL Div: 2443.9055, Diffuse loss: 83.2565
# Epoch[35/100], Step [500/782], Reconst Loss: 109976.4844, KL Div: 2474.2466, Diffuse loss: 82.7429
# Epoch[35/100], Step [600/782], Reconst Loss: 111196.1562, KL Div: 2481.0498, Diffuse loss: 80.3695
# Epoch[35/100], Step [700/782], Reconst Loss: 112402.0312, KL Div: 2535.8311, Diffuse loss: 80.4330
# Epoch[36/100], Step [100/782], Reconst Loss: 112987.1562, KL Div: 2511.7297, Diffuse loss: 83.4286
# Epoch[36/100], Step [200/782], Reconst Loss: 111250.8281, KL Div: 2501.7241, Diffuse loss: 87.2019
# Epoch[36/100], Step [300/782], Reconst Loss: 115469.2188, KL Div: 2472.3228, Diffuse loss: 83.9153
# Epoch[36/100], Step [400/782], Reconst Loss: 113753.5703, KL Div: 2517.5566, Diffuse loss: 81.4953
# Epoch[36/100], Step [500/782], Reconst Loss: 113093.2656, KL Div: 2508.8286, Diffuse loss: 81.7772
# Epoch[36/100], Step [600/782], Reconst Loss: 113112.5391, KL Div: 2584.2590, Diffuse loss: 81.7518
# Epoch[36/100], Step [700/782], Reconst Loss: 112954.5781, KL Div: 2483.5005, Diffuse loss: 80.1767
# Epoch[37/100], Step [100/782], Reconst Loss: 113628.7734, KL Div: 2491.6997, Diffuse loss: 81.1136
# Epoch[37/100], Step [200/782], Reconst Loss: 112448.3438, KL Div: 2530.2686, Diffuse loss: 80.6397
# Epoch[37/100], Step [300/782], Reconst Loss: 112189.6094, KL Div: 2474.8872, Diffuse loss: 85.3926
# Epoch[37/100], Step [400/782], Reconst Loss: 111765.0938, KL Div: 2555.7920, Diffuse loss: 82.5971
# Epoch[37/100], Step [500/782], Reconst Loss: 111774.3203, KL Div: 2567.0811, Diffuse loss: 81.9728
# Epoch[37/100], Step [600/782], Reconst Loss: 109962.2656, KL Div: 2518.9109, Diffuse loss: 82.8357
# Epoch[37/100], Step [700/782], Reconst Loss: 115864.9219, KL Div: 2567.9736, Diffuse loss: 80.1111
# Epoch[38/100], Step [100/782], Reconst Loss: 109663.7344, KL Div: 2516.1685, Diffuse loss: 82.8379
# Epoch[38/100], Step [200/782], Reconst Loss: 112950.6797, KL Div: 2553.1147, Diffuse loss: 82.9048
# Epoch[38/100], Step [300/782], Reconst Loss: 108879.1094, KL Div: 2508.5000, Diffuse loss: 82.1473
# Epoch[38/100], Step [400/782], Reconst Loss: 111895.1172, KL Div: 2514.6270, Diffuse loss: 83.5410
# Epoch[38/100], Step [500/782], Reconst Loss: 109898.5000, KL Div: 2592.3784, Diffuse loss: 79.8294
# Epoch[38/100], Step [600/782], Reconst Loss: 114466.0312, KL Div: 2610.2207, Diffuse loss: 82.0595
# Epoch[38/100], Step [700/782], Reconst Loss: 113898.9141, KL Div: 2591.2808, Diffuse loss: 84.1879
# Epoch[39/100], Step [100/782], Reconst Loss: 113475.5938, KL Div: 2617.5535, Diffuse loss: 85.1526
# Epoch[39/100], Step [200/782], Reconst Loss: 112617.7422, KL Div: 2596.6948, Diffuse loss: 79.7437
# Epoch[39/100], Step [300/782], Reconst Loss: 111525.6562, KL Div: 2594.7412, Diffuse loss: 83.8492
# Epoch[39/100], Step [400/782], Reconst Loss: 113123.8047, KL Div: 2598.8203, Diffuse loss: 80.7435
# Epoch[39/100], Step [500/782], Reconst Loss: 113963.0703, KL Div: 2592.1758, Diffuse loss: 83.1207
# Epoch[39/100], Step [600/782], Reconst Loss: 114924.3281, KL Div: 2594.4805, Diffuse loss: 82.9109
# Epoch[39/100], Step [700/782], Reconst Loss: 115049.7422, KL Div: 2614.5693, Diffuse loss: 86.6361
# Epoch[40/100], Step [100/782], Reconst Loss: 112161.7031, KL Div: 2573.1274, Diffuse loss: 81.1499
# Epoch[40/100], Step [200/782], Reconst Loss: 112513.4219, KL Div: 2731.0347, Diffuse loss: 83.0751
# Epoch[40/100], Step [300/782], Reconst Loss: 114009.4141, KL Div: 2663.9924, Diffuse loss: 84.5580
# Epoch[40/100], Step [400/782], Reconst Loss: 110976.7031, KL Div: 2590.0049, Diffuse loss: 86.1897
# Epoch[40/100], Step [500/782], Reconst Loss: 108836.1562, KL Div: 2649.9937, Diffuse loss: 84.1603
# Epoch[40/100], Step [600/782], Reconst Loss: 109776.6875, KL Div: 2638.5366, Diffuse loss: 79.6438
# Epoch[40/100], Step [700/782], Reconst Loss: 113618.0703, KL Div: 2680.3765, Diffuse loss: 82.5563
# Epoch[41/100], Step [100/782], Reconst Loss: 113577.5000, KL Div: 2638.8296, Diffuse loss: 83.0672
# Epoch[41/100], Step [200/782], Reconst Loss: 111791.2656, KL Div: 2666.9546, Diffuse loss: 86.0781
# Epoch[41/100], Step [300/782], Reconst Loss: 113096.4141, KL Div: 2671.2769, Diffuse loss: 83.5807
# Epoch[41/100], Step [400/782], Reconst Loss: 112178.7656, KL Div: 2605.1440, Diffuse loss: 82.7164
# Epoch[41/100], Step [500/782], Reconst Loss: 109112.8281, KL Div: 2633.1877, Diffuse loss: 85.5368
# Epoch[41/100], Step [600/782], Reconst Loss: 106688.8203, KL Div: 2641.0044, Diffuse loss: 81.2049
# Epoch[41/100], Step [700/782], Reconst Loss: 113022.5078, KL Div: 2680.6011, Diffuse loss: 83.4188
# Epoch[42/100], Step [100/782], Reconst Loss: 112198.8281, KL Div: 2645.1543, Diffuse loss: 84.0172
# Epoch[42/100], Step [200/782], Reconst Loss: 111272.0000, KL Div: 2684.8586, Diffuse loss: 82.5930
# Epoch[42/100], Step [300/782], Reconst Loss: 112686.6328, KL Div: 2698.0349, Diffuse loss: 83.3551
# Epoch[42/100], Step [400/782], Reconst Loss: 113719.6250, KL Div: 2711.7810, Diffuse loss: 80.9772
# Epoch[42/100], Step [500/782], Reconst Loss: 110571.3594, KL Div: 2708.9602, Diffuse loss: 84.5252
# Epoch[42/100], Step [600/782], Reconst Loss: 113018.3281, KL Div: 2657.3220, Diffuse loss: 78.9585
# Epoch[42/100], Step [700/782], Reconst Loss: 113095.1172, KL Div: 2715.2146, Diffuse loss: 83.7914
# Epoch[43/100], Step [100/782], Reconst Loss: 113699.1562, KL Div: 2679.0432, Diffuse loss: 84.7369
# Epoch[43/100], Step [200/782], Reconst Loss: 111503.5938, KL Div: 2701.2000, Diffuse loss: 81.5461
# Epoch[43/100], Step [300/782], Reconst Loss: 110225.4844, KL Div: 2635.6741, Diffuse loss: 83.6763
# Epoch[43/100], Step [400/782], Reconst Loss: 112748.2969, KL Div: 2677.9619, Diffuse loss: 81.3604
# Epoch[43/100], Step [500/782], Reconst Loss: 109560.7969, KL Div: 2751.5425, Diffuse loss: 84.8309
# Epoch[43/100], Step [600/782], Reconst Loss: 114727.2500, KL Div: 2734.9131, Diffuse loss: 81.8287
# Epoch[43/100], Step [700/782], Reconst Loss: 108138.6484, KL Div: 2718.5688, Diffuse loss: 82.1330
# Epoch[44/100], Step [100/782], Reconst Loss: 114644.4688, KL Div: 2764.6318, Diffuse loss: 86.2004
# Epoch[44/100], Step [200/782], Reconst Loss: 113368.4062, KL Div: 2697.8965, Diffuse loss: 86.4330
# Epoch[44/100], Step [300/782], Reconst Loss: 109063.5625, KL Div: 2690.4985, Diffuse loss: 84.7954
# Epoch[44/100], Step [400/782], Reconst Loss: 113610.1797, KL Div: 2726.6030, Diffuse loss: 84.0449
# Epoch[44/100], Step [500/782], Reconst Loss: 113412.7969, KL Div: 2777.7878, Diffuse loss: 80.6695
# Epoch[44/100], Step [600/782], Reconst Loss: 109633.4062, KL Div: 2726.8486, Diffuse loss: 79.5604
# Epoch[44/100], Step [700/782], Reconst Loss: 111473.5234, KL Div: 2772.1946, Diffuse loss: 82.4148
# Epoch[45/100], Step [100/782], Reconst Loss: 112588.7969, KL Div: 2749.3667, Diffuse loss: 84.1960
# Epoch[45/100], Step [200/782], Reconst Loss: 113345.4531, KL Div: 2772.3215, Diffuse loss: 82.0390
# Epoch[45/100], Step [300/782], Reconst Loss: 113385.6016, KL Div: 2783.5142, Diffuse loss: 83.0098
# Epoch[45/100], Step [400/782], Reconst Loss: 113531.2812, KL Div: 2727.6101, Diffuse loss: 83.8455
# Epoch[45/100], Step [500/782], Reconst Loss: 111500.2031, KL Div: 2785.6470, Diffuse loss: 84.6454
# Epoch[45/100], Step [600/782], Reconst Loss: 111812.2578, KL Div: 2754.5227, Diffuse loss: 82.6811
# Epoch[45/100], Step [700/782], Reconst Loss: 114029.0234, KL Div: 2771.8850, Diffuse loss: 84.4619
# Epoch[46/100], Step [100/782], Reconst Loss: 111249.0156, KL Div: 2758.2627, Diffuse loss: 79.8741
# Epoch[46/100], Step [200/782], Reconst Loss: 113690.2891, KL Div: 2815.9937, Diffuse loss: 86.9854
# Epoch[46/100], Step [300/782], Reconst Loss: 113311.2031, KL Div: 2801.8879, Diffuse loss: 81.0015
# Epoch[46/100], Step [400/782], Reconst Loss: 112283.3125, KL Div: 2788.2104, Diffuse loss: 80.1007
# Epoch[46/100], Step [500/782], Reconst Loss: 112047.3281, KL Div: 2793.2063, Diffuse loss: 81.1649
# Epoch[46/100], Step [600/782], Reconst Loss: 109377.7578, KL Div: 2845.8950, Diffuse loss: 82.1155
# Epoch[46/100], Step [700/782], Reconst Loss: 114625.0312, KL Div: 2856.9854, Diffuse loss: 86.8913
# Epoch[47/100], Step [100/782], Reconst Loss: 110512.5781, KL Div: 2847.2202, Diffuse loss: 84.1131
# Epoch[47/100], Step [200/782], Reconst Loss: 111847.9844, KL Div: 2901.1030, Diffuse loss: 81.4196
# Epoch[47/100], Step [300/782], Reconst Loss: 112066.8594, KL Div: 2804.3362, Diffuse loss: 84.4377
# Epoch[47/100], Step [400/782], Reconst Loss: 110397.7266, KL Div: 2801.5518, Diffuse loss: 81.1210
# Epoch[47/100], Step [500/782], Reconst Loss: 114609.5547, KL Div: 2918.1086, Diffuse loss: 85.1109
# Epoch[47/100], Step [600/782], Reconst Loss: 110002.6953, KL Div: 2843.5439, Diffuse loss: 79.6919
# Epoch[47/100], Step [700/782], Reconst Loss: 106952.8281, KL Div: 2793.4058, Diffuse loss: 81.5478
# Epoch[48/100], Step [100/782], Reconst Loss: 112549.3516, KL Div: 2843.2251, Diffuse loss: 83.8370
# Epoch[48/100], Step [200/782], Reconst Loss: 109438.7812, KL Div: 2900.9419, Diffuse loss: 83.9074
# Epoch[48/100], Step [300/782], Reconst Loss: 111503.5312, KL Div: 2849.9194, Diffuse loss: 81.3861
# Epoch[48/100], Step [400/782], Reconst Loss: 115302.4062, KL Div: 2881.8953, Diffuse loss: 84.7645
# Epoch[48/100], Step [500/782], Reconst Loss: 114610.6797, KL Div: 2841.3726, Diffuse loss: 85.1012
# Epoch[48/100], Step [600/782], Reconst Loss: 110835.0391, KL Div: 2880.0767, Diffuse loss: 83.2575
# Epoch[48/100], Step [700/782], Reconst Loss: 111555.6797, KL Div: 2916.6567, Diffuse loss: 86.0928
# Epoch[49/100], Step [100/782], Reconst Loss: 112029.5781, KL Div: 2958.3379, Diffuse loss: 82.7863
# Epoch[49/100], Step [200/782], Reconst Loss: 111040.7109, KL Div: 2829.1968, Diffuse loss: 82.5316
# Epoch[49/100], Step [300/782], Reconst Loss: 111935.3125, KL Div: 2836.6487, Diffuse loss: 79.8797
# Epoch[49/100], Step [400/782], Reconst Loss: 110901.7969, KL Div: 2903.7849, Diffuse loss: 82.1823
# Epoch[49/100], Step [500/782], Reconst Loss: 108645.4453, KL Div: 2920.2715, Diffuse loss: 85.2197
# Epoch[49/100], Step [600/782], Reconst Loss: 111934.6406, KL Div: 2857.9346, Diffuse loss: 85.4030
# Epoch[49/100], Step [700/782], Reconst Loss: 111020.0469, KL Div: 2918.1467, Diffuse loss: 84.8864
# Epoch[50/100], Step [100/782], Reconst Loss: 112215.5859, KL Div: 2874.6934, Diffuse loss: 82.2623
# Epoch[50/100], Step [200/782], Reconst Loss: 107918.9844, KL Div: 2870.9595, Diffuse loss: 85.5873
# Epoch[50/100], Step [300/782], Reconst Loss: 112541.5859, KL Div: 2935.4241, Diffuse loss: 81.7208
# Epoch[50/100], Step [400/782], Reconst Loss: 113236.5000, KL Div: 2877.6729, Diffuse loss: 82.0640
# Epoch[50/100], Step [500/782], Reconst Loss: 114841.5312, KL Div: 2934.2612, Diffuse loss: 86.3902
# Epoch[50/100], Step [600/782], Reconst Loss: 110531.2969, KL Div: 2931.4238, Diffuse loss: 85.0022
# Epoch[50/100], Step [700/782], Reconst Loss: 110998.0156, KL Div: 2954.3003, Diffuse loss: 83.4936
# Epoch[51/100], Step [100/782], Reconst Loss: 110569.4375, KL Div: 2970.1079, Diffuse loss: 79.1689
# Epoch[51/100], Step [200/782], Reconst Loss: 114291.7969, KL Div: 3015.3877, Diffuse loss: 81.8008
# Epoch[51/100], Step [300/782], Reconst Loss: 113688.0312, KL Div: 2954.9790, Diffuse loss: 83.4224
# Epoch[51/100], Step [400/782], Reconst Loss: 113589.6094, KL Div: 2944.6909, Diffuse loss: 82.5658
# Epoch[51/100], Step [500/782], Reconst Loss: 115335.9688, KL Div: 2981.3301, Diffuse loss: 85.1710
# Epoch[51/100], Step [600/782], Reconst Loss: 110128.8125, KL Div: 2919.6536, Diffuse loss: 82.9107
# Epoch[51/100], Step [700/782], Reconst Loss: 110698.6016, KL Div: 2991.1599, Diffuse loss: 83.9863
# Epoch[52/100], Step [100/782], Reconst Loss: 113413.4844, KL Div: 2950.5610, Diffuse loss: 84.6353
# Epoch[52/100], Step [200/782], Reconst Loss: 112167.2188, KL Div: 2960.6523, Diffuse loss: 83.5712
# Epoch[52/100], Step [300/782], Reconst Loss: 110408.2344, KL Div: 2947.8682, Diffuse loss: 85.3117
# Epoch[52/100], Step [400/782], Reconst Loss: 112685.4531, KL Div: 2962.1357, Diffuse loss: 82.6408
# Epoch[52/100], Step [500/782], Reconst Loss: 110099.9531, KL Div: 2960.0320, Diffuse loss: 87.6352
# Epoch[52/100], Step [600/782], Reconst Loss: 117133.9766, KL Div: 3014.3281, Diffuse loss: 83.7781
# Epoch[52/100], Step [700/782], Reconst Loss: 110260.8203, KL Div: 2922.7690, Diffuse loss: 87.0305
# Epoch[53/100], Step [100/782], Reconst Loss: 112501.1406, KL Div: 2977.2258, Diffuse loss: 85.9320
# Epoch[53/100], Step [200/782], Reconst Loss: 108165.0703, KL Div: 2967.8296, Diffuse loss: 84.8081
# Epoch[53/100], Step [300/782], Reconst Loss: 115638.6094, KL Div: 3030.7983, Diffuse loss: 82.4405
# Epoch[53/100], Step [400/782], Reconst Loss: 110996.8125, KL Div: 2897.6631, Diffuse loss: 83.4277
# Epoch[53/100], Step [500/782], Reconst Loss: 113566.2031, KL Div: 2968.2554, Diffuse loss: 85.5451
# Epoch[53/100], Step [600/782], Reconst Loss: 114222.0156, KL Div: 3042.0010, Diffuse loss: 84.9829
# Epoch[53/100], Step [700/782], Reconst Loss: 116093.8125, KL Div: 2966.0122, Diffuse loss: 85.0323
# Epoch[54/100], Step [100/782], Reconst Loss: 114435.2266, KL Div: 2983.1943, Diffuse loss: 86.6189
# Epoch[54/100], Step [200/782], Reconst Loss: 114518.3203, KL Div: 3020.6340, Diffuse loss: 87.7814
# Epoch[54/100], Step [300/782], Reconst Loss: 109815.7578, KL Div: 2948.3599, Diffuse loss: 82.1335
# Epoch[54/100], Step [400/782], Reconst Loss: 112578.3516, KL Div: 2982.3359, Diffuse loss: 84.3773
# Epoch[54/100], Step [500/782], Reconst Loss: 109294.8203, KL Div: 3057.7319, Diffuse loss: 80.9968
# Epoch[54/100], Step [600/782], Reconst Loss: 110950.4531, KL Div: 2972.7402, Diffuse loss: 82.2975
# Epoch[54/100], Step [700/782], Reconst Loss: 114878.8984, KL Div: 3024.1729, Diffuse loss: 82.4715
# Epoch[55/100], Step [100/782], Reconst Loss: 114888.2734, KL Div: 2971.6094, Diffuse loss: 81.9948
# Epoch[55/100], Step [200/782], Reconst Loss: 112161.6172, KL Div: 3023.4917, Diffuse loss: 82.6675
# Epoch[55/100], Step [300/782], Reconst Loss: 111471.8516, KL Div: 3012.2419, Diffuse loss: 84.0167
# Epoch[55/100], Step [400/782], Reconst Loss: 111008.9688, KL Div: 3020.2744, Diffuse loss: 82.5173
# Epoch[55/100], Step [500/782], Reconst Loss: 112655.2109, KL Div: 2933.1396, Diffuse loss: 82.4810
# Epoch[55/100], Step [600/782], Reconst Loss: 112433.0469, KL Div: 2937.6616, Diffuse loss: 85.0412
# Epoch[55/100], Step [700/782], Reconst Loss: 108515.6641, KL Div: 2982.1055, Diffuse loss: 82.0979
# Epoch[56/100], Step [100/782], Reconst Loss: 115343.3594, KL Div: 3062.2979, Diffuse loss: 82.0136
# Epoch[56/100], Step [200/782], Reconst Loss: 112331.3906, KL Div: 3074.5654, Diffuse loss: 82.2824
# Epoch[56/100], Step [300/782], Reconst Loss: 110772.0156, KL Div: 2966.0706, Diffuse loss: 85.7118
# Epoch[56/100], Step [400/782], Reconst Loss: 112747.4531, KL Div: 2996.3872, Diffuse loss: 83.2147
# Epoch[56/100], Step [500/782], Reconst Loss: 114884.8359, KL Div: 3048.3906, Diffuse loss: 82.5911
# Epoch[56/100], Step [600/782], Reconst Loss: 111376.5625, KL Div: 3030.1809, Diffuse loss: 84.9741
# Epoch[56/100], Step [700/782], Reconst Loss: 111313.7344, KL Div: 3028.5500, Diffuse loss: 82.6948
# Epoch[57/100], Step [100/782], Reconst Loss: 115828.1875, KL Div: 3019.7754, Diffuse loss: 88.5721
# Epoch[57/100], Step [200/782], Reconst Loss: 108245.9844, KL Div: 3053.0757, Diffuse loss: 83.7743
# Epoch[57/100], Step [300/782], Reconst Loss: 111607.5469, KL Div: 3008.7720, Diffuse loss: 82.4006
# Epoch[57/100], Step [400/782], Reconst Loss: 114445.2266, KL Div: 3093.8875, Diffuse loss: 83.1764
# Epoch[57/100], Step [500/782], Reconst Loss: 113364.7344, KL Div: 3068.0420, Diffuse loss: 84.6602
# Epoch[57/100], Step [600/782], Reconst Loss: 110671.4297, KL Div: 3111.6938, Diffuse loss: 86.0248
# Epoch[57/100], Step [700/782], Reconst Loss: 111590.9375, KL Div: 3025.0303, Diffuse loss: 85.9583
# Epoch[58/100], Step [100/782], Reconst Loss: 108518.3359, KL Div: 3013.9526, Diffuse loss: 82.2077
# Epoch[58/100], Step [200/782], Reconst Loss: 113169.9766, KL Div: 3075.6904, Diffuse loss: 83.0519
# Epoch[58/100], Step [300/782], Reconst Loss: 114562.4141, KL Div: 3062.0547, Diffuse loss: 81.5398
# Epoch[58/100], Step [400/782], Reconst Loss: 112150.3828, KL Div: 3040.3257, Diffuse loss: 82.9646
# Epoch[58/100], Step [500/782], Reconst Loss: 112313.0547, KL Div: 3098.0686, Diffuse loss: 85.3370
# Epoch[58/100], Step [600/782], Reconst Loss: 111707.7969, KL Div: 3123.2871, Diffuse loss: 83.0917
# Epoch[58/100], Step [700/782], Reconst Loss: 112344.1406, KL Div: 3096.1094, Diffuse loss: 84.9916
# Epoch[59/100], Step [100/782], Reconst Loss: 111576.1875, KL Div: 3061.1196, Diffuse loss: 83.9503
# Epoch[59/100], Step [200/782], Reconst Loss: 110445.0703, KL Div: 3085.8970, Diffuse loss: 85.9371
# Epoch[59/100], Step [300/782], Reconst Loss: 113300.6875, KL Div: 3067.0134, Diffuse loss: 82.4875
# Epoch[59/100], Step [400/782], Reconst Loss: 112369.5938, KL Div: 3178.9624, Diffuse loss: 82.4784
# Epoch[59/100], Step [500/782], Reconst Loss: 110965.4453, KL Div: 3077.8975, Diffuse loss: 83.6571
# Epoch[59/100], Step [600/782], Reconst Loss: 110352.0859, KL Div: 3087.9351, Diffuse loss: 82.4059
# Epoch[59/100], Step [700/782], Reconst Loss: 111526.5547, KL Div: 3108.1675, Diffuse loss: 86.7763
# Epoch[60/100], Step [100/782], Reconst Loss: 111872.2344, KL Div: 3095.8608, Diffuse loss: 83.2391
# Epoch[60/100], Step [200/782], Reconst Loss: 112644.4609, KL Div: 3136.5815, Diffuse loss: 86.2475
# Epoch[60/100], Step [300/782], Reconst Loss: 115289.7734, KL Div: 3088.2759, Diffuse loss: 79.4608
# Epoch[60/100], Step [400/782], Reconst Loss: 105697.5547, KL Div: 3004.8105, Diffuse loss: 85.8974
# Epoch[60/100], Step [500/782], Reconst Loss: 113262.7188, KL Div: 3112.0432, Diffuse loss: 80.0323
# Epoch[60/100], Step [600/782], Reconst Loss: 113617.3750, KL Div: 3110.9980, Diffuse loss: 83.9488
# Epoch[60/100], Step [700/782], Reconst Loss: 111271.2812, KL Div: 3123.2925, Diffuse loss: 82.2366
# Epoch[61/100], Step [100/782], Reconst Loss: 113767.2344, KL Div: 3074.9751, Diffuse loss: 84.6733
# Epoch[61/100], Step [200/782], Reconst Loss: 110928.5781, KL Div: 3075.8896, Diffuse loss: 84.2902
# Epoch[61/100], Step [300/782], Reconst Loss: 111315.4219, KL Div: 3127.9233, Diffuse loss: 84.5358
# Epoch[61/100], Step [400/782], Reconst Loss: 109298.5156, KL Div: 3076.5312, Diffuse loss: 87.5973
# Epoch[61/100], Step [500/782], Reconst Loss: 111839.9688, KL Div: 3104.5347, Diffuse loss: 86.3060
# Epoch[61/100], Step [600/782], Reconst Loss: 110581.9141, KL Div: 3089.2000, Diffuse loss: 83.7179
# Epoch[61/100], Step [700/782], Reconst Loss: 113572.5859, KL Div: 3217.6367, Diffuse loss: 83.2180
# Epoch[62/100], Step [100/782], Reconst Loss: 112052.9062, KL Div: 3119.8696, Diffuse loss: 83.1444
# Epoch[62/100], Step [200/782], Reconst Loss: 112262.9922, KL Div: 3184.8638, Diffuse loss: 85.9952
# Epoch[62/100], Step [300/782], Reconst Loss: 109853.8906, KL Div: 3182.5459, Diffuse loss: 81.4181
# Epoch[62/100], Step [400/782], Reconst Loss: 113507.2344, KL Div: 3133.2427, Diffuse loss: 85.5917
# Epoch[62/100], Step [500/782], Reconst Loss: 113842.6250, KL Div: 3176.4556, Diffuse loss: 83.2894
# Epoch[62/100], Step [600/782], Reconst Loss: 110703.6406, KL Div: 3153.3657, Diffuse loss: 84.4691
# Epoch[62/100], Step [700/782], Reconst Loss: 108412.0938, KL Div: 3198.2056, Diffuse loss: 83.8789
# Epoch[63/100], Step [100/782], Reconst Loss: 114175.8750, KL Div: 3216.0940, Diffuse loss: 80.5620
# Epoch[63/100], Step [200/782], Reconst Loss: 112272.4453, KL Div: 3167.8196, Diffuse loss: 79.5498
# Epoch[63/100], Step [300/782], Reconst Loss: 115174.3203, KL Div: 3182.8916, Diffuse loss: 85.4114
# Epoch[63/100], Step [400/782], Reconst Loss: 114756.6953, KL Div: 3201.5159, Diffuse loss: 83.8780
# Epoch[63/100], Step [500/782], Reconst Loss: 110333.8594, KL Div: 3144.6416, Diffuse loss: 85.2107
# Epoch[63/100], Step [600/782], Reconst Loss: 113776.5625, KL Div: 3178.0457, Diffuse loss: 87.2026
# Epoch[63/100], Step [700/782], Reconst Loss: 109424.6562, KL Div: 3223.6118, Diffuse loss: 85.3552
# Epoch[64/100], Step [100/782], Reconst Loss: 110739.4453, KL Div: 3224.9180, Diffuse loss: 84.8653
# Epoch[64/100], Step [200/782], Reconst Loss: 112437.9375, KL Div: 3182.4150, Diffuse loss: 82.7170
# Epoch[64/100], Step [300/782], Reconst Loss: 113880.9844, KL Div: 3266.0059, Diffuse loss: 86.3195
# Epoch[64/100], Step [400/782], Reconst Loss: 112291.0312, KL Div: 3198.1484, Diffuse loss: 82.7359
# Epoch[64/100], Step [500/782], Reconst Loss: 111609.2344, KL Div: 3144.2256, Diffuse loss: 87.0011
# Epoch[64/100], Step [600/782], Reconst Loss: 112730.3203, KL Div: 3218.0134, Diffuse loss: 86.5876
# Epoch[64/100], Step [700/782], Reconst Loss: 111735.4219, KL Div: 3246.5859, Diffuse loss: 86.0172
# Epoch[65/100], Step [100/782], Reconst Loss: 114218.4688, KL Div: 3235.9373, Diffuse loss: 82.8098
# Epoch[65/100], Step [200/782], Reconst Loss: 111065.5156, KL Div: 3324.3162, Diffuse loss: 83.1836
# Epoch[65/100], Step [300/782], Reconst Loss: 109758.4531, KL Div: 3182.7729, Diffuse loss: 83.9592
# Epoch[65/100], Step [400/782], Reconst Loss: 112858.9453, KL Div: 3225.5171, Diffuse loss: 83.9370
# Epoch[65/100], Step [500/782], Reconst Loss: 111707.1797, KL Div: 3245.6201, Diffuse loss: 83.0695
# Epoch[65/100], Step [600/782], Reconst Loss: 114086.2109, KL Div: 3217.7031, Diffuse loss: 84.5429
# Epoch[65/100], Step [700/782], Reconst Loss: 115297.3438, KL Div: 3201.6899, Diffuse loss: 80.3602
# Epoch[66/100], Step [100/782], Reconst Loss: 112581.2188, KL Div: 3167.4263, Diffuse loss: 82.3789
# Epoch[66/100], Step [200/782], Reconst Loss: 113183.6016, KL Div: 3264.7798, Diffuse loss: 83.3867
# Epoch[66/100], Step [300/782], Reconst Loss: 115920.1484, KL Div: 3165.5339, Diffuse loss: 80.2704
# Epoch[66/100], Step [400/782], Reconst Loss: 112927.6562, KL Div: 3239.1729, Diffuse loss: 87.1742
# Epoch[66/100], Step [500/782], Reconst Loss: 115403.9766, KL Div: 3245.8276, Diffuse loss: 83.8874
# Epoch[66/100], Step [600/782], Reconst Loss: 111723.8750, KL Div: 3221.9482, Diffuse loss: 83.7679
# Epoch[66/100], Step [700/782], Reconst Loss: 109473.3594, KL Div: 3233.0688, Diffuse loss: 84.5311
# Epoch[67/100], Step [100/782], Reconst Loss: 112817.5234, KL Div: 3176.9609, Diffuse loss: 83.2272
# Epoch[67/100], Step [200/782], Reconst Loss: 111741.0469, KL Div: 3227.6753, Diffuse loss: 82.3067
# Epoch[67/100], Step [300/782], Reconst Loss: 115166.7031, KL Div: 3171.2251, Diffuse loss: 84.1991
# Epoch[67/100], Step [400/782], Reconst Loss: 111714.4062, KL Div: 3263.1685, Diffuse loss: 85.5300
# Epoch[67/100], Step [500/782], Reconst Loss: 114122.1016, KL Div: 3260.8379, Diffuse loss: 82.9924
# Epoch[67/100], Step [600/782], Reconst Loss: 111972.0938, KL Div: 3225.7151, Diffuse loss: 81.9926
# Epoch[67/100], Step [700/782], Reconst Loss: 108458.5547, KL Div: 3192.2910, Diffuse loss: 85.0091
# Epoch[68/100], Step [100/782], Reconst Loss: 112837.8203, KL Div: 3260.4194, Diffuse loss: 82.4550
# Epoch[68/100], Step [200/782], Reconst Loss: 111508.2031, KL Div: 3274.3887, Diffuse loss: 85.1640
# Epoch[68/100], Step [300/782], Reconst Loss: 113791.7266, KL Div: 3231.2256, Diffuse loss: 82.7259
# Epoch[68/100], Step [400/782], Reconst Loss: 111472.4922, KL Div: 3212.3276, Diffuse loss: 85.7112
# Epoch[68/100], Step [500/782], Reconst Loss: 109233.1328, KL Div: 3233.4163, Diffuse loss: 84.1556
# Epoch[68/100], Step [600/782], Reconst Loss: 109271.0859, KL Div: 3275.8354, Diffuse loss: 81.5945
# Epoch[68/100], Step [700/782], Reconst Loss: 111085.2031, KL Div: 3269.6855, Diffuse loss: 84.1491
# Epoch[69/100], Step [100/782], Reconst Loss: 113261.7109, KL Div: 3263.0859, Diffuse loss: 82.7110
# Epoch[69/100], Step [200/782], Reconst Loss: 112651.9062, KL Div: 3274.4893, Diffuse loss: 86.8433
# Epoch[69/100], Step [300/782], Reconst Loss: 114221.2656, KL Div: 3234.2827, Diffuse loss: 86.0093
# Epoch[69/100], Step [400/782], Reconst Loss: 111688.6328, KL Div: 3247.6912, Diffuse loss: 83.6346
# Epoch[69/100], Step [500/782], Reconst Loss: 110950.1719, KL Div: 3259.5925, Diffuse loss: 84.9187
# Epoch[69/100], Step [600/782], Reconst Loss: 112021.9062, KL Div: 3259.8503, Diffuse loss: 83.2747
# ...
# Epoch[78/100], Step [100/782], Reconst Loss: 112458.1094, KL Div: 3365.5264, Diffuse loss: 84.6761
# Epoch[78/100], Step [200/782], Reconst Loss: 109841.5312, KL Div: 3389.0894, Diffuse loss: 86.7959
# Epoch[78/100], Step [300/782], Reconst Loss: 113358.1953, KL Div: 3439.4922, Diffuse loss: 84.7960
# Epoch[78/100], Step [400/782], Reconst Loss: 111755.2109, KL Div: 3348.3750, Diffuse loss: 82.1641
# Epoch[78/100], Step [500/782], Reconst Loss: 112307.0312, KL Div: 3379.1323, Diffuse loss: 85.6571
# Epoch[78/100], Step [600/782], Reconst Loss: 111251.0625, KL Div: 3286.9536, Diffuse loss: 86.7943
# Epoch[78/100], Step [700/782], Reconst Loss: 111331.4062, KL Div: 3452.8223, Diffuse loss: 84.8884
# Epoch[79/100], Step [100/782], Reconst Loss: 110674.5781, KL Div: 3367.1650, Diffuse loss: 82.8712
# Epoch[79/100], Step [200/782], Reconst Loss: 108978.6406, KL Div: 3346.8311, Diffuse loss: 86.3185
# Epoch[79/100], Step [300/782], Reconst Loss: 113087.6484, KL Div: 3415.0000, Diffuse loss: 85.6067
# Epoch[79/100], Step [400/782], Reconst Loss: 113457.7891, KL Div: 3418.9292, Diffuse loss: 82.8510
# Epoch[79/100], Step [500/782], Reconst Loss: 111253.9219, KL Div: 3418.1797, Diffuse loss: 85.1477
# Epoch[79/100], Step [600/782], Reconst Loss: 110588.3594, KL Div: 3304.3840, Diffuse loss: 82.4903
# Epoch[79/100], Step [700/782], Reconst Loss: 110326.1328, KL Div: 3396.4912, Diffuse loss: 82.4080
# Epoch[80/100], Step [100/782], Reconst Loss: 111024.5469, KL Div: 3400.2344, Diffuse loss: 84.6649
# Epoch[80/100], Step [200/782], Reconst Loss: 112417.8125, KL Div: 3416.6885, Diffuse loss: 83.5412
# Epoch[80/100], Step [300/782], Reconst Loss: 110596.6953, KL Div: 3439.1484, Diffuse loss: 85.8663
# Epoch[80/100], Step [400/782], Reconst Loss: 113724.8438, KL Div: 3439.4575, Diffuse loss: 83.1070
# Epoch[80/100], Step [500/782], Reconst Loss: 116415.8438, KL Div: 3424.1587, Diffuse loss: 81.9811
# Epoch[80/100], Step [600/782], Reconst Loss: 109853.9375, KL Div: 3383.2251, Diffuse loss: 84.5847
# Epoch[80/100], Step [700/782], Reconst Loss: 110065.5391, KL Div: 3283.4028, Diffuse loss: 80.1246
# Epoch[81/100], Step [100/782], Reconst Loss: 111329.7812, KL Div: 3405.6001, Diffuse loss: 85.4599
# Epoch[81/100], Step [200/782], Reconst Loss: 111451.6719, KL Div: 3453.4180, Diffuse loss: 83.3334
# Epoch[81/100], Step [300/782], Reconst Loss: 110373.5703, KL Div: 3404.4106, Diffuse loss: 83.0626
# Epoch[81/100], Step [400/782], Reconst Loss: 109182.4922, KL Div: 3346.9478, Diffuse loss: 81.1804
# Epoch[81/100], Step [500/782], Reconst Loss: 110819.6562, KL Div: 3386.7979, Diffuse loss: 84.1946
# Epoch[81/100], Step [600/782], Reconst Loss: 111506.8125, KL Div: 3387.5146, Diffuse loss: 82.8422
# Epoch[81/100], Step [700/782], Reconst Loss: 112341.1016, KL Div: 3384.2087, Diffuse loss: 86.2518
# Epoch[82/100], Step [100/782], Reconst Loss: 112632.5000, KL Div: 3395.5776, Diffuse loss: 83.7090
# Epoch[82/100], Step [200/782], Reconst Loss: 113150.9531, KL Div: 3423.6177, Diffuse loss: 83.8384
# Epoch[82/100], Step [300/782], Reconst Loss: 113043.1953, KL Div: 3458.3931, Diffuse loss: 85.8008
# Epoch[82/100], Step [400/782], Reconst Loss: 112701.7109, KL Div: 3345.3574, Diffuse loss: 84.8706
# Epoch[82/100], Step [500/782], Reconst Loss: 115122.8984, KL Div: 3451.3962, Diffuse loss: 84.1231
# Epoch[82/100], Step [600/782], Reconst Loss: 110031.1875, KL Div: 3395.7249, Diffuse loss: 82.7863
# Epoch[82/100], Step [700/782], Reconst Loss: 112997.5938, KL Div: 3504.1270, Diffuse loss: 84.3511
# Epoch[83/100], Step [100/782], Reconst Loss: 113784.8359, KL Div: 3477.0698, Diffuse loss: 82.6960
# Epoch[83/100], Step [200/782], Reconst Loss: 110635.2188, KL Div: 3485.2146, Diffuse loss: 82.9798
# Epoch[83/100], Step [300/782], Reconst Loss: 112212.2188, KL Div: 3408.3748, Diffuse loss: 87.8865
# Epoch[83/100], Step [400/782], Reconst Loss: 110469.9453, KL Div: 3401.3206, Diffuse loss: 82.2064
# Epoch[83/100], Step [500/782], Reconst Loss: 112335.2656, KL Div: 3503.2251, Diffuse loss: 84.3718
# Epoch[83/100], Step [600/782], Reconst Loss: 113253.6719, KL Div: 3393.1665, Diffuse loss: 84.1896
# Epoch[83/100], Step [700/782], Reconst Loss: 114380.5469, KL Div: 3454.7896, Diffuse loss: 84.0832
# Epoch[84/100], Step [100/782], Reconst Loss: 113438.2891, KL Div: 3486.6318, Diffuse loss: 86.1095
# Epoch[84/100], Step [200/782], Reconst Loss: 112349.6406, KL Div: 3470.1128, Diffuse loss: 87.2303
# Epoch[84/100], Step [300/782], Reconst Loss: 111083.8594, KL Div: 3445.9075, Diffuse loss: 84.3685
# Epoch[84/100], Step [400/782], Reconst Loss: 112416.5234, KL Div: 3455.8914, Diffuse loss: 84.3399
# Epoch[84/100], Step [500/782], Reconst Loss: 112234.9219, KL Div: 3401.5547, Diffuse loss: 85.1838
# Epoch[84/100], Step [600/782], Reconst Loss: 109279.4609, KL Div: 3420.0127, Diffuse loss: 86.7995
# Epoch[84/100], Step [700/782], Reconst Loss: 111055.3750, KL Div: 3517.8604, Diffuse loss: 82.2890
# Epoch[85/100], Step [100/782], Reconst Loss: 113967.7500, KL Div: 3493.3926, Diffuse loss: 83.6177
# Epoch[85/100], Step [200/782], Reconst Loss: 109870.6562, KL Div: 3514.8040, Diffuse loss: 83.4061
# Epoch[85/100], Step [300/782], Reconst Loss: 109793.7109, KL Div: 3423.8730, Diffuse loss: 82.0692
# Epoch[85/100], Step [400/782], Reconst Loss: 110975.9219, KL Div: 3444.4951, Diffuse loss: 81.6861
# Epoch[85/100], Step [500/782], Reconst Loss: 111383.2656, KL Div: 3501.0908, Diffuse loss: 86.9104
# Epoch[85/100], Step [600/782], Reconst Loss: 112464.9844, KL Div: 3446.8042, Diffuse loss: 87.5757
# Epoch[85/100], Step [700/782], Reconst Loss: 113846.1328, KL Div: 3493.2954, Diffuse loss: 83.2666
# Epoch[86/100], Step [100/782], Reconst Loss: 115281.9922, KL Div: 3438.1484, Diffuse loss: 85.3692
# Epoch[86/100], Step [200/782], Reconst Loss: 112924.3828, KL Div: 3478.9727, Diffuse loss: 83.4204
# Epoch[86/100], Step [300/782], Reconst Loss: 114177.4219, KL Div: 3525.8638, Diffuse loss: 83.4167
# Epoch[86/100], Step [400/782], Reconst Loss: 110677.4297, KL Div: 3487.2080, Diffuse loss: 83.9475
# Epoch[86/100], Step [500/782], Reconst Loss: 114055.4297, KL Div: 3488.8486, Diffuse loss: 83.7350
# Epoch[86/100], Step [600/782], Reconst Loss: 112514.1719, KL Div: 3507.3394, Diffuse loss: 85.0578
# Epoch[86/100], Step [700/782], Reconst Loss: 114694.5938, KL Div: 3496.7100, Diffuse loss: 87.3697
# Epoch[87/100], Step [100/782], Reconst Loss: 113053.0469, KL Div: 3576.2529, Diffuse loss: 82.7687
# Epoch[87/100], Step [200/782], Reconst Loss: 111901.3672, KL Div: 3492.2544, Diffuse loss: 87.9221
# Epoch[87/100], Step [300/782], Reconst Loss: 113334.1094, KL Div: 3532.2378, Diffuse loss: 84.6853
# Epoch[87/100], Step [400/782], Reconst Loss: 114958.5469, KL Div: 3629.1470, Diffuse loss: 86.2537
# Epoch[87/100], Step [500/782], Reconst Loss: 111532.3672, KL Div: 3484.2473, Diffuse loss: 84.6601
# Epoch[87/100], Step [600/782], Reconst Loss: 109639.7344, KL Div: 3418.6931, Diffuse loss: 86.3831
# Epoch[87/100], Step [700/782], Reconst Loss: 113700.1719, KL Div: 3466.5884, Diffuse loss: 87.9262
# Epoch[88/100], Step [100/782], Reconst Loss: 111048.0938, KL Div: 3579.1470, Diffuse loss: 85.9435
# Epoch[88/100], Step [200/782], Reconst Loss: 107919.1641, KL Div: 3474.4778, Diffuse loss: 83.9718
# Epoch[88/100], Step [300/782], Reconst Loss: 112198.2500, KL Div: 3462.0640, Diffuse loss: 84.0949
# Epoch[88/100], Step [400/782], Reconst Loss: 112064.4297, KL Div: 3472.5112, Diffuse loss: 86.3170
# Epoch[88/100], Step [500/782], Reconst Loss: 114154.7578, KL Div: 3530.0820, Diffuse loss: 83.6590
# Epoch[88/100], Step [600/782], Reconst Loss: 112361.5938, KL Div: 3521.9678, Diffuse loss: 81.5919
# Epoch[88/100], Step [700/782], Reconst Loss: 113285.4922, KL Div: 3505.4116, Diffuse loss: 82.6840
# Epoch[89/100], Step [100/782], Reconst Loss: 110513.5234, KL Div: 3482.6431, Diffuse loss: 82.9222
# Epoch[89/100], Step [200/782], Reconst Loss: 111340.6797, KL Div: 3457.6204, Diffuse loss: 83.5292
# Epoch[89/100], Step [300/782], Reconst Loss: 111217.5156, KL Div: 3480.6436, Diffuse loss: 83.1423
# Epoch[89/100], Step [400/782], Reconst Loss: 112031.9375, KL Div: 3511.1343, Diffuse loss: 84.1175
# Epoch[89/100], Step [500/782], Reconst Loss: 112910.8906, KL Div: 3537.1799, Diffuse loss: 86.9050
# Epoch[89/100], Step [600/782], Reconst Loss: 113043.0469, KL Div: 3498.0244, Diffuse loss: 84.0578
# Epoch[89/100], Step [700/782], Reconst Loss: 112763.9609, KL Div: 3493.9131, Diffuse loss: 87.6312
# Epoch[90/100], Step [100/782], Reconst Loss: 112326.7656, KL Div: 3470.1621, Diffuse loss: 84.1369
# Epoch[90/100], Step [200/782], Reconst Loss: 109836.3125, KL Div: 3575.5884, Diffuse loss: 86.2712
# Epoch[90/100], Step [300/782], Reconst Loss: 112073.5391, KL Div: 3398.1592, Diffuse loss: 85.6756
# Epoch[90/100], Step [400/782], Reconst Loss: 114352.5625, KL Div: 3560.1755, Diffuse loss: 88.9774
# Epoch[90/100], Step [500/782], Reconst Loss: 107577.5781, KL Div: 3452.4131, Diffuse loss: 85.6803
# Epoch[90/100], Step [600/782], Reconst Loss: 111727.0000, KL Div: 3552.6309, Diffuse loss: 84.3963
# Epoch[90/100], Step [700/782], Reconst Loss: 112321.5625, KL Div: 3598.3027, Diffuse loss: 85.9373
# Epoch[91/100], Step [100/782], Reconst Loss: 112244.0469, KL Div: 3596.7324, Diffuse loss: 84.5120
# Epoch[91/100], Step [200/782], Reconst Loss: 111653.2656, KL Div: 3594.0566, Diffuse loss: 88.0791
# Epoch[91/100], Step [300/782], Reconst Loss: 112719.6094, KL Div: 3551.2056, Diffuse loss: 86.6144
# Epoch[91/100], Step [400/782], Reconst Loss: 111690.2578, KL Div: 3443.8354, Diffuse loss: 85.3319
# Epoch[91/100], Step [500/782], Reconst Loss: 112147.4219, KL Div: 3524.6082, Diffuse loss: 85.1809
# Epoch[91/100], Step [600/782], Reconst Loss: 112070.7344, KL Div: 3492.4849, Diffuse loss: 85.9846
# Epoch[91/100], Step [700/782], Reconst Loss: 115405.8438, KL Div: 3548.4863, Diffuse loss: 84.9903
# Epoch[92/100], Step [100/782], Reconst Loss: 113470.4766, KL Div: 3567.6548, Diffuse loss: 86.0708
# Epoch[92/100], Step [200/782], Reconst Loss: 114908.1953, KL Div: 3522.8208, Diffuse loss: 86.4689
# Epoch[92/100], Step [300/782], Reconst Loss: 108031.2500, KL Div: 3483.6025, Diffuse loss: 79.4204
# Epoch[92/100], Step [400/782], Reconst Loss: 112590.8594, KL Div: 3537.2668, Diffuse loss: 85.5465
# Epoch[92/100], Step [500/782], Reconst Loss: 111577.2656, KL Div: 3405.2671, Diffuse loss: 85.0782
# Epoch[92/100], Step [600/782], Reconst Loss: 114310.3750, KL Div: 3533.2637, Diffuse loss: 86.3165
# Epoch[92/100], Step [700/782], Reconst Loss: 109901.9609, KL Div: 3536.5884, Diffuse loss: 83.9138
# Epoch[93/100], Step [100/782], Reconst Loss: 111271.7422, KL Div: 3497.0725, Diffuse loss: 82.4045
# Epoch[93/100], Step [200/782], Reconst Loss: 108523.8125, KL Div: 3540.0132, Diffuse loss: 82.1539
# Epoch[93/100], Step [300/782], Reconst Loss: 110881.8125, KL Div: 3551.3716, Diffuse loss: 88.3701
# Epoch[93/100], Step [400/782], Reconst Loss: 110406.7031, KL Div: 3555.2861, Diffuse loss: 84.4401
# Epoch[93/100], Step [500/782], Reconst Loss: 113350.2500, KL Div: 3587.2661, Diffuse loss: 87.8927
# Epoch[93/100], Step [600/782], Reconst Loss: 109835.3125, KL Div: 3513.7991, Diffuse loss: 84.6730
# Epoch[93/100], Step [700/782], Reconst Loss: 112431.0312, KL Div: 3577.9238, Diffuse loss: 83.6956
# Epoch[94/100], Step [100/782], Reconst Loss: 111961.2734, KL Div: 3534.9624, Diffuse loss: 82.6351
# Epoch[94/100], Step [200/782], Reconst Loss: 111198.5078, KL Div: 3620.4473, Diffuse loss: 84.7769
# Epoch[94/100], Step [300/782], Reconst Loss: 109908.1641, KL Div: 3594.7939, Diffuse loss: 82.2545
# Epoch[94/100], Step [400/782], Reconst Loss: 111629.9141, KL Div: 3476.0483, Diffuse loss: 86.9892
# Epoch[94/100], Step [500/782], Reconst Loss: 107912.2656, KL Div: 3570.5513, Diffuse loss: 81.6164
# Epoch[94/100], Step [600/782], Reconst Loss: 111581.0781, KL Div: 3636.2305, Diffuse loss: 83.9374
# Epoch[94/100], Step [700/782], Reconst Loss: 112248.3125, KL Div: 3578.2969, Diffuse loss: 83.7282
# Epoch[95/100], Step [100/782], Reconst Loss: 114448.1484, KL Div: 3595.2778, Diffuse loss: 85.9140
# Epoch[95/100], Step [200/782], Reconst Loss: 110162.4219, KL Div: 3562.0278, Diffuse loss: 84.4509
# Epoch[95/100], Step [300/782], Reconst Loss: 112310.5156, KL Div: 3552.4746, Diffuse loss: 85.3112
# Epoch[95/100], Step [400/782], Reconst Loss: 110669.9844, KL Div: 3528.0769, Diffuse loss: 84.0105
# Epoch[95/100], Step [500/782], Reconst Loss: 115455.5781, KL Div: 3522.2778, Diffuse loss: 85.7360
# Epoch[95/100], Step [600/782], Reconst Loss: 112578.8828, KL Div: 3596.0757, Diffuse loss: 85.3739
# Epoch[95/100], Step [700/782], Reconst Loss: 110608.6797, KL Div: 3552.8591, Diffuse loss: 84.2261
# Epoch[96/100], Step [100/782], Reconst Loss: 112068.2188, KL Div: 3656.9653, Diffuse loss: 84.1514
# Epoch[96/100], Step [200/782], Reconst Loss: 112746.2188, KL Div: 3523.4675, Diffuse loss: 82.9900
# Epoch[96/100], Step [300/782], Reconst Loss: 111271.5469, KL Div: 3592.8752, Diffuse loss: 82.6160
# Epoch[96/100], Step [400/782], Reconst Loss: 112220.5078, KL Div: 3593.7471, Diffuse loss: 87.8104
# Epoch[96/100], Step [500/782], Reconst Loss: 113251.7812, KL Div: 3575.3223, Diffuse loss: 84.8671
# Epoch[96/100], Step [600/782], Reconst Loss: 113157.5000, KL Div: 3641.6902, Diffuse loss: 86.9683
# Epoch[96/100], Step [700/782], Reconst Loss: 114989.6641, KL Div: 3646.0732, Diffuse loss: 81.6616
# Epoch[97/100], Step [100/782], Reconst Loss: 114303.7344, KL Div: 3567.9668, Diffuse loss: 82.9052
# Epoch[97/100], Step [200/782], Reconst Loss: 112235.2578, KL Div: 3606.6145, Diffuse loss: 81.9599
# Epoch[97/100], Step [300/782], Reconst Loss: 110599.3047, KL Div: 3504.7144, Diffuse loss: 83.8619
# Epoch[97/100], Step [400/782], Reconst Loss: 113117.7812, KL Div: 3547.4351, Diffuse loss: 85.0899
# Epoch[97/100], Step [500/782], Reconst Loss: 114285.3125, KL Div: 3639.2812, Diffuse loss: 83.1717
# Epoch[97/100], Step [600/782], Reconst Loss: 115135.4766, KL Div: 3636.7896, Diffuse loss: 86.1184
# Epoch[97/100], Step [700/782], Reconst Loss: 112306.8281, KL Div: 3643.3154, Diffuse loss: 84.1237
# Epoch[98/100], Step [100/782], Reconst Loss: 112196.6797, KL Div: 3510.1377, Diffuse loss: 83.7452
# Epoch[98/100], Step [200/782], Reconst Loss: 111959.1250, KL Div: 3600.4336, Diffuse loss: 85.5915
# Epoch[98/100], Step [300/782], Reconst Loss: 112092.6094, KL Div: 3608.7361, Diffuse loss: 84.6306
# Epoch[98/100], Step [400/782], Reconst Loss: 110670.5859, KL Div: 3605.5840, Diffuse loss: 86.6566
# Epoch[98/100], Step [500/782], Reconst Loss: 110186.0469, KL Div: 3608.9316, Diffuse loss: 88.2796
# Epoch[98/100], Step [600/782], Reconst Loss: 114890.5000, KL Div: 3565.9585, Diffuse loss: 82.9737
# Epoch[98/100], Step [700/782], Reconst Loss: 114434.1562, KL Div: 3651.3530, Diffuse loss: 84.2897
# Epoch[99/100], Step [100/782], Reconst Loss: 114146.0312, KL Div: 3604.4238, Diffuse loss: 87.3916
# Epoch[99/100], Step [200/782], Reconst Loss: 110322.6562, KL Div: 3577.0562, Diffuse loss: 86.0122
# Epoch[99/100], Step [300/782], Reconst Loss: 112635.8672, KL Div: 3577.2656, Diffuse loss: 83.0422
# Epoch[99/100], Step [400/782], Reconst Loss: 108541.6641, KL Div: 3564.8691, Diffuse loss: 83.1619
# Epoch[99/100], Step [500/782], Reconst Loss: 111684.7188, KL Div: 3585.1079, Diffuse loss: 82.0833
# Epoch[99/100], Step [600/782], Reconst Loss: 113578.2266, KL Div: 3639.2012, Diffuse loss: 83.1747
# Epoch[99/100], Step [700/782], Reconst Loss: 107767.5234, KL Div: 3561.4995, Diffuse loss: 83.7634
# Epoch[100/100], Step [100/782], Reconst Loss: 112866.1094, KL Div: 3585.8945, Diffuse loss: 85.6586
# Epoch[100/100], Step [200/782], Reconst Loss: 109496.8359, KL Div: 3613.4541, Diffuse loss: 84.2991
# Epoch[100/100], Step [300/782], Reconst Loss: 113847.1094, KL Div: 3751.8296, Diffuse loss: 86.9592
# Epoch[100/100], Step [400/782], Reconst Loss: 109754.4219, KL Div: 3552.7681, Diffuse loss: 81.8634
# Epoch[100/100], Step [500/782], Reconst Loss: 110649.1406, KL Div: 3518.9585, Diffuse loss: 83.8001
# Epoch[100/100], Step [600/782], Reconst Loss: 112819.3125, KL Div: 3562.1846, Diffuse loss: 85.9335
# Epoch[100/100], Step [700/782], Reconst Loss: 109804.1094, KL Div: 3602.9517, Diffuse loss: 84.5084

# %%
if load_available:
    ckpt = torch.load(model_dir+'ckpt.pth', map_location=device)
    vae = CnnVAE(in_channels=3, latent_dim=z_dim).to(device)
    sn = SN_Model(marginal_prob_std=marginal_prob_std_fn, embed_dim=20, dim=z_dim, drop_p=0.3, num_classes=10, device=device)
    vae.load_state_dict(ckpt['vae_state'])
    sn.load_state_dict(ckpt['sn_state'])

# %%
_, (x, y) = next(enumerate(data_loader))
x = x.to(device)
y = y.to(device)

# %%
only_final = False
n_steps = 8
test_size = 4
# dynamic = AnnealedLangevinDynamic(sigma_min, sigma_max, n_steps, annealed_step, sn, device, eps=eps)
# sample = dynamic.sampling(test_size, z_dim, only_final=False)
sample = Euler_Maruyama_sampler(sn, marginal_prob_std_fn, diffusion_coeff_fn, dim=z_dim, batch_size=test_size, num_steps=500, device=device, only_final=False)
diffuse_data = vae.decode(sample).reshape(-1, test_size, 3, 32, 32)

step_size = sample.size(0)
# Out:
# /home/oem/Documents/wangxu/LSGM-demo/models/scorenetwork.py:134: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(sigma**t, device=device)

# %%
fig, axs = plt.subplots(1, step_size, figsize=(step_size * 6, 6), constrained_layout = True)
for i in range(step_size):
    diff_data = diffuse_data[i].view(-1, 3, 32, 32)
    axs[i].imshow(make_grid(diff_data, nrow=int(np.sqrt(test_size))).permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
    # plt.show()

# %%
sample_grid = make_grid(x.view(-1, 3, 32, 32), nrow=int(np.sqrt(x.shape[0])))

select_t = 0.3

plt.figure(figsize=(6,6))
plt.axis('off')
plt.imshow(sample_grid.permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
plt.show()

# %%
mu, log_var = vae.encode(x)
z = vae.reparameterize(mu, log_var)
z_ = forward_process(z, marginal_prob_std_fn, 100, device=device, end_t=select_t, only_final=True)

# %%
sample = Euler_Maruyama_sampler(sn, marginal_prob_std_fn, diffusion_coeff_fn, dim=z_dim, batch_size=z_.shape[0], num_steps=100, device=device, start_t=select_t, only_final=True, init_x=z_, y=y)

diffuse_data = vae.decode(sample)

from torchvision.utils import make_grid

sample_grid = make_grid(diffuse_data.view(-1, 3, 32, 32), nrow=int(np.sqrt(x.shape[0])))

plt.figure(figsize=(6,6))
plt.axis('off')
plt.imshow(sample_grid.permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
plt.show()

# %%
## ODE sampler

sampler = ode_sampler #@param ['Euler_Maruyama_sampler', 'pc_sampler', 'ode_sampler'] {'type': 'raw'}

## Generate samples using the specified sampler.
z_ode = sampler(sn,
            marginal_prob_std_fn,
            diffusion_coeff_fn,
            batch_size=128,
            device=device,
            z=z_,
            y=y,
            start_t=select_t)
samples = vae.decode(z_ode.float()).view(-1, 3, 32, 32)
## Sample visualization.
samples = samples.clamp(0.0, 1.0)
# %matplotlib inline
import matplotlib.pyplot as plt
sample_grid = make_grid(samples, nrow=int(np.sqrt(batch_size)))

plt.figure(figsize=(6,6))
plt.axis('off')
plt.imshow(sample_grid.permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
plt.show()
# Out:
# Number of function evaluations: 5414

# %% [markdown]
# ### The changes of one sample

# %%
recon_x, _, _, _ = vae(x[0:2])

# %%
fig, axs = plt.subplots(1, 2, figsize=(4 * 2, 2), constrained_layout = True)
axs[0].imshow(make_grid(x[0:2], nrow=2).permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
axs[1].imshow(make_grid(recon_x[0:2], nrow=2).permute(1, 2, 0).cpu(), vmin=0., vmax=1.)

# %%
mu, log_var = vae.encode(x[0:2])
z = vae.reparameterize(mu, log_var)

z_ = forward_process(z, marginal_prob_std_fn, num_steps=10, device=device, end_t=1., only_final=False)
recon_x_seq = vae.decode(z_).clamp(0.0, 1.0).reshape(-1, 2, 3, 32, 32)

# %%
fig, axs = plt.subplots(1, recon_x_seq.shape[0], figsize=(recon_x_seq.shape[0] * 6, 6), constrained_layout = True)
for i in range(recon_x_seq.shape[0]):
    diff_data = recon_x_seq[i]
    axs[i].imshow(make_grid(diff_data, nrow=2).permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
plt.title('Forward process in latent space and its reconstruction')
# Out:
# Text(0.5, 1.0, 'Forward process in latent space and its reconstruction')

# %%
z_[-1].shape
# Out:
# torch.Size([2, 128])

# %%
sample = Euler_Maruyama_sampler(sn, marginal_prob_std_fn, diffusion_coeff_fn, dim=z_dim, batch_size=2, num_steps=500, device=device, save_times=10, start_t=select_t, only_final=False, init_x=z_[-1], y=y[0:2])
# sample = Euler_Maruyama_sampler(sn, marginal_prob_std_fn, diffusion_coeff_fn, dim=z_dim, batch_size=1, num_steps=500, device=device, save_times=10, start_t=1., only_final=False)
diffuse_data = vae.decode(sample).clamp(0.0, 1.0).reshape(-1, 2, 3, 32, 32)
# Out:
# /home/oem/Documents/wangxu/LSGM-demo/models/scorenetwork.py:134: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(sigma**t, device=device)

# %%
step_size = diffuse_data.shape[0]
fig, axs = plt.subplots(1, step_size, figsize=(step_size * 6, 6), constrained_layout = True)
for i in range(step_size):
    diff_data = diffuse_data[i]
    axs[i].imshow(make_grid(diff_data, nrow=2).permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
plt.title('Reverse process in latent space and its reconstruction')
# Out:
# Text(0.5, 1.0, 'Reverse process in latent space and its reconstruction')
