# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from utils import *
from models.scorenetwork import *
from models.cnnvae import *
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from scipy.ndimage import rotate
from itertools import chain
from torchvision import transforms
from torchvision.utils import save_image, make_grid

from IPython.display import HTML
from IPython.display import clear_output

# %%
CUDA_VISIBLE_DEVICES = 0

# initialize random seed
SEED = 0
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
np.random.seed(SEED)

# cuda = True if torch.cuda.is_available() else False
# FloatTensor = torch.cuda.FloatTensor if cuda else torch.FloatTensor
# torch.set_default_tensor_type(FloatTensor)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

sample_dir = './results/CIFAR_DAE'
model_dir = './results/checkpoints/CIFAR_DAE'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# if not os.path.exists(model_dir):
#     os.makedirs(model_dir)

# %%
joint_training = True
load_available = True

z_dim = 128
num_epochs = 100
batch_size = 64
learning_rate = 0.005
kl_weight = 0.00025

eps = 1e-6
sigma_min = 0.001
sigma_max = 10
n_steps = 10
annealed_step = 100

# %%
# MNIST dataset
dataset = torchvision.datasets.CIFAR10(root='../../Data/cifar10/',
                                     train=True,
                                     transform=transforms.ToTensor(),
                                     download=True)

# Data loader
data_loader = torch.utils.data.DataLoader(dataset=dataset,
                                          batch_size=batch_size,
                                          shuffle=True)

sigma =  5.0#@param {'type':'number'}
marginal_prob_std_fn = functools.partial(marginal_prob_std, sigma=sigma)
diffusion_coeff_fn = functools.partial(diffusion_coeff, sigma=sigma)
# Out:
# Files already downloaded and verified

# %%
vae = CnnVAE(in_channels=3, latent_dim=z_dim).to(device)
vae_optimizer = torch.optim.Adam(vae.parameters(), lr=learning_rate)

# sn = SN_Model(device, n_steps, sigma_min, sigma_max, dim=z_dim, p = 0.3)
sn = SN_Model(marginal_prob_std=marginal_prob_std_fn, embed_dim=20, dim=z_dim, drop_p=0.3, device=device)
sn_optim = torch.optim.Adam(sn.parameters(), lr = 0.005)
# dynamic = AnnealedLangevinDynamic(sigma_min, sigma_max, n_steps, annealed_step, sn, device, eps=eps)

joint_optim = torch.optim.Adam(params=chain(vae.parameters(), sn.parameters()))

# Start training
for epoch in range(num_epochs):
    for i, (x, _) in enumerate(data_loader):
        x = x.to(device)
        if joint_training:
            mu, log_var = vae.encode(x)
            z = vae.reparameterize(mu, log_var)
            x_reconst = vae.decode(z)
            # Compute reconstruction loss and kl divergence
            reconst_loss = F.binary_cross_entropy(x_reconst, x, size_average=False)
            # reconst_loss = F.mse_loss(x_reconst, x)
            # reconst_loss = F.cross_entropy(x_reconst, x)
            # kl_div = - 0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
            kl_div = torch.mean(-0.5 * torch.sum(1 + log_var - mu ** 2 - log_var.exp(), dim = 1), dim = 0)
            loss_sn = sn.loss(z)
            loss = loss_sn + reconst_loss + kl_weight*kl_div

            joint_optim.zero_grad()
            loss.backward()
            joint_optim.step()
        else:
            #============= First Stage: Update VAE ==============#
            # Forward pass
            x_reconst, _, mu, log_var = vae(x)
            # Compute reconstruction loss and kl divergence
            reconst_loss = F.mse_loss(x_reconst, x)
            # kl_div = - 0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
            kl_div = torch.mean(-0.5 * torch.sum(1 + log_var - mu ** 2 - log_var.exp(), dim = 1), dim = 0)
            
            # Backprop and optimize
            vae_loss = reconst_loss + kl_div
            vae_optimizer.zero_grad()
            vae_loss.backward()
            vae_optimizer.step()

            #============= Second Stage: Update SN ==============#
            mu, log_var = vae.encode(x)
            z = vae.reparameterize(mu, log_var)

            loss_sn = sn.loss(z)
            vae_optimizer.zero_grad()
            sn_optim.zero_grad()
            loss_sn.backward()
            sn_optim.step()

        if (i+1) % 100 == 0:
            print ("Epoch[{}/{}], Step [{}/{}], Reconst Loss: {:.4f}, KL Div: {:.4f}, Diffuse loss: {:.4f}"
                   .format(epoch+1, num_epochs, i+1, len(data_loader), reconst_loss.item(), kl_div.item(), loss_sn.item()))

    with torch.no_grad():
        # Save the sampled images
        z = torch.randn(x.shape[0], z_dim).to(device)
        out = vae.decode(z)
        x_concat = torch.cat([x, out], dim=3)
        save_image(x_concat, os.path.join(sample_dir, 'sampled-{}.png'.format(epoch+1)), nrow=4)

        # Save the reconstructed images
        out, _, _, _ = vae(x)
        x_concat = torch.cat([x, out], dim=3)
        save_image(x_concat, os.path.join(sample_dir, 'reconst-{}.png'.format(epoch+1)), nrow=4)

        # Save the diffused ima ges
        # dynamic = AnnealedLangevinDynamic(sigma_min, sigma_max, n_steps, annealed_step, sn, device, eps=eps)
        # z_ = forward_proc(z, sigma_min, sigma_max, n_steps, device=device, only_final=True)
        # sample = dynamic.sampling(x.shape[0], z_dim, sample=z_, only_final=True)

        sample = Euler_Maruyama_sampler(sn, marginal_prob_std_fn, diffusion_coeff_fn, dim=z_dim, batch_size=x.shape[0], num_steps=500, device=device)

        # sample = dynamic.sampling(x.shape[0], z_dim, only_final=True)
        out = vae.decode(sample)
        x_concat = torch.cat([x, out], dim=3)
        save_image(x_concat, os.path.join(sample_dir, 'diffuse-{}.png'.format(epoch+1)), nrow=4)
torch.save({'sn_state':sn.state_dict(), 'vae_state':vae.state_dict()}, model_dir+'ckpt.pth')
# Out:
# /home/oem/anaconda3/envs/piq/lib/python3.10/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Epoch[1/100], Step [100/782], Reconst Loss: 120554.9609, KL Div: 299.7425, Diffuse loss: 107.7940
# Epoch[1/100], Step [200/782], Reconst Loss: 123003.2266, KL Div: 364.4265, Diffuse loss: 101.6006
# Epoch[1/100], Step [300/782], Reconst Loss: 116574.9375, KL Div: 429.2878, Diffuse loss: 94.7110
# Epoch[1/100], Step [400/782], Reconst Loss: 117639.1875, KL Div: 477.9545, Diffuse loss: 89.4637
# Epoch[1/100], Step [500/782], Reconst Loss: 120582.3906, KL Div: 509.9618, Diffuse loss: 92.2075
# Epoch[1/100], Step [600/782], Reconst Loss: 118829.7812, KL Div: 549.4015, Diffuse loss: 91.6486
# Epoch[1/100], Step [700/782], Reconst Loss: 116104.3281, KL Div: 574.7114, Diffuse loss: 88.3932
# /home/oem/Documents/wangxu/LSGM-demo/models/scorenetwork.py:134: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(sigma**t, device=device)
# Epoch[2/100], Step [100/782], Reconst Loss: 120468.0781, KL Div: 635.5632, Diffuse loss: 90.1091
# Epoch[2/100], Step [200/782], Reconst Loss: 116917.1875, KL Div: 671.2646, Diffuse loss: 90.8163
# Epoch[2/100], Step [300/782], Reconst Loss: 116511.8672, KL Div: 698.5016, Diffuse loss: 87.3588
# Epoch[2/100], Step [400/782], Reconst Loss: 113435.4219, KL Div: 724.0654, Diffuse loss: 85.7205
# Epoch[2/100], Step [500/782], Reconst Loss: 115068.8125, KL Div: 741.4551, Diffuse loss: 91.1879
# Epoch[2/100], Step [600/782], Reconst Loss: 116447.4844, KL Div: 776.9221, Diffuse loss: 84.2899
# Epoch[2/100], Step [700/782], Reconst Loss: 118666.5078, KL Div: 793.1935, Diffuse loss: 85.9652
# Epoch[3/100], Step [100/782], Reconst Loss: 117992.2891, KL Div: 822.2650, Diffuse loss: 85.5884
# Epoch[3/100], Step [200/782], Reconst Loss: 115730.2031, KL Div: 830.6921, Diffuse loss: 88.7287
# Epoch[3/100], Step [300/782], Reconst Loss: 115546.8281, KL Div: 835.8374, Diffuse loss: 84.7377
# Epoch[3/100], Step [400/782], Reconst Loss: 116413.6484, KL Div: 853.3558, Diffuse loss: 87.5271
# Epoch[3/100], Step [500/782], Reconst Loss: 111905.7812, KL Div: 866.8012, Diffuse loss: 82.8718
# Epoch[3/100], Step [600/782], Reconst Loss: 114976.2031, KL Div: 882.1277, Diffuse loss: 84.2908
# Epoch[3/100], Step [700/782], Reconst Loss: 115893.1406, KL Div: 902.7380, Diffuse loss: 85.1361
# Epoch[4/100], Step [100/782], Reconst Loss: 114471.9844, KL Div: 933.0828, Diffuse loss: 85.9358
# Epoch[4/100], Step [200/782], Reconst Loss: 115402.9531, KL Div: 958.1654, Diffuse loss: 83.2156
# Epoch[4/100], Step [300/782], Reconst Loss: 116386.3047, KL Div: 971.4520, Diffuse loss: 86.0929
# Epoch[4/100], Step [400/782], Reconst Loss: 115093.4531, KL Div: 990.5408, Diffuse loss: 83.1112
# Epoch[4/100], Step [500/782], Reconst Loss: 116974.7891, KL Div: 998.2343, Diffuse loss: 85.4422
# Epoch[4/100], Step [600/782], Reconst Loss: 116255.1172, KL Div: 1012.6227, Diffuse loss: 84.1482
# Epoch[4/100], Step [700/782], Reconst Loss: 116460.3750, KL Div: 1033.4431, Diffuse loss: 83.8460
# Epoch[5/100], Step [100/782], Reconst Loss: 115785.6172, KL Div: 1049.2554, Diffuse loss: 83.5082
# Epoch[5/100], Step [200/782], Reconst Loss: 115672.4062, KL Div: 1065.5847, Diffuse loss: 84.8522
# Epoch[5/100], Step [300/782], Reconst Loss: 114898.2266, KL Div: 1076.7963, Diffuse loss: 84.7846
# Epoch[5/100], Step [400/782], Reconst Loss: 111387.2188, KL Div: 1101.3318, Diffuse loss: 82.9493
# Epoch[5/100], Step [500/782], Reconst Loss: 114722.1172, KL Div: 1111.8325, Diffuse loss: 87.0361
# Epoch[5/100], Step [600/782], Reconst Loss: 116912.7422, KL Div: 1109.0723, Diffuse loss: 83.8200
# Epoch[5/100], Step [700/782], Reconst Loss: 114731.0078, KL Div: 1124.5605, Diffuse loss: 81.0516
# Epoch[6/100], Step [100/782], Reconst Loss: 115667.5156, KL Div: 1136.7095, Diffuse loss: 81.9376
# Epoch[6/100], Step [200/782], Reconst Loss: 113038.5000, KL Div: 1159.7153, Diffuse loss: 87.3779
# Epoch[6/100], Step [300/782], Reconst Loss: 112735.7188, KL Div: 1169.9717, Diffuse loss: 84.7412
# Epoch[6/100], Step [400/782], Reconst Loss: 112203.9531, KL Div: 1177.7000, Diffuse loss: 83.3158
# Epoch[6/100], Step [500/782], Reconst Loss: 114335.3203, KL Div: 1192.5466, Diffuse loss: 83.6434
# Epoch[6/100], Step [600/782], Reconst Loss: 113075.0859, KL Div: 1199.4607, Diffuse loss: 82.2347
# Epoch[6/100], Step [700/782], Reconst Loss: 114716.1406, KL Div: 1195.4286, Diffuse loss: 84.8793
# Epoch[7/100], Step [100/782], Reconst Loss: 115146.5469, KL Div: 1226.7930, Diffuse loss: 83.5794
# Epoch[7/100], Step [200/782], Reconst Loss: 113452.0234, KL Div: 1217.4779, Diffuse loss: 86.2293
# Epoch[7/100], Step [300/782], Reconst Loss: 115614.4062, KL Div: 1226.1259, Diffuse loss: 80.5905
# Epoch[7/100], Step [400/782], Reconst Loss: 114088.2656, KL Div: 1251.4548, Diffuse loss: 83.3830
# Epoch[7/100], Step [500/782], Reconst Loss: 114051.9141, KL Div: 1253.7021, Diffuse loss: 80.7034
# Epoch[7/100], Step [600/782], Reconst Loss: 113694.2500, KL Div: 1257.2734, Diffuse loss: 82.7805
# Epoch[7/100], Step [700/782], Reconst Loss: 110867.5156, KL Div: 1280.9674, Diffuse loss: 81.7271
# Epoch[8/100], Step [100/782], Reconst Loss: 115510.8281, KL Div: 1296.5099, Diffuse loss: 82.2999
# Epoch[8/100], Step [200/782], Reconst Loss: 114806.9609, KL Div: 1289.6306, Diffuse loss: 76.9896
# Epoch[8/100], Step [300/782], Reconst Loss: 114948.1562, KL Div: 1316.8682, Diffuse loss: 80.4392
# Epoch[8/100], Step [400/782], Reconst Loss: 110493.8281, KL Div: 1320.1445, Diffuse loss: 79.8975
# Epoch[8/100], Step [500/782], Reconst Loss: 111660.3438, KL Div: 1345.3840, Diffuse loss: 77.1075
# Epoch[8/100], Step [600/782], Reconst Loss: 115606.5938, KL Div: 1354.8147, Diffuse loss: 86.6381
# Epoch[8/100], Step [700/782], Reconst Loss: 111882.7422, KL Div: 1358.9591, Diffuse loss: 79.6169
# Epoch[9/100], Step [100/782], Reconst Loss: 116416.8281, KL Div: 1385.3843, Diffuse loss: 84.7901
# Epoch[9/100], Step [200/782], Reconst Loss: 115172.8438, KL Div: 1380.7213, Diffuse loss: 84.4866
# Epoch[9/100], Step [300/782], Reconst Loss: 114044.7734, KL Div: 1360.7263, Diffuse loss: 82.0908
# Epoch[9/100], Step [400/782], Reconst Loss: 113755.3828, KL Div: 1411.2217, Diffuse loss: 77.1294
# Epoch[9/100], Step [500/782], Reconst Loss: 114147.2656, KL Div: 1398.3140, Diffuse loss: 81.9151
# Epoch[9/100], Step [600/782], Reconst Loss: 113813.7344, KL Div: 1416.5259, Diffuse loss: 81.0109
# Epoch[9/100], Step [700/782], Reconst Loss: 112539.8125, KL Div: 1423.2209, Diffuse loss: 81.9701
# Epoch[10/100], Step [100/782], Reconst Loss: 111657.4688, KL Div: 1443.9573, Diffuse loss: 78.9782
# Epoch[10/100], Step [200/782], Reconst Loss: 115605.0156, KL Div: 1449.8563, Diffuse loss: 80.2329
# Epoch[10/100], Step [300/782], Reconst Loss: 115308.8594, KL Div: 1461.3906, Diffuse loss: 82.9362
# Epoch[10/100], Step [400/782], Reconst Loss: 110431.5156, KL Div: 1462.7244, Diffuse loss: 79.3066
# Epoch[10/100], Step [500/782], Reconst Loss: 111211.7344, KL Div: 1478.2581, Diffuse loss: 81.8999
# Epoch[10/100], Step [600/782], Reconst Loss: 116600.0234, KL Div: 1503.3809, Diffuse loss: 79.9285
# Epoch[10/100], Step [700/782], Reconst Loss: 115870.6250, KL Div: 1486.5494, Diffuse loss: 81.9881
# Epoch[11/100], Step [100/782], Reconst Loss: 112629.1250, KL Div: 1496.0983, Diffuse loss: 77.5720
# Epoch[11/100], Step [200/782], Reconst Loss: 114196.3750, KL Div: 1508.7537, Diffuse loss: 81.5320
# Epoch[11/100], Step [300/782], Reconst Loss: 116686.5156, KL Div: 1495.5544, Diffuse loss: 83.1096
# Epoch[11/100], Step [400/782], Reconst Loss: 113419.6797, KL Div: 1509.8243, Diffuse loss: 84.2107
# Epoch[11/100], Step [500/782], Reconst Loss: 115004.8750, KL Div: 1520.5012, Diffuse loss: 83.4923
# Epoch[11/100], Step [600/782], Reconst Loss: 111377.0469, KL Div: 1536.2280, Diffuse loss: 80.4598
# Epoch[11/100], Step [700/782], Reconst Loss: 113187.8906, KL Div: 1536.1404, Diffuse loss: 85.9655
# Epoch[12/100], Step [100/782], Reconst Loss: 113559.4141, KL Div: 1571.1882, Diffuse loss: 79.7102
# Epoch[12/100], Step [200/782], Reconst Loss: 110445.4062, KL Div: 1571.2358, Diffuse loss: 81.2781
# Epoch[12/100], Step [300/782], Reconst Loss: 112726.6562, KL Div: 1561.7327, Diffuse loss: 84.0232
# Epoch[12/100], Step [400/782], Reconst Loss: 108663.1875, KL Div: 1544.0302, Diffuse loss: 83.5414
# Epoch[12/100], Step [500/782], Reconst Loss: 112045.7812, KL Div: 1553.5042, Diffuse loss: 81.4021
# Epoch[12/100], Step [600/782], Reconst Loss: 111786.8516, KL Div: 1575.3090, Diffuse loss: 78.1059
# Epoch[12/100], Step [700/782], Reconst Loss: 116367.8203, KL Div: 1581.2314, Diffuse loss: 80.9208
# Epoch[13/100], Step [100/782], Reconst Loss: 111020.3750, KL Div: 1581.5844, Diffuse loss: 81.3001
# Epoch[13/100], Step [200/782], Reconst Loss: 110503.1562, KL Div: 1587.3228, Diffuse loss: 81.7698
# Epoch[13/100], Step [300/782], Reconst Loss: 114987.2344, KL Div: 1607.3044, Diffuse loss: 79.0688
# Epoch[13/100], Step [400/782], Reconst Loss: 116990.8828, KL Div: 1629.9622, Diffuse loss: 80.1095
# Epoch[13/100], Step [500/782], Reconst Loss: 112653.6406, KL Div: 1602.5629, Diffuse loss: 82.0941
# Epoch[13/100], Step [600/782], Reconst Loss: 113277.4844, KL Div: 1615.1614, Diffuse loss: 83.0799
# Epoch[13/100], Step [700/782], Reconst Loss: 113889.5938, KL Div: 1621.4778, Diffuse loss: 84.5503
# Epoch[14/100], Step [100/782], Reconst Loss: 110292.4688, KL Div: 1654.4517, Diffuse loss: 81.2218
# Epoch[14/100], Step [200/782], Reconst Loss: 111980.8516, KL Div: 1643.1199, Diffuse loss: 81.6570
# Epoch[14/100], Step [300/782], Reconst Loss: 112973.3906, KL Div: 1682.3990, Diffuse loss: 80.8988
# Epoch[14/100], Step [400/782], Reconst Loss: 114176.1797, KL Div: 1661.0759, Diffuse loss: 77.6269
# Epoch[14/100], Step [500/782], Reconst Loss: 113559.8672, KL Div: 1657.4250, Diffuse loss: 78.6173
# Epoch[14/100], Step [600/782], Reconst Loss: 112171.7578, KL Div: 1680.4181, Diffuse loss: 79.0843
# Epoch[14/100], Step [700/782], Reconst Loss: 115318.1562, KL Div: 1692.6570, Diffuse loss: 82.3670
# Epoch[15/100], Step [100/782], Reconst Loss: 111746.4766, KL Div: 1681.2334, Diffuse loss: 81.9410
# Epoch[15/100], Step [200/782], Reconst Loss: 112520.7266, KL Div: 1696.0961, Diffuse loss: 77.5353
# Epoch[15/100], Step [300/782], Reconst Loss: 112898.7266, KL Div: 1695.7704, Diffuse loss: 79.7709
# Epoch[15/100], Step [400/782], Reconst Loss: 112778.7812, KL Div: 1733.0077, Diffuse loss: 78.8045
# Epoch[15/100], Step [500/782], Reconst Loss: 114135.8906, KL Div: 1737.5134, Diffuse loss: 80.9891
# Epoch[15/100], Step [600/782], Reconst Loss: 112326.5781, KL Div: 1745.9071, Diffuse loss: 83.0463
# Epoch[15/100], Step [700/782], Reconst Loss: 116471.6016, KL Div: 1718.4318, Diffuse loss: 82.8087
# Epoch[16/100], Step [100/782], Reconst Loss: 113351.5312, KL Div: 1762.6927, Diffuse loss: 81.7258
# Epoch[16/100], Step [200/782], Reconst Loss: 111651.5547, KL Div: 1703.0952, Diffuse loss: 81.6799
# Epoch[16/100], Step [300/782], Reconst Loss: 114446.5938, KL Div: 1736.5059, Diffuse loss: 76.8949
# Epoch[16/100], Step [400/782], Reconst Loss: 116346.6562, KL Div: 1728.6207, Diffuse loss: 81.7901
# Epoch[16/100], Step [500/782], Reconst Loss: 111393.8047, KL Div: 1758.7955, Diffuse loss: 82.9557
# Epoch[16/100], Step [600/782], Reconst Loss: 111904.9453, KL Div: 1764.8723, Diffuse loss: 84.4095
# Epoch[16/100], Step [700/782], Reconst Loss: 114951.3984, KL Div: 1771.4635, Diffuse loss: 81.5343
# Epoch[17/100], Step [100/782], Reconst Loss: 106870.8672, KL Div: 1767.5719, Diffuse loss: 80.7327
# Epoch[17/100], Step [200/782], Reconst Loss: 110260.9375, KL Div: 1762.0354, Diffuse loss: 81.4446
# Epoch[17/100], Step [300/782], Reconst Loss: 111617.5469, KL Div: 1769.1167, Diffuse loss: 81.5213
# Epoch[17/100], Step [400/782], Reconst Loss: 113070.3281, KL Div: 1774.9475, Diffuse loss: 76.7252
# Epoch[17/100], Step [500/782], Reconst Loss: 113059.1875, KL Div: 1798.3615, Diffuse loss: 80.4626
# Epoch[17/100], Step [600/782], Reconst Loss: 113928.7266, KL Div: 1778.5564, Diffuse loss: 82.6396
# Epoch[17/100], Step [700/782], Reconst Loss: 113593.1172, KL Div: 1829.8452, Diffuse loss: 81.7282
# Epoch[18/100], Step [100/782], Reconst Loss: 115086.6875, KL Div: 1816.7990, Diffuse loss: 78.6513
# Epoch[18/100], Step [200/782], Reconst Loss: 112770.9062, KL Div: 1804.8961, Diffuse loss: 78.5654
# Epoch[18/100], Step [300/782], Reconst Loss: 115634.9531, KL Div: 1843.9517, Diffuse loss: 87.3478
# Epoch[18/100], Step [400/782], Reconst Loss: 113680.0625, KL Div: 1834.7175, Diffuse loss: 81.0906
# Epoch[18/100], Step [500/782], Reconst Loss: 112471.5547, KL Div: 1808.7520, Diffuse loss: 81.7845
# Epoch[18/100], Step [600/782], Reconst Loss: 111429.7344, KL Div: 1828.4048, Diffuse loss: 82.1853
# Epoch[18/100], Step [700/782], Reconst Loss: 114765.5234, KL Div: 1856.4377, Diffuse loss: 77.6176
# Epoch[19/100], Step [100/782], Reconst Loss: 112344.6875, KL Div: 1888.7961, Diffuse loss: 78.6649
# Epoch[19/100], Step [200/782], Reconst Loss: 113722.8516, KL Div: 1877.2405, Diffuse loss: 78.4760
# Epoch[19/100], Step [300/782], Reconst Loss: 112474.5391, KL Div: 1873.7638, Diffuse loss: 81.5011
# Epoch[19/100], Step [400/782], Reconst Loss: 115244.3438, KL Div: 1868.6292, Diffuse loss: 79.3020
# Epoch[19/100], Step [500/782], Reconst Loss: 113030.0469, KL Div: 1865.0059, Diffuse loss: 81.0945
# Epoch[19/100], Step [600/782], Reconst Loss: 112326.3672, KL Div: 1874.4979, Diffuse loss: 79.4797
# Epoch[19/100], Step [700/782], Reconst Loss: 114466.0078, KL Div: 1929.9751, Diffuse loss: 84.8579
# Epoch[20/100], Step [100/782], Reconst Loss: 112919.4062, KL Div: 1947.0651, Diffuse loss: 83.7049
# Epoch[20/100], Step [200/782], Reconst Loss: 117076.3281, KL Div: 1938.9203, Diffuse loss: 85.0257
# Epoch[20/100], Step [300/782], Reconst Loss: 111790.9297, KL Div: 1918.5713, Diffuse loss: 82.1942
# Epoch[20/100], Step [400/782], Reconst Loss: 110827.4453, KL Div: 1916.5190, Diffuse loss: 82.7394
# Epoch[20/100], Step [500/782], Reconst Loss: 111669.1641, KL Div: 1916.7926, Diffuse loss: 81.4363
# Epoch[20/100], Step [600/782], Reconst Loss: 110099.5625, KL Div: 1954.5226, Diffuse loss: 83.6388
# Epoch[20/100], Step [700/782], Reconst Loss: 112460.5938, KL Div: 1909.6975, Diffuse loss: 85.1062
# Epoch[21/100], Step [100/782], Reconst Loss: 114825.8594, KL Div: 1911.2524, Diffuse loss: 80.3012
# Epoch[21/100], Step [200/782], Reconst Loss: 109120.6562, KL Div: 1964.2570, Diffuse loss: 78.7644
# Epoch[21/100], Step [300/782], Reconst Loss: 113474.3125, KL Div: 1951.5525, Diffuse loss: 79.7538
# Epoch[21/100], Step [400/782], Reconst Loss: 113466.2188, KL Div: 1952.6733, Diffuse loss: 82.4285
# Epoch[21/100], Step [500/782], Reconst Loss: 111703.0547, KL Div: 1947.6777, Diffuse loss: 87.5866
# Epoch[21/100], Step [600/782], Reconst Loss: 111238.4375, KL Div: 1911.7036, Diffuse loss: 81.4490
# Epoch[21/100], Step [700/782], Reconst Loss: 113549.6250, KL Div: 1962.5681, Diffuse loss: 82.5986
# Epoch[22/100], Step [100/782], Reconst Loss: 114547.5781, KL Div: 1985.7697, Diffuse loss: 79.5249
# Epoch[22/100], Step [200/782], Reconst Loss: 113766.5781, KL Div: 1962.1919, Diffuse loss: 83.2103
# Epoch[22/100], Step [300/782], Reconst Loss: 111993.5391, KL Div: 1964.0779, Diffuse loss: 85.5820
# Epoch[22/100], Step [400/782], Reconst Loss: 110337.2031, KL Div: 1986.9763, Diffuse loss: 81.6862
# Epoch[22/100], Step [500/782], Reconst Loss: 116230.4219, KL Div: 1976.1992, Diffuse loss: 83.3307
# Epoch[22/100], Step [600/782], Reconst Loss: 114055.2188, KL Div: 2019.6085, Diffuse loss: 82.9421
# Epoch[22/100], Step [700/782], Reconst Loss: 113811.5469, KL Div: 2002.5569, Diffuse loss: 82.6110
# Epoch[23/100], Step [100/782], Reconst Loss: 111706.6562, KL Div: 2018.4836, Diffuse loss: 85.9055
# Epoch[23/100], Step [200/782], Reconst Loss: 114522.1562, KL Div: 2074.6445, Diffuse loss: 79.3349
# Epoch[23/100], Step [300/782], Reconst Loss: 114250.9844, KL Div: 1995.0143, Diffuse loss: 80.8019
# Epoch[23/100], Step [400/782], Reconst Loss: 112284.2812, KL Div: 2002.3981, Diffuse loss: 82.3396
# Epoch[23/100], Step [500/782], Reconst Loss: 112256.0625, KL Div: 2045.6716, Diffuse loss: 81.8447
# Epoch[23/100], Step [600/782], Reconst Loss: 113161.4375, KL Div: 2056.7544, Diffuse loss: 83.3203
# Epoch[23/100], Step [700/782], Reconst Loss: 113131.8281, KL Div: 2036.6260, Diffuse loss: 78.2386
# Epoch[24/100], Step [100/782], Reconst Loss: 112843.9062, KL Div: 2015.5984, Diffuse loss: 84.8932
# Epoch[24/100], Step [200/782], Reconst Loss: 117264.2969, KL Div: 2054.8533, Diffuse loss: 82.5270
# Epoch[24/100], Step [300/782], Reconst Loss: 115134.1484, KL Div: 2071.6982, Diffuse loss: 83.0584
# Epoch[24/100], Step [400/782], Reconst Loss: 108629.0938, KL Div: 2053.5732, Diffuse loss: 80.9517
# Epoch[24/100], Step [500/782], Reconst Loss: 112707.3125, KL Div: 2066.8875, Diffuse loss: 79.3328
# Epoch[24/100], Step [600/782], Reconst Loss: 111123.9688, KL Div: 2053.3645, Diffuse loss: 80.7449
# Epoch[24/100], Step [700/782], Reconst Loss: 115397.5391, KL Div: 2061.6567, Diffuse loss: 84.5105
# Epoch[25/100], Step [100/782], Reconst Loss: 115339.1719, KL Div: 2053.7349, Diffuse loss: 81.5420
# Epoch[25/100], Step [200/782], Reconst Loss: 115091.7656, KL Div: 2106.1099, Diffuse loss: 83.9083
# Epoch[25/100], Step [300/782], Reconst Loss: 110552.5469, KL Div: 2079.3367, Diffuse loss: 81.0789
# Epoch[25/100], Step [400/782], Reconst Loss: 113367.8125, KL Div: 2095.3589, Diffuse loss: 82.8997
# Epoch[25/100], Step [500/782], Reconst Loss: 111213.9062, KL Div: 2106.2695, Diffuse loss: 81.4425
# Epoch[25/100], Step [600/782], Reconst Loss: 111086.7656, KL Div: 2111.9512, Diffuse loss: 82.2365
# Epoch[25/100], Step [700/782], Reconst Loss: 114919.7656, KL Div: 2104.1016, Diffuse loss: 83.1483
# Epoch[26/100], Step [100/782], Reconst Loss: 109716.9297, KL Div: 2102.7266, Diffuse loss: 84.2471
# Epoch[26/100], Step [200/782], Reconst Loss: 115703.7656, KL Div: 2102.5408, Diffuse loss: 81.9122
# Epoch[26/100], Step [300/782], Reconst Loss: 112180.0938, KL Div: 2135.7090, Diffuse loss: 81.0012
# Epoch[26/100], Step [400/782], Reconst Loss: 111457.3750, KL Div: 2141.7236, Diffuse loss: 83.0405
# Epoch[26/100], Step [500/782], Reconst Loss: 111642.4531, KL Div: 2100.7188, Diffuse loss: 82.8074
# Epoch[26/100], Step [600/782], Reconst Loss: 113103.6250, KL Div: 2114.6641, Diffuse loss: 81.7710
# Epoch[26/100], Step [700/782], Reconst Loss: 112916.4141, KL Div: 2129.2598, Diffuse loss: 83.5470
# Epoch[27/100], Step [100/782], Reconst Loss: 113620.0391, KL Div: 2144.9280, Diffuse loss: 81.1816
# Epoch[27/100], Step [200/782], Reconst Loss: 112949.1250, KL Div: 2182.4622, Diffuse loss: 82.3409
# Epoch[27/100], Step [300/782], Reconst Loss: 110677.5469, KL Div: 2143.1392, Diffuse loss: 82.6306
# Epoch[27/100], Step [400/782], Reconst Loss: 113451.7500, KL Div: 2202.8127, Diffuse loss: 82.6834
# Epoch[27/100], Step [500/782], Reconst Loss: 111371.5078, KL Div: 2149.6606, Diffuse loss: 80.0253
# Epoch[27/100], Step [600/782], Reconst Loss: 113998.0469, KL Div: 2204.6057, Diffuse loss: 80.9526
# Epoch[27/100], Step [700/782], Reconst Loss: 112275.9375, KL Div: 2193.5225, Diffuse loss: 80.7637
# Epoch[28/100], Step [100/782], Reconst Loss: 112378.7109, KL Div: 2191.9312, Diffuse loss: 81.8414
# Epoch[28/100], Step [200/782], Reconst Loss: 109885.8438, KL Div: 2171.5544, Diffuse loss: 81.3122
# Epoch[28/100], Step [300/782], Reconst Loss: 108226.4375, KL Div: 2155.2373, Diffuse loss: 82.7013
# Epoch[28/100], Step [400/782], Reconst Loss: 114250.7031, KL Div: 2208.2070, Diffuse loss: 81.3376
# Epoch[28/100], Step [500/782], Reconst Loss: 110402.9375, KL Div: 2199.7700, Diffuse loss: 80.5260
# Epoch[28/100], Step [600/782], Reconst Loss: 113902.6562, KL Div: 2192.3184, Diffuse loss: 80.0934
# Epoch[28/100], Step [700/782], Reconst Loss: 111362.8203, KL Div: 2219.4873, Diffuse loss: 81.8313
# Epoch[29/100], Step [100/782], Reconst Loss: 110644.4219, KL Div: 2202.9375, Diffuse loss: 84.1890
# Epoch[29/100], Step [200/782], Reconst Loss: 115299.3750, KL Div: 2235.2400, Diffuse loss: 84.7754
# Epoch[29/100], Step [300/782], Reconst Loss: 115798.6250, KL Div: 2241.3083, Diffuse loss: 81.6375
# Epoch[29/100], Step [400/782], Reconst Loss: 112870.0469, KL Div: 2199.4199, Diffuse loss: 86.4006
# Epoch[29/100], Step [500/782], Reconst Loss: 110846.2969, KL Div: 2193.2429, Diffuse loss: 85.5700
# Epoch[29/100], Step [600/782], Reconst Loss: 115850.4531, KL Div: 2210.8472, Diffuse loss: 84.8570
# Epoch[29/100], Step [700/782], Reconst Loss: 111214.1406, KL Div: 2223.7930, Diffuse loss: 85.3184
# Epoch[30/100], Step [100/782], Reconst Loss: 114449.9844, KL Div: 2225.5837, Diffuse loss: 85.3448
# Epoch[30/100], Step [200/782], Reconst Loss: 113344.2344, KL Div: 2265.0747, Diffuse loss: 84.0008
# Epoch[30/100], Step [300/782], Reconst Loss: 110655.5312, KL Div: 2290.7417, Diffuse loss: 86.5322
# Epoch[30/100], Step [400/782], Reconst Loss: 112238.8125, KL Div: 2254.0288, Diffuse loss: 81.5796
# Epoch[30/100], Step [500/782], Reconst Loss: 115259.6719, KL Div: 2274.0037, Diffuse loss: 81.5907
# Epoch[30/100], Step [600/782], Reconst Loss: 113340.3359, KL Div: 2296.4026, Diffuse loss: 80.8698
# Epoch[30/100], Step [700/782], Reconst Loss: 113986.6406, KL Div: 2336.0071, Diffuse loss: 80.3197
# Epoch[31/100], Step [100/782], Reconst Loss: 111868.0625, KL Div: 2279.6313, Diffuse loss: 84.6021
# Epoch[31/100], Step [200/782], Reconst Loss: 112252.5938, KL Div: 2308.5830, Diffuse loss: 85.3439
# Epoch[31/100], Step [300/782], Reconst Loss: 110653.8281, KL Div: 2287.8579, Diffuse loss: 83.4374
# Epoch[31/100], Step [400/782], Reconst Loss: 112257.9688, KL Div: 2303.3284, Diffuse loss: 85.4070
# Epoch[31/100], Step [500/782], Reconst Loss: 114209.1562, KL Div: 2272.7012, Diffuse loss: 81.3517
# Epoch[31/100], Step [600/782], Reconst Loss: 111296.1875, KL Div: 2284.8228, Diffuse loss: 83.3264
# Epoch[31/100], Step [700/782], Reconst Loss: 114058.7031, KL Div: 2316.2290, Diffuse loss: 82.1237
# Epoch[32/100], Step [100/782], Reconst Loss: 112068.7188, KL Div: 2331.2124, Diffuse loss: 82.5280
# Epoch[32/100], Step [200/782], Reconst Loss: 114300.7734, KL Div: 2356.9976, Diffuse loss: 82.7949
# Epoch[32/100], Step [300/782], Reconst Loss: 112841.9688, KL Div: 2300.9316, Diffuse loss: 84.0020
# Epoch[32/100], Step [400/782], Reconst Loss: 113856.2266, KL Div: 2347.3809, Diffuse loss: 83.6932
# Epoch[32/100], Step [500/782], Reconst Loss: 114998.5469, KL Div: 2325.2690, Diffuse loss: 80.9950
# Epoch[32/100], Step [600/782], Reconst Loss: 111179.8125, KL Div: 2334.5981, Diffuse loss: 85.7077
# Epoch[32/100], Step [700/782], Reconst Loss: 113112.7969, KL Div: 2348.7053, Diffuse loss: 79.6237
# Epoch[33/100], Step [100/782], Reconst Loss: 113477.5469, KL Div: 2341.4512, Diffuse loss: 80.7636
# Epoch[33/100], Step [200/782], Reconst Loss: 108369.0469, KL Div: 2383.9526, Diffuse loss: 86.2098
# Epoch[33/100], Step [300/782], Reconst Loss: 108940.2969, KL Div: 2400.4888, Diffuse loss: 87.0283
# Epoch[33/100], Step [400/782], Reconst Loss: 111196.7031, KL Div: 2357.2566, Diffuse loss: 84.5175
# Epoch[33/100], Step [500/782], Reconst Loss: 111951.7188, KL Div: 2315.6802, Diffuse loss: 81.5205
# Epoch[33/100], Step [600/782], Reconst Loss: 113593.3906, KL Div: 2382.1387, Diffuse loss: 83.5250
# Epoch[33/100], Step [700/782], Reconst Loss: 114650.3438, KL Div: 2389.6360, Diffuse loss: 81.3697
# Epoch[34/100], Step [100/782], Reconst Loss: 113655.2109, KL Div: 2378.1216, Diffuse loss: 80.9865
# Epoch[34/100], Step [200/782], Reconst Loss: 112173.3438, KL Div: 2352.2383, Diffuse loss: 85.0493
# Epoch[34/100], Step [300/782], Reconst Loss: 112929.4531, KL Div: 2403.2695, Diffuse loss: 88.6494
# Epoch[34/100], Step [400/782], Reconst Loss: 115925.6562, KL Div: 2401.9912, Diffuse loss: 85.0009
# Epoch[34/100], Step [500/782], Reconst Loss: 112085.8281, KL Div: 2377.0444, Diffuse loss: 83.0839
# Epoch[34/100], Step [600/782], Reconst Loss: 112533.3906, KL Div: 2428.8706, Diffuse loss: 84.5104
# Epoch[34/100], Step [700/782], Reconst Loss: 115466.4297, KL Div: 2446.7334, Diffuse loss: 81.4519
# Epoch[35/100], Step [100/782], Reconst Loss: 116390.6797, KL Div: 2473.9072, Diffuse loss: 83.5236
# Epoch[35/100], Step [200/782], Reconst Loss: 113780.4844, KL Div: 2457.0769, Diffuse loss: 85.5872
# Epoch[35/100], Step [300/782], Reconst Loss: 113903.9531, KL Div: 2447.6724, Diffuse loss: 84.1366
# Epoch[35/100], Step [400/782], Reconst Loss: 111870.4922, KL Div: 2460.5369, Diffuse loss: 83.0243
# Epoch[35/100], Step [500/782], Reconst Loss: 111110.7344, KL Div: 2438.0532, Diffuse loss: 83.8192
# Epoch[35/100], Step [600/782], Reconst Loss: 111498.1250, KL Div: 2404.6133, Diffuse loss: 81.2841
# Epoch[35/100], Step [700/782], Reconst Loss: 113578.6953, KL Div: 2488.6350, Diffuse loss: 82.0826
# Epoch[36/100], Step [100/782], Reconst Loss: 113545.0312, KL Div: 2505.3423, Diffuse loss: 81.3809
# Epoch[36/100], Step [200/782], Reconst Loss: 114197.3750, KL Div: 2457.3735, Diffuse loss: 86.2945
# Epoch[36/100], Step [300/782], Reconst Loss: 108105.0938, KL Div: 2432.6147, Diffuse loss: 82.7633
# Epoch[36/100], Step [400/782], Reconst Loss: 113135.0469, KL Div: 2487.1511, Diffuse loss: 81.5109
# Epoch[36/100], Step [500/782], Reconst Loss: 111900.6328, KL Div: 2488.7239, Diffuse loss: 80.8748
# Epoch[36/100], Step [600/782], Reconst Loss: 110500.6875, KL Div: 2474.5972, Diffuse loss: 81.2621
# Epoch[36/100], Step [700/782], Reconst Loss: 111408.2109, KL Div: 2437.1194, Diffuse loss: 80.8860
# Epoch[37/100], Step [100/782], Reconst Loss: 112402.7031, KL Div: 2491.2534, Diffuse loss: 81.9356
# Epoch[37/100], Step [200/782], Reconst Loss: 108477.3672, KL Div: 2477.3337, Diffuse loss: 81.4081
# Epoch[37/100], Step [300/782], Reconst Loss: 112578.2109, KL Div: 2469.9133, Diffuse loss: 84.6535
# Epoch[37/100], Step [400/782], Reconst Loss: 114619.7969, KL Div: 2481.2998, Diffuse loss: 81.0382
# Epoch[37/100], Step [500/782], Reconst Loss: 113546.1719, KL Div: 2543.0342, Diffuse loss: 84.5880
# Epoch[37/100], Step [600/782], Reconst Loss: 113821.0938, KL Div: 2506.3203, Diffuse loss: 86.0346
# Epoch[37/100], Step [700/782], Reconst Loss: 112569.9453, KL Div: 2547.2300, Diffuse loss: 81.7463
# Epoch[38/100], Step [100/782], Reconst Loss: 115205.8125, KL Div: 2521.4463, Diffuse loss: 83.3512
# Epoch[38/100], Step [200/782], Reconst Loss: 114320.2031, KL Div: 2538.6797, Diffuse loss: 82.6737
# Epoch[38/100], Step [300/782], Reconst Loss: 111842.3828, KL Div: 2504.2261, Diffuse loss: 81.6284
# Epoch[38/100], Step [400/782], Reconst Loss: 115071.3672, KL Div: 2587.8564, Diffuse loss: 85.4842
# Epoch[38/100], Step [500/782], Reconst Loss: 112914.7344, KL Div: 2485.0688, Diffuse loss: 81.2994
# Epoch[38/100], Step [600/782], Reconst Loss: 111464.8281, KL Div: 2551.7222, Diffuse loss: 81.3129
# Epoch[38/100], Step [700/782], Reconst Loss: 114840.9766, KL Div: 2501.5181, Diffuse loss: 85.9165
# Epoch[39/100], Step [100/782], Reconst Loss: 112260.0391, KL Div: 2551.3518, Diffuse loss: 84.3964
# Epoch[39/100], Step [200/782], Reconst Loss: 114756.2031, KL Div: 2582.0283, Diffuse loss: 80.9402
# Epoch[39/100], Step [300/782], Reconst Loss: 112091.8750, KL Div: 2587.1206, Diffuse loss: 84.9614
# Epoch[39/100], Step [400/782], Reconst Loss: 111918.7188, KL Div: 2540.6411, Diffuse loss: 80.9386
# Epoch[39/100], Step [500/782], Reconst Loss: 112776.4688, KL Div: 2591.5962, Diffuse loss: 83.5060
# Epoch[39/100], Step [600/782], Reconst Loss: 111732.1250, KL Div: 2612.9067, Diffuse loss: 83.9111
# Epoch[39/100], Step [700/782], Reconst Loss: 109566.6016, KL Div: 2597.0449, Diffuse loss: 87.1934
# Epoch[40/100], Step [100/782], Reconst Loss: 115154.5469, KL Div: 2604.7183, Diffuse loss: 80.9426
# Epoch[40/100], Step [200/782], Reconst Loss: 109024.9766, KL Div: 2534.2153, Diffuse loss: 81.7384
# Epoch[40/100], Step [300/782], Reconst Loss: 116272.9844, KL Div: 2581.3230, Diffuse loss: 83.6700
# Epoch[40/100], Step [400/782], Reconst Loss: 114335.0000, KL Div: 2587.1423, Diffuse loss: 84.7113
# Epoch[40/100], Step [500/782], Reconst Loss: 112362.9219, KL Div: 2630.9570, Diffuse loss: 82.4897
# Epoch[40/100], Step [600/782], Reconst Loss: 108847.5703, KL Div: 2564.9839, Diffuse loss: 78.2901
# Epoch[40/100], Step [700/782], Reconst Loss: 113877.8047, KL Div: 2632.1331, Diffuse loss: 84.0860
# Epoch[41/100], Step [100/782], Reconst Loss: 113737.5938, KL Div: 2592.4678, Diffuse loss: 83.5240
# Epoch[41/100], Step [200/782], Reconst Loss: 112833.0469, KL Div: 2636.9067, Diffuse loss: 83.6874
# Epoch[41/100], Step [300/782], Reconst Loss: 114192.7344, KL Div: 2535.9624, Diffuse loss: 80.7704
# Epoch[41/100], Step [400/782], Reconst Loss: 113985.3516, KL Div: 2671.8245, Diffuse loss: 83.9246
# Epoch[41/100], Step [500/782], Reconst Loss: 109534.5625, KL Div: 2624.8135, Diffuse loss: 84.9385
# Epoch[41/100], Step [600/782], Reconst Loss: 111091.0391, KL Div: 2609.9575, Diffuse loss: 82.3796
# Epoch[41/100], Step [700/782], Reconst Loss: 116396.1250, KL Div: 2651.7534, Diffuse loss: 82.9750
# Epoch[42/100], Step [100/782], Reconst Loss: 112505.2500, KL Div: 2615.7217, Diffuse loss: 84.5344
# Epoch[42/100], Step [200/782], Reconst Loss: 111271.6250, KL Div: 2600.6697, Diffuse loss: 82.3671
# Epoch[42/100], Step [300/782], Reconst Loss: 114131.0469, KL Div: 2649.8403, Diffuse loss: 82.4696
# Epoch[42/100], Step [400/782], Reconst Loss: 114139.0469, KL Div: 2643.7271, Diffuse loss: 81.4871
# Epoch[42/100], Step [500/782], Reconst Loss: 113156.2109, KL Div: 2660.4277, Diffuse loss: 84.4231
# Epoch[42/100], Step [600/782], Reconst Loss: 112240.2188, KL Div: 2706.4199, Diffuse loss: 80.9426
# Epoch[42/100], Step [700/782], Reconst Loss: 107209.0078, KL Div: 2608.4951, Diffuse loss: 82.9428
# Epoch[43/100], Step [100/782], Reconst Loss: 112844.2500, KL Div: 2625.2549, Diffuse loss: 84.7999
# Epoch[43/100], Step [200/782], Reconst Loss: 112145.0312, KL Div: 2717.4165, Diffuse loss: 81.4543
# Epoch[43/100], Step [300/782], Reconst Loss: 112974.8359, KL Div: 2694.0630, Diffuse loss: 84.9665
# Epoch[43/100], Step [400/782], Reconst Loss: 113769.0000, KL Div: 2701.7231, Diffuse loss: 82.0205
# Epoch[43/100], Step [500/782], Reconst Loss: 111218.8594, KL Div: 2662.4739, Diffuse loss: 83.9855
# Epoch[43/100], Step [600/782], Reconst Loss: 112161.1250, KL Div: 2678.7417, Diffuse loss: 82.3916
# Epoch[43/100], Step [700/782], Reconst Loss: 111315.6641, KL Div: 2665.7593, Diffuse loss: 81.8715
# Epoch[44/100], Step [100/782], Reconst Loss: 114193.4141, KL Div: 2719.0938, Diffuse loss: 84.8968
# Epoch[44/100], Step [200/782], Reconst Loss: 112549.6016, KL Div: 2671.0300, Diffuse loss: 86.0173
# Epoch[44/100], Step [300/782], Reconst Loss: 113511.8672, KL Div: 2681.9302, Diffuse loss: 84.2323
# Epoch[44/100], Step [400/782], Reconst Loss: 115652.2188, KL Div: 2753.2476, Diffuse loss: 84.2610
# Epoch[44/100], Step [500/782], Reconst Loss: 112604.6094, KL Div: 2712.8506, Diffuse loss: 81.3114
# Epoch[44/100], Step [600/782], Reconst Loss: 111622.8594, KL Div: 2697.0410, Diffuse loss: 80.2822
# Epoch[44/100], Step [700/782], Reconst Loss: 114821.8828, KL Div: 2708.2605, Diffuse loss: 83.6044
# Epoch[45/100], Step [100/782], Reconst Loss: 112351.0781, KL Div: 2720.7546, Diffuse loss: 86.5170
# Epoch[45/100], Step [200/782], Reconst Loss: 113320.1562, KL Div: 2796.1226, Diffuse loss: 84.7098
# Epoch[45/100], Step [300/782], Reconst Loss: 115477.0625, KL Div: 2770.1436, Diffuse loss: 82.8673
# Epoch[45/100], Step [400/782], Reconst Loss: 112244.5000, KL Div: 2755.0095, Diffuse loss: 84.7967
# Epoch[45/100], Step [500/782], Reconst Loss: 110286.5781, KL Div: 2731.9919, Diffuse loss: 86.3299
# Epoch[45/100], Step [600/782], Reconst Loss: 115175.0859, KL Div: 2727.5747, Diffuse loss: 82.5999
# Epoch[45/100], Step [700/782], Reconst Loss: 113193.4531, KL Div: 2703.6240, Diffuse loss: 84.2030
# Epoch[46/100], Step [100/782], Reconst Loss: 115056.3984, KL Div: 2712.9365, Diffuse loss: 81.0061
# Epoch[46/100], Step [200/782], Reconst Loss: 112277.8828, KL Div: 2751.6030, Diffuse loss: 89.2458
# Epoch[46/100], Step [300/782], Reconst Loss: 111712.1562, KL Div: 2768.4575, Diffuse loss: 81.9591
# Epoch[46/100], Step [400/782], Reconst Loss: 115062.1562, KL Div: 2768.6157, Diffuse loss: 81.9637
# Epoch[46/100], Step [500/782], Reconst Loss: 108037.1641, KL Div: 2751.7778, Diffuse loss: 82.6066
# Epoch[46/100], Step [600/782], Reconst Loss: 114429.5859, KL Div: 2818.2473, Diffuse loss: 83.4166
# Epoch[46/100], Step [700/782], Reconst Loss: 112394.8203, KL Div: 2773.0215, Diffuse loss: 87.3757
# Epoch[47/100], Step [100/782], Reconst Loss: 110728.2969, KL Div: 2774.7742, Diffuse loss: 83.0740
# Epoch[47/100], Step [200/782], Reconst Loss: 110602.5938, KL Div: 2746.7915, Diffuse loss: 82.5343
# Epoch[47/100], Step [300/782], Reconst Loss: 111992.5938, KL Div: 2709.0315, Diffuse loss: 83.6091
# Epoch[47/100], Step [400/782], Reconst Loss: 113083.8125, KL Div: 2796.0020, Diffuse loss: 81.3084
# Epoch[47/100], Step [500/782], Reconst Loss: 114210.5469, KL Div: 2761.6953, Diffuse loss: 86.1758
# Epoch[47/100], Step [600/782], Reconst Loss: 110212.9219, KL Div: 2783.0635, Diffuse loss: 81.5897
# Epoch[47/100], Step [700/782], Reconst Loss: 111728.9766, KL Div: 2763.8862, Diffuse loss: 81.2539
# Epoch[48/100], Step [100/782], Reconst Loss: 112246.7734, KL Div: 2743.4146, Diffuse loss: 84.1173
# Epoch[48/100], Step [200/782], Reconst Loss: 114168.0469, KL Div: 2776.7754, Diffuse loss: 84.2338
# Epoch[48/100], Step [300/782], Reconst Loss: 111923.0000, KL Div: 2745.9238, Diffuse loss: 81.5769
# Epoch[48/100], Step [400/782], Reconst Loss: 109403.2500, KL Div: 2753.6975, Diffuse loss: 86.4176
# Epoch[48/100], Step [500/782], Reconst Loss: 108178.9531, KL Div: 2786.5171, Diffuse loss: 84.7461
# Epoch[48/100], Step [600/782], Reconst Loss: 107718.8516, KL Div: 2696.7949, Diffuse loss: 85.3498
# Epoch[48/100], Step [700/782], Reconst Loss: 109708.0078, KL Div: 2777.2988, Diffuse loss: 86.8431
# Epoch[49/100], Step [100/782], Reconst Loss: 113217.9531, KL Div: 2828.9036, Diffuse loss: 83.8146
# Epoch[49/100], Step [200/782], Reconst Loss: 109066.7422, KL Div: 2825.7241, Diffuse loss: 84.9892
# Epoch[49/100], Step [300/782], Reconst Loss: 114561.4531, KL Div: 2792.7681, Diffuse loss: 80.6657
# Epoch[49/100], Step [400/782], Reconst Loss: 113768.5312, KL Div: 2846.1040, Diffuse loss: 83.8010
# Epoch[49/100], Step [500/782], Reconst Loss: 111349.8594, KL Div: 2820.2617, Diffuse loss: 85.7812
# Epoch[49/100], Step [600/782], Reconst Loss: 112450.2188, KL Div: 2837.6975, Diffuse loss: 86.3284
# Epoch[49/100], Step [700/782], Reconst Loss: 111993.8906, KL Div: 2848.7297, Diffuse loss: 84.6437
# Epoch[50/100], Step [100/782], Reconst Loss: 114677.2344, KL Div: 2872.7747, Diffuse loss: 83.5723
# Epoch[50/100], Step [200/782], Reconst Loss: 114699.4219, KL Div: 2805.4028, Diffuse loss: 85.1290
# Epoch[50/100], Step [300/782], Reconst Loss: 108970.9609, KL Div: 2810.2485, Diffuse loss: 81.1277
# Epoch[50/100], Step [400/782], Reconst Loss: 110870.4766, KL Div: 2843.0156, Diffuse loss: 82.2340
# Epoch[50/100], Step [500/782], Reconst Loss: 111991.1250, KL Div: 2808.7876, Diffuse loss: 86.8232
# Epoch[50/100], Step [600/782], Reconst Loss: 113630.4453, KL Div: 2822.9067, Diffuse loss: 86.1895
# Epoch[50/100], Step [700/782], Reconst Loss: 110959.9844, KL Div: 2839.8474, Diffuse loss: 84.6641
# Epoch[51/100], Step [100/782], Reconst Loss: 110930.3750, KL Div: 2812.9155, Diffuse loss: 78.3820
# Epoch[51/100], Step [200/782], Reconst Loss: 110345.4844, KL Div: 2835.7310, Diffuse loss: 81.6066
# Epoch[51/100], Step [300/782], Reconst Loss: 111237.9375, KL Div: 2881.6912, Diffuse loss: 84.4949
# Epoch[51/100], Step [400/782], Reconst Loss: 113447.2109, KL Div: 2872.4080, Diffuse loss: 84.0699
# Epoch[51/100], Step [500/782], Reconst Loss: 110713.2891, KL Div: 2882.4717, Diffuse loss: 85.6865
# Epoch[51/100], Step [600/782], Reconst Loss: 111603.9375, KL Div: 2863.3462, Diffuse loss: 82.7707
# Epoch[51/100], Step [700/782], Reconst Loss: 112904.6172, KL Div: 2802.6968, Diffuse loss: 82.2288
# Epoch[52/100], Step [100/782], Reconst Loss: 110201.3594, KL Div: 2846.7153, Diffuse loss: 85.0220
# Epoch[52/100], Step [200/782], Reconst Loss: 114880.7500, KL Div: 2894.3696, Diffuse loss: 85.6334
# Epoch[52/100], Step [300/782], Reconst Loss: 115080.8906, KL Div: 2849.9033, Diffuse loss: 85.1238
# Epoch[52/100], Step [400/782], Reconst Loss: 112016.3281, KL Div: 2899.4653, Diffuse loss: 85.1637
# Epoch[52/100], Step [500/782], Reconst Loss: 111910.5469, KL Div: 2871.9341, Diffuse loss: 89.5417
# Epoch[52/100], Step [600/782], Reconst Loss: 112484.8594, KL Div: 2926.7656, Diffuse loss: 84.5723
# Epoch[52/100], Step [700/782], Reconst Loss: 113488.0312, KL Div: 2854.5891, Diffuse loss: 87.8179
# Epoch[53/100], Step [100/782], Reconst Loss: 111980.5938, KL Div: 2843.9106, Diffuse loss: 86.0909
# Epoch[53/100], Step [200/782], Reconst Loss: 111248.4375, KL Div: 2914.8748, Diffuse loss: 85.4692
# Epoch[53/100], Step [300/782], Reconst Loss: 112966.0547, KL Div: 2901.6838, Diffuse loss: 84.2168
# Epoch[53/100], Step [400/782], Reconst Loss: 110252.1094, KL Div: 2951.2920, Diffuse loss: 84.4713
# Epoch[53/100], Step [500/782], Reconst Loss: 110635.7344, KL Div: 2890.0894, Diffuse loss: 85.6867
# Epoch[53/100], Step [600/782], Reconst Loss: 111352.3281, KL Div: 2976.1443, Diffuse loss: 85.5194
# Epoch[53/100], Step [700/782], Reconst Loss: 112437.9531, KL Div: 2951.9575, Diffuse loss: 86.3575
# Epoch[54/100], Step [100/782], Reconst Loss: 110876.2344, KL Div: 2858.0425, Diffuse loss: 86.3773
# Epoch[54/100], Step [200/782], Reconst Loss: 112164.2656, KL Div: 2909.9595, Diffuse loss: 87.5278
# Epoch[54/100], Step [300/782], Reconst Loss: 112402.2422, KL Div: 2959.6660, Diffuse loss: 83.7312
# Epoch[54/100], Step [400/782], Reconst Loss: 112588.6094, KL Div: 2976.6875, Diffuse loss: 83.4258
# Epoch[54/100], Step [500/782], Reconst Loss: 110185.3438, KL Div: 2925.6357, Diffuse loss: 82.2543
# Epoch[54/100], Step [600/782], Reconst Loss: 111324.1719, KL Div: 3015.2275, Diffuse loss: 83.7900
# Epoch[54/100], Step [700/782], Reconst Loss: 113960.8281, KL Div: 2919.5156, Diffuse loss: 82.7275
# Epoch[55/100], Step [100/782], Reconst Loss: 108707.7031, KL Div: 2893.3760, Diffuse loss: 81.6816
# Epoch[55/100], Step [200/782], Reconst Loss: 110872.9219, KL Div: 2950.4731, Diffuse loss: 84.0490
# Epoch[55/100], Step [300/782], Reconst Loss: 112597.6953, KL Div: 2954.7070, Diffuse loss: 84.3250
# Epoch[55/100], Step [400/782], Reconst Loss: 111830.4922, KL Div: 2948.7488, Diffuse loss: 82.2667
# Epoch[55/100], Step [500/782], Reconst Loss: 113441.5078, KL Div: 2989.1663, Diffuse loss: 83.3448
# Epoch[55/100], Step [600/782], Reconst Loss: 110554.7031, KL Div: 2903.1025, Diffuse loss: 84.9882
# Epoch[55/100], Step [700/782], Reconst Loss: 114493.8125, KL Div: 2977.1934, Diffuse loss: 82.7885
# Epoch[56/100], Step [100/782], Reconst Loss: 112332.0625, KL Div: 2943.4080, Diffuse loss: 82.3504
# Epoch[56/100], Step [200/782], Reconst Loss: 113819.2031, KL Div: 2911.8369, Diffuse loss: 83.2202
# Epoch[56/100], Step [300/782], Reconst Loss: 108221.8750, KL Div: 2973.7219, Diffuse loss: 85.0551
# Epoch[56/100], Step [400/782], Reconst Loss: 112809.5547, KL Div: 2930.0674, Diffuse loss: 85.8992
# Epoch[56/100], Step [500/782], Reconst Loss: 110582.4219, KL Div: 2994.9150, Diffuse loss: 84.1950
# Epoch[56/100], Step [600/782], Reconst Loss: 111672.4375, KL Div: 2889.8792, Diffuse loss: 86.5633
# Epoch[56/100], Step [700/782], Reconst Loss: 111416.5469, KL Div: 2960.6707, Diffuse loss: 84.5695
# Epoch[57/100], Step [100/782], Reconst Loss: 114088.3125, KL Div: 2977.9744, Diffuse loss: 87.5239
# Epoch[57/100], Step [200/782], Reconst Loss: 112229.6250, KL Div: 2998.8081, Diffuse loss: 84.7744
# Epoch[57/100], Step [300/782], Reconst Loss: 113261.9453, KL Div: 2978.5215, Diffuse loss: 83.7794
# Epoch[57/100], Step [400/782], Reconst Loss: 112819.1328, KL Div: 2985.9111, Diffuse loss: 86.6963
# Epoch[57/100], Step [500/782], Reconst Loss: 113290.5781, KL Div: 2972.9434, Diffuse loss: 85.2325
# Epoch[57/100], Step [600/782], Reconst Loss: 111743.1406, KL Div: 3020.2554, Diffuse loss: 86.2538
# Epoch[57/100], Step [700/782], Reconst Loss: 110518.0391, KL Div: 2962.8091, Diffuse loss: 85.8795
# Epoch[58/100], Step [100/782], Reconst Loss: 108442.2266, KL Div: 3011.6709, Diffuse loss: 82.5950
# Epoch[58/100], Step [200/782], Reconst Loss: 112153.5625, KL Div: 3030.7803, Diffuse loss: 83.6264
# Epoch[58/100], Step [300/782], Reconst Loss: 114308.9219, KL Div: 2960.0056, Diffuse loss: 82.2700
# Epoch[58/100], Step [400/782], Reconst Loss: 116714.6016, KL Div: 3020.7427, Diffuse loss: 85.9830
# Epoch[58/100], Step [500/782], Reconst Loss: 113307.0625, KL Div: 3057.2861, Diffuse loss: 85.1455
# Epoch[58/100], Step [600/782], Reconst Loss: 113393.2031, KL Div: 2949.0928, Diffuse loss: 83.2490
# Epoch[58/100], Step [700/782], Reconst Loss: 111786.2969, KL Div: 2998.0137, Diffuse loss: 87.7963
# Epoch[59/100], Step [100/782], Reconst Loss: 114609.3359, KL Div: 3011.2891, Diffuse loss: 84.9394
# Epoch[59/100], Step [200/782], Reconst Loss: 113090.0859, KL Div: 2999.2051, Diffuse loss: 85.6153
# Epoch[59/100], Step [300/782], Reconst Loss: 111292.3281, KL Div: 3030.2627, Diffuse loss: 83.2932
# Epoch[59/100], Step [400/782], Reconst Loss: 111390.1484, KL Div: 3062.7424, Diffuse loss: 85.2486
# Epoch[59/100], Step [500/782], Reconst Loss: 112054.3750, KL Div: 3024.3679, Diffuse loss: 84.8684
# Epoch[59/100], Step [600/782], Reconst Loss: 112877.7266, KL Div: 3111.7761, Diffuse loss: 83.7980
# Epoch[59/100], Step [700/782], Reconst Loss: 113793.6719, KL Div: 3082.5552, Diffuse loss: 85.3904
# Epoch[60/100], Step [100/782], Reconst Loss: 108731.6797, KL Div: 3077.3604, Diffuse loss: 84.4919
# Epoch[60/100], Step [200/782], Reconst Loss: 113893.9453, KL Div: 3052.0396, Diffuse loss: 85.9471
# Epoch[60/100], Step [300/782], Reconst Loss: 110751.6719, KL Div: 3058.5007, Diffuse loss: 81.5443
# Epoch[60/100], Step [400/782], Reconst Loss: 114740.8906, KL Div: 3060.7339, Diffuse loss: 86.5368
# Epoch[60/100], Step [500/782], Reconst Loss: 111661.7422, KL Div: 3059.6089, Diffuse loss: 81.2646
# Epoch[60/100], Step [600/782], Reconst Loss: 110413.2188, KL Div: 3066.4866, Diffuse loss: 83.8668
# Epoch[60/100], Step [700/782], Reconst Loss: 114429.9688, KL Div: 3034.7427, Diffuse loss: 83.4142
# Epoch[61/100], Step [100/782], Reconst Loss: 109884.1641, KL Div: 3051.2583, Diffuse loss: 83.5422
# Epoch[61/100], Step [200/782], Reconst Loss: 112756.6016, KL Div: 3038.4751, Diffuse loss: 85.1749
# Epoch[61/100], Step [300/782], Reconst Loss: 113170.6328, KL Div: 3048.7578, Diffuse loss: 86.7919
# Epoch[61/100], Step [400/782], Reconst Loss: 111294.7188, KL Div: 3043.7439, Diffuse loss: 85.7427
# Epoch[61/100], Step [500/782], Reconst Loss: 107269.7109, KL Div: 3078.6875, Diffuse loss: 86.6450
# Epoch[61/100], Step [600/782], Reconst Loss: 113373.4922, KL Div: 3098.1997, Diffuse loss: 84.4996
# Epoch[61/100], Step [700/782], Reconst Loss: 114253.1484, KL Div: 3118.3394, Diffuse loss: 85.2778
# Epoch[62/100], Step [100/782], Reconst Loss: 110242.6641, KL Div: 3041.0747, Diffuse loss: 83.9712
# Epoch[62/100], Step [200/782], Reconst Loss: 112126.5000, KL Div: 3028.2261, Diffuse loss: 84.8007
# Epoch[62/100], Step [300/782], Reconst Loss: 112195.3203, KL Div: 3069.9282, Diffuse loss: 83.8157
# Epoch[62/100], Step [400/782], Reconst Loss: 112182.8828, KL Div: 3111.9102, Diffuse loss: 86.3182
# Epoch[62/100], Step [500/782], Reconst Loss: 112766.1172, KL Div: 3075.1409, Diffuse loss: 83.1166
# Epoch[62/100], Step [600/782], Reconst Loss: 112400.0469, KL Div: 3091.0220, Diffuse loss: 85.2067
# Epoch[62/100], Step [700/782], Reconst Loss: 112116.9062, KL Div: 3087.8696, Diffuse loss: 85.7395
# Epoch[63/100], Step [100/782], Reconst Loss: 112609.1875, KL Div: 3093.2444, Diffuse loss: 82.0390
# Epoch[63/100], Step [200/782], Reconst Loss: 111393.8828, KL Div: 3045.5835, Diffuse loss: 80.8804
# Epoch[63/100], Step [300/782], Reconst Loss: 113084.6641, KL Div: 3072.3635, Diffuse loss: 86.6116
# Epoch[63/100], Step [400/782], Reconst Loss: 111057.1719, KL Div: 3103.2759, Diffuse loss: 85.9159
# Epoch[63/100], Step [500/782], Reconst Loss: 112128.5156, KL Div: 3087.3604, Diffuse loss: 85.4268
# Epoch[63/100], Step [600/782], Reconst Loss: 111857.0078, KL Div: 3067.3486, Diffuse loss: 86.7625
# Epoch[63/100], Step [700/782], Reconst Loss: 114669.5625, KL Div: 3084.9036, Diffuse loss: 85.1010
# Epoch[64/100], Step [100/782], Reconst Loss: 110178.1406, KL Div: 3077.3630, Diffuse loss: 83.6849
# Epoch[64/100], Step [200/782], Reconst Loss: 111325.4219, KL Div: 3159.4185, Diffuse loss: 82.3572
# Epoch[64/100], Step [300/782], Reconst Loss: 113196.6875, KL Div: 3165.9573, Diffuse loss: 87.0637
# Epoch[64/100], Step [400/782], Reconst Loss: 111447.0625, KL Div: 3090.6743, Diffuse loss: 84.7263
# Epoch[64/100], Step [500/782], Reconst Loss: 114701.6875, KL Div: 3121.0271, Diffuse loss: 86.0063
# Epoch[64/100], Step [600/782], Reconst Loss: 113740.2969, KL Div: 3106.1843, Diffuse loss: 86.7229
# Epoch[64/100], Step [700/782], Reconst Loss: 112771.4141, KL Div: 3043.2302, Diffuse loss: 84.6739
# Epoch[65/100], Step [100/782], Reconst Loss: 110986.7188, KL Div: 3210.1489, Diffuse loss: 82.1723
# Epoch[65/100], Step [200/782], Reconst Loss: 114062.3438, KL Div: 3165.6309, Diffuse loss: 82.9980
# Epoch[65/100], Step [300/782], Reconst Loss: 110318.2344, KL Div: 3125.0713, Diffuse loss: 85.4435
# Epoch[65/100], Step [400/782], Reconst Loss: 113113.3594, KL Div: 3077.6528, Diffuse loss: 86.1115
# Epoch[65/100], Step [500/782], Reconst Loss: 111417.8281, KL Div: 3122.3860, Diffuse loss: 82.3672
# Epoch[65/100], Step [600/782], Reconst Loss: 113008.2344, KL Div: 3143.3416, Diffuse loss: 84.2049
# Epoch[65/100], Step [700/782], Reconst Loss: 114814.7578, KL Div: 3152.1006, Diffuse loss: 81.9531
# Epoch[66/100], Step [100/782], Reconst Loss: 112709.1406, KL Div: 3141.5776, Diffuse loss: 83.4705
# Epoch[66/100], Step [200/782], Reconst Loss: 110458.2188, KL Div: 3061.8872, Diffuse loss: 85.5444
# Epoch[66/100], Step [300/782], Reconst Loss: 110773.8438, KL Div: 3189.3433, Diffuse loss: 81.3281
# Epoch[66/100], Step [400/782], Reconst Loss: 111425.8047, KL Div: 3155.0713, Diffuse loss: 86.6835
# Epoch[66/100], Step [500/782], Reconst Loss: 110010.0312, KL Div: 3163.0762, Diffuse loss: 86.1907
# Epoch[66/100], Step [600/782], Reconst Loss: 112350.0000, KL Div: 3090.2766, Diffuse loss: 87.1704
# Epoch[66/100], Step [700/782], Reconst Loss: 113640.3438, KL Div: 3119.5088, Diffuse loss: 84.8835
# Epoch[67/100], Step [100/782], Reconst Loss: 111863.7656, KL Div: 3149.1372, Diffuse loss: 83.5348
# Epoch[67/100], Step [200/782], Reconst Loss: 111840.2578, KL Div: 3128.7073, Diffuse loss: 83.6767
# Epoch[67/100], Step [300/782], Reconst Loss: 115573.6719, KL Div: 3167.4150, Diffuse loss: 86.2035
# Epoch[67/100], Step [400/782], Reconst Loss: 111465.1562, KL Div: 3155.5376, Diffuse loss: 87.5174
# Epoch[67/100], Step [500/782], Reconst Loss: 114362.2031, KL Div: 3206.2368, Diffuse loss: 83.9839
# Epoch[67/100], Step [600/782], Reconst Loss: 110405.5078, KL Div: 3219.2256, Diffuse loss: 85.3113
# Epoch[67/100], Step [700/782], Reconst Loss: 114714.0000, KL Div: 3248.9343, Diffuse loss: 88.3431
# Epoch[68/100], Step [100/782], Reconst Loss: 111392.8906, KL Div: 3178.9485, Diffuse loss: 81.7341
# Epoch[68/100], Step [200/782], Reconst Loss: 113882.6953, KL Div: 3115.6440, Diffuse loss: 86.8935
# Epoch[68/100], Step [300/782], Reconst Loss: 111407.6562, KL Div: 3207.2202, Diffuse loss: 84.2630
# Epoch[68/100], Step [400/782], Reconst Loss: 109658.4609, KL Div: 3159.2397, Diffuse loss: 85.3166
# Epoch[68/100], Step [500/782], Reconst Loss: 110764.2812, KL Div: 3152.4805, Diffuse loss: 86.3463
# Epoch[68/100], Step [600/782], Reconst Loss: 110071.5469, KL Div: 3183.2017, Diffuse loss: 81.6297
# Epoch[68/100], Step [700/782], Reconst Loss: 112657.0156, KL Div: 3159.5796, Diffuse loss: 85.4195
# Epoch[69/100], Step [100/782], Reconst Loss: 112852.5781, KL Div: 3209.3818, Diffuse loss: 86.1942
# Epoch[69/100], Step [200/782], Reconst Loss: 112597.1719, KL Div: 3208.4995, Diffuse loss: 86.3977
# Epoch[69/100], Step [300/782], Reconst Loss: 111305.3047, KL Div: 3214.6770, Diffuse loss: 85.2945
# Epoch[69/100], Step [400/782], Reconst Loss: 108970.3672, KL Div: 3191.1680, Diffuse loss: 84.3957
# ...
# Epoch[78/100], Step [100/782], Reconst Loss: 116950.6484, KL Div: 3291.8464, Diffuse loss: 83.9120
# Epoch[78/100], Step [200/782], Reconst Loss: 113330.8672, KL Div: 3242.0532, Diffuse loss: 86.8492
# Epoch[78/100], Step [300/782], Reconst Loss: 113093.9297, KL Div: 3326.3235, Diffuse loss: 84.1227
# Epoch[78/100], Step [400/782], Reconst Loss: 114150.1953, KL Div: 3296.9329, Diffuse loss: 83.7521
# Epoch[78/100], Step [500/782], Reconst Loss: 112467.0078, KL Div: 3262.9758, Diffuse loss: 85.4500
# Epoch[78/100], Step [600/782], Reconst Loss: 108708.4688, KL Div: 3381.0535, Diffuse loss: 86.3101
# Epoch[78/100], Step [700/782], Reconst Loss: 114621.6094, KL Div: 3312.4153, Diffuse loss: 85.0034
# Epoch[79/100], Step [100/782], Reconst Loss: 109822.6875, KL Div: 3242.6826, Diffuse loss: 84.7447
# Epoch[79/100], Step [200/782], Reconst Loss: 113107.4062, KL Div: 3316.5652, Diffuse loss: 84.4598
# Epoch[79/100], Step [300/782], Reconst Loss: 109707.0469, KL Div: 3278.7661, Diffuse loss: 85.8976
# Epoch[79/100], Step [400/782], Reconst Loss: 109731.0703, KL Div: 3235.1934, Diffuse loss: 82.7866
# Epoch[79/100], Step [500/782], Reconst Loss: 112421.1719, KL Div: 3250.7891, Diffuse loss: 84.2936
# Epoch[79/100], Step [600/782], Reconst Loss: 112478.4766, KL Div: 3326.9326, Diffuse loss: 82.5153
# Epoch[79/100], Step [700/782], Reconst Loss: 108677.4922, KL Div: 3289.7512, Diffuse loss: 81.7540
# Epoch[80/100], Step [100/782], Reconst Loss: 111341.6094, KL Div: 3366.1699, Diffuse loss: 83.3344
# Epoch[80/100], Step [200/782], Reconst Loss: 109911.0156, KL Div: 3340.0732, Diffuse loss: 85.9618
# Epoch[80/100], Step [300/782], Reconst Loss: 114244.1094, KL Div: 3350.1829, Diffuse loss: 86.1234
# Epoch[80/100], Step [400/782], Reconst Loss: 110828.7031, KL Div: 3345.7637, Diffuse loss: 83.3569
# Epoch[80/100], Step [500/782], Reconst Loss: 114380.6406, KL Div: 3386.4197, Diffuse loss: 83.4092
# Epoch[80/100], Step [600/782], Reconst Loss: 108647.6953, KL Div: 3287.8555, Diffuse loss: 83.3266
# Epoch[80/100], Step [700/782], Reconst Loss: 112908.5391, KL Div: 3247.0059, Diffuse loss: 80.6922
# Epoch[81/100], Step [100/782], Reconst Loss: 110852.4688, KL Div: 3245.5852, Diffuse loss: 84.6458
# Epoch[81/100], Step [200/782], Reconst Loss: 110779.9219, KL Div: 3389.1089, Diffuse loss: 84.9541
# Epoch[81/100], Step [300/782], Reconst Loss: 112894.5938, KL Div: 3323.8989, Diffuse loss: 81.5398
# Epoch[81/100], Step [400/782], Reconst Loss: 111135.3125, KL Div: 3345.2883, Diffuse loss: 79.6195
# Epoch[81/100], Step [500/782], Reconst Loss: 112713.3438, KL Div: 3464.2573, Diffuse loss: 85.8371
# Epoch[81/100], Step [600/782], Reconst Loss: 110321.3984, KL Div: 3381.2939, Diffuse loss: 84.8517
# Epoch[81/100], Step [700/782], Reconst Loss: 110820.4062, KL Div: 3364.9448, Diffuse loss: 88.7855
# Epoch[82/100], Step [100/782], Reconst Loss: 112333.5625, KL Div: 3367.1978, Diffuse loss: 85.3322
# Epoch[82/100], Step [200/782], Reconst Loss: 112995.7812, KL Div: 3357.7866, Diffuse loss: 84.8485
# Epoch[82/100], Step [300/782], Reconst Loss: 110542.1875, KL Div: 3307.8228, Diffuse loss: 88.0130
# Epoch[82/100], Step [400/782], Reconst Loss: 112210.6953, KL Div: 3330.0186, Diffuse loss: 85.3755
# Epoch[82/100], Step [500/782], Reconst Loss: 111972.3359, KL Div: 3352.1538, Diffuse loss: 83.5804
# Epoch[82/100], Step [600/782], Reconst Loss: 110977.0703, KL Div: 3307.5781, Diffuse loss: 83.1941
# Epoch[82/100], Step [700/782], Reconst Loss: 111286.5312, KL Div: 3312.1724, Diffuse loss: 85.1656
# Epoch[83/100], Step [100/782], Reconst Loss: 109069.0234, KL Div: 3359.4395, Diffuse loss: 84.4627
# Epoch[83/100], Step [200/782], Reconst Loss: 109678.0000, KL Div: 3299.3169, Diffuse loss: 83.9960
# Epoch[83/100], Step [300/782], Reconst Loss: 109239.5625, KL Div: 3376.0859, Diffuse loss: 86.7062
# Epoch[83/100], Step [400/782], Reconst Loss: 110624.0234, KL Div: 3392.3950, Diffuse loss: 84.3690
# Epoch[83/100], Step [500/782], Reconst Loss: 111824.7031, KL Div: 3313.7153, Diffuse loss: 83.3610
# Epoch[83/100], Step [600/782], Reconst Loss: 112826.2578, KL Div: 3390.0952, Diffuse loss: 85.4516
# Epoch[83/100], Step [700/782], Reconst Loss: 113700.9219, KL Div: 3385.7202, Diffuse loss: 83.1828
# Epoch[84/100], Step [100/782], Reconst Loss: 112350.9062, KL Div: 3405.9373, Diffuse loss: 86.0813
# Epoch[84/100], Step [200/782], Reconst Loss: 111529.7500, KL Div: 3421.1433, Diffuse loss: 87.7263
# Epoch[84/100], Step [300/782], Reconst Loss: 111677.4219, KL Div: 3376.5571, Diffuse loss: 84.3010
# Epoch[84/100], Step [400/782], Reconst Loss: 111391.8203, KL Div: 3272.7754, Diffuse loss: 83.9597
# Epoch[84/100], Step [500/782], Reconst Loss: 112851.0391, KL Div: 3314.4863, Diffuse loss: 88.2214
# Epoch[84/100], Step [600/782], Reconst Loss: 113760.2891, KL Div: 3402.4043, Diffuse loss: 85.7050
# Epoch[84/100], Step [700/782], Reconst Loss: 109536.4844, KL Div: 3430.7046, Diffuse loss: 83.3893
# Epoch[85/100], Step [100/782], Reconst Loss: 111823.4219, KL Div: 3371.9336, Diffuse loss: 86.4380
# Epoch[85/100], Step [200/782], Reconst Loss: 111953.5156, KL Div: 3397.8525, Diffuse loss: 82.5229
# Epoch[85/100], Step [300/782], Reconst Loss: 113233.4453, KL Div: 3489.1030, Diffuse loss: 84.3558
# Epoch[85/100], Step [400/782], Reconst Loss: 111959.2422, KL Div: 3359.7144, Diffuse loss: 84.5043
# Epoch[85/100], Step [500/782], Reconst Loss: 111767.4375, KL Div: 3392.6245, Diffuse loss: 86.8085
# Epoch[85/100], Step [600/782], Reconst Loss: 112812.1719, KL Div: 3401.2417, Diffuse loss: 85.9400
# Epoch[85/100], Step [700/782], Reconst Loss: 113744.7656, KL Div: 3376.3760, Diffuse loss: 85.3744
# Epoch[86/100], Step [100/782], Reconst Loss: 114548.4609, KL Div: 3404.2729, Diffuse loss: 85.0476
# Epoch[86/100], Step [200/782], Reconst Loss: 109139.8438, KL Div: 3393.0415, Diffuse loss: 84.7803
# Epoch[86/100], Step [300/782], Reconst Loss: 112477.3750, KL Div: 3430.3550, Diffuse loss: 83.8102
# Epoch[86/100], Step [400/782], Reconst Loss: 112256.1953, KL Div: 3359.8159, Diffuse loss: 85.4536
# Epoch[86/100], Step [500/782], Reconst Loss: 112134.0938, KL Div: 3392.6711, Diffuse loss: 86.0100
# Epoch[86/100], Step [600/782], Reconst Loss: 112424.4844, KL Div: 3434.9231, Diffuse loss: 85.1383
# Epoch[86/100], Step [700/782], Reconst Loss: 110162.1094, KL Div: 3364.4429, Diffuse loss: 87.2827
# Epoch[87/100], Step [100/782], Reconst Loss: 111883.1875, KL Div: 3426.4854, Diffuse loss: 82.4654
# Epoch[87/100], Step [200/782], Reconst Loss: 112257.3984, KL Div: 3394.0857, Diffuse loss: 86.9488
# Epoch[87/100], Step [300/782], Reconst Loss: 112595.8438, KL Div: 3378.1868, Diffuse loss: 86.6396
# Epoch[87/100], Step [400/782], Reconst Loss: 110938.9219, KL Div: 3437.0066, Diffuse loss: 87.9565
# Epoch[87/100], Step [500/782], Reconst Loss: 112384.8125, KL Div: 3458.9487, Diffuse loss: 87.3702
# Epoch[87/100], Step [600/782], Reconst Loss: 110370.5625, KL Div: 3395.2861, Diffuse loss: 87.1307
# Epoch[87/100], Step [700/782], Reconst Loss: 112973.6953, KL Div: 3344.1553, Diffuse loss: 88.9369
# Epoch[88/100], Step [100/782], Reconst Loss: 113478.4219, KL Div: 3396.9355, Diffuse loss: 88.1352
# Epoch[88/100], Step [200/782], Reconst Loss: 111225.9531, KL Div: 3365.7561, Diffuse loss: 83.2250
# Epoch[88/100], Step [300/782], Reconst Loss: 115640.2266, KL Div: 3426.4307, Diffuse loss: 86.6185
# Epoch[88/100], Step [400/782], Reconst Loss: 112862.0547, KL Div: 3435.8003, Diffuse loss: 88.4752
# Epoch[88/100], Step [500/782], Reconst Loss: 112900.5781, KL Div: 3374.2168, Diffuse loss: 84.0801
# Epoch[88/100], Step [600/782], Reconst Loss: 112419.9766, KL Div: 3471.5723, Diffuse loss: 83.9218
# Epoch[88/100], Step [700/782], Reconst Loss: 110674.0781, KL Div: 3408.6963, Diffuse loss: 83.5313
# Epoch[89/100], Step [100/782], Reconst Loss: 113882.5391, KL Div: 3470.9749, Diffuse loss: 84.8558
# Epoch[89/100], Step [200/782], Reconst Loss: 112260.2500, KL Div: 3382.9795, Diffuse loss: 84.8855
# Epoch[89/100], Step [300/782], Reconst Loss: 113105.3047, KL Div: 3401.3667, Diffuse loss: 84.9030
# Epoch[89/100], Step [400/782], Reconst Loss: 114055.8594, KL Div: 3463.6667, Diffuse loss: 86.3047
# Epoch[89/100], Step [500/782], Reconst Loss: 111239.4766, KL Div: 3480.6426, Diffuse loss: 86.8042
# Epoch[89/100], Step [600/782], Reconst Loss: 109908.4922, KL Div: 3497.2058, Diffuse loss: 84.7721
# Epoch[89/100], Step [700/782], Reconst Loss: 112627.6562, KL Div: 3406.3616, Diffuse loss: 89.6024
# Epoch[90/100], Step [100/782], Reconst Loss: 112614.0234, KL Div: 3408.8813, Diffuse loss: 86.0396
# Epoch[90/100], Step [200/782], Reconst Loss: 111837.6094, KL Div: 3526.1968, Diffuse loss: 86.2299
# Epoch[90/100], Step [300/782], Reconst Loss: 110670.0547, KL Div: 3345.9297, Diffuse loss: 87.4568
# Epoch[90/100], Step [400/782], Reconst Loss: 111814.7344, KL Div: 3473.4695, Diffuse loss: 88.2821
# Epoch[90/100], Step [500/782], Reconst Loss: 112803.8906, KL Div: 3489.5947, Diffuse loss: 88.7697
# Epoch[90/100], Step [600/782], Reconst Loss: 111569.9844, KL Div: 3353.5332, Diffuse loss: 86.4716
# Epoch[90/100], Step [700/782], Reconst Loss: 110934.4922, KL Div: 3422.9346, Diffuse loss: 85.4492
# Epoch[91/100], Step [100/782], Reconst Loss: 110126.3047, KL Div: 3439.8892, Diffuse loss: 87.6515
# Epoch[91/100], Step [200/782], Reconst Loss: 110661.5156, KL Div: 3449.1963, Diffuse loss: 88.8709
# Epoch[91/100], Step [300/782], Reconst Loss: 109808.4766, KL Div: 3434.2949, Diffuse loss: 87.0640
# Epoch[91/100], Step [400/782], Reconst Loss: 111438.5078, KL Div: 3375.5684, Diffuse loss: 85.9836
# Epoch[91/100], Step [500/782], Reconst Loss: 110631.8438, KL Div: 3446.8066, Diffuse loss: 86.0019
# Epoch[91/100], Step [600/782], Reconst Loss: 110249.2422, KL Div: 3467.9976, Diffuse loss: 84.8898
# Epoch[91/100], Step [700/782], Reconst Loss: 112188.1250, KL Div: 3440.5979, Diffuse loss: 85.3729
# Epoch[92/100], Step [100/782], Reconst Loss: 113020.1875, KL Div: 3510.4834, Diffuse loss: 85.8725
# Epoch[92/100], Step [200/782], Reconst Loss: 111500.7656, KL Div: 3378.2590, Diffuse loss: 87.5832
# Epoch[92/100], Step [300/782], Reconst Loss: 113968.4062, KL Div: 3500.9492, Diffuse loss: 82.0646
# Epoch[92/100], Step [400/782], Reconst Loss: 112374.9375, KL Div: 3349.8918, Diffuse loss: 84.9655
# Epoch[92/100], Step [500/782], Reconst Loss: 116161.0391, KL Div: 3470.6299, Diffuse loss: 85.8346
# Epoch[92/100], Step [600/782], Reconst Loss: 114400.8984, KL Div: 3425.3569, Diffuse loss: 85.4027
# Epoch[92/100], Step [700/782], Reconst Loss: 114163.4688, KL Div: 3432.9285, Diffuse loss: 85.0675
# Epoch[93/100], Step [100/782], Reconst Loss: 112158.3281, KL Div: 3486.1167, Diffuse loss: 83.8176
# Epoch[93/100], Step [200/782], Reconst Loss: 112568.6797, KL Div: 3494.8254, Diffuse loss: 83.6644
# Epoch[93/100], Step [300/782], Reconst Loss: 114067.3438, KL Div: 3455.4946, Diffuse loss: 88.9559
# Epoch[93/100], Step [400/782], Reconst Loss: 111916.5625, KL Div: 3462.1440, Diffuse loss: 85.1921
# Epoch[93/100], Step [500/782], Reconst Loss: 113460.9922, KL Div: 3471.5625, Diffuse loss: 88.8302
# Epoch[93/100], Step [600/782], Reconst Loss: 109356.8906, KL Div: 3419.9248, Diffuse loss: 85.6848
# Epoch[93/100], Step [700/782], Reconst Loss: 110790.0938, KL Div: 3518.3530, Diffuse loss: 86.5033
# Epoch[94/100], Step [100/782], Reconst Loss: 109831.5391, KL Div: 3447.9421, Diffuse loss: 84.5688
# Epoch[94/100], Step [200/782], Reconst Loss: 111794.1562, KL Div: 3500.0833, Diffuse loss: 84.7487
# Epoch[94/100], Step [300/782], Reconst Loss: 111306.0156, KL Div: 3550.1899, Diffuse loss: 84.6592
# Epoch[94/100], Step [400/782], Reconst Loss: 114242.5156, KL Div: 3538.6782, Diffuse loss: 86.0788
# Epoch[94/100], Step [500/782], Reconst Loss: 113202.1172, KL Div: 3513.3521, Diffuse loss: 82.0801
# Epoch[94/100], Step [600/782], Reconst Loss: 111415.8750, KL Div: 3471.6621, Diffuse loss: 84.4584
# Epoch[94/100], Step [700/782], Reconst Loss: 112098.5547, KL Div: 3515.1257, Diffuse loss: 84.8750
# Epoch[95/100], Step [100/782], Reconst Loss: 112250.8281, KL Div: 3439.3071, Diffuse loss: 86.2336
# Epoch[95/100], Step [200/782], Reconst Loss: 111377.8359, KL Div: 3492.7148, Diffuse loss: 84.6447
# Epoch[95/100], Step [300/782], Reconst Loss: 111155.0625, KL Div: 3518.8708, Diffuse loss: 86.7780
# Epoch[95/100], Step [400/782], Reconst Loss: 113252.2734, KL Div: 3586.9673, Diffuse loss: 85.9132
# Epoch[95/100], Step [500/782], Reconst Loss: 113041.1406, KL Div: 3430.0337, Diffuse loss: 87.2318
# Epoch[95/100], Step [600/782], Reconst Loss: 111763.1797, KL Div: 3482.8955, Diffuse loss: 86.1280
# Epoch[95/100], Step [700/782], Reconst Loss: 112875.0078, KL Div: 3578.8755, Diffuse loss: 85.2247
# Epoch[96/100], Step [100/782], Reconst Loss: 110834.3828, KL Div: 3434.2686, Diffuse loss: 84.1100
# Epoch[96/100], Step [200/782], Reconst Loss: 112911.5078, KL Div: 3449.4443, Diffuse loss: 84.5358
# Epoch[96/100], Step [300/782], Reconst Loss: 109292.6250, KL Div: 3494.1970, Diffuse loss: 82.7226
# Epoch[96/100], Step [400/782], Reconst Loss: 109796.6875, KL Div: 3443.6357, Diffuse loss: 88.0980
# Epoch[96/100], Step [500/782], Reconst Loss: 109116.8438, KL Div: 3393.8501, Diffuse loss: 85.4294
# Epoch[96/100], Step [600/782], Reconst Loss: 115397.0547, KL Div: 3486.6362, Diffuse loss: 87.7184
# Epoch[96/100], Step [700/782], Reconst Loss: 108481.7188, KL Div: 3510.8877, Diffuse loss: 82.7678
# Epoch[97/100], Step [100/782], Reconst Loss: 112856.0938, KL Div: 3504.3428, Diffuse loss: 84.7411
# Epoch[97/100], Step [200/782], Reconst Loss: 109612.0859, KL Div: 3543.8052, Diffuse loss: 82.1608
# Epoch[97/100], Step [300/782], Reconst Loss: 114050.3906, KL Div: 3535.5352, Diffuse loss: 85.0444
# Epoch[97/100], Step [400/782], Reconst Loss: 107985.8281, KL Div: 3541.1814, Diffuse loss: 85.0534
# Epoch[97/100], Step [500/782], Reconst Loss: 110941.9297, KL Div: 3526.0901, Diffuse loss: 83.6712
# Epoch[97/100], Step [600/782], Reconst Loss: 113484.4531, KL Div: 3450.4707, Diffuse loss: 85.7707
# Epoch[97/100], Step [700/782], Reconst Loss: 111931.8047, KL Div: 3546.1636, Diffuse loss: 85.3518
# Epoch[98/100], Step [100/782], Reconst Loss: 114602.7656, KL Div: 3523.4062, Diffuse loss: 83.3269
# Epoch[98/100], Step [200/782], Reconst Loss: 108177.6562, KL Div: 3421.2073, Diffuse loss: 86.7232
# Epoch[98/100], Step [300/782], Reconst Loss: 115008.7188, KL Div: 3526.7354, Diffuse loss: 87.1466
# Epoch[98/100], Step [400/782], Reconst Loss: 107720.1797, KL Div: 3494.5898, Diffuse loss: 85.9490
# Epoch[98/100], Step [500/782], Reconst Loss: 112791.2188, KL Div: 3580.5229, Diffuse loss: 89.8485
# Epoch[98/100], Step [600/782], Reconst Loss: 110467.1250, KL Div: 3467.3813, Diffuse loss: 84.0090
# Epoch[98/100], Step [700/782], Reconst Loss: 113045.8984, KL Div: 3452.1729, Diffuse loss: 84.3552
# Epoch[99/100], Step [100/782], Reconst Loss: 109572.6250, KL Div: 3448.0825, Diffuse loss: 87.6488
# Epoch[99/100], Step [200/782], Reconst Loss: 114635.7734, KL Div: 3571.0083, Diffuse loss: 88.0345
# Epoch[99/100], Step [300/782], Reconst Loss: 114279.5234, KL Div: 3531.9155, Diffuse loss: 85.5044
# Epoch[99/100], Step [400/782], Reconst Loss: 113183.6016, KL Div: 3602.9429, Diffuse loss: 84.7826
# Epoch[99/100], Step [500/782], Reconst Loss: 108250.3516, KL Div: 3590.1611, Diffuse loss: 83.9583
# Epoch[99/100], Step [600/782], Reconst Loss: 112704.8594, KL Div: 3518.3403, Diffuse loss: 84.6017
# Epoch[99/100], Step [700/782], Reconst Loss: 109247.4062, KL Div: 3535.0203, Diffuse loss: 85.0583
# Epoch[100/100], Step [100/782], Reconst Loss: 113175.2344, KL Div: 3557.6191, Diffuse loss: 86.4601
# Epoch[100/100], Step [200/782], Reconst Loss: 110568.7031, KL Div: 3473.4219, Diffuse loss: 85.0539
# Epoch[100/100], Step [300/782], Reconst Loss: 110723.0391, KL Div: 3543.6597, Diffuse loss: 87.3311
# Epoch[100/100], Step [400/782], Reconst Loss: 111495.3125, KL Div: 3551.7144, Diffuse loss: 81.7772
# Epoch[100/100], Step [500/782], Reconst Loss: 112818.3750, KL Div: 3475.8967, Diffuse loss: 84.5395
# Epoch[100/100], Step [600/782], Reconst Loss: 111348.1328, KL Div: 3479.4814, Diffuse loss: 86.8526
# Epoch[100/100], Step [700/782], Reconst Loss: 110695.2344, KL Div: 3532.4373, Diffuse loss: 84.8679

# %%
if load_available:
    ckpt = torch.load(model_dir+'ckpt.pth', map_location=device)
    vae = CnnVAE(in_channels=3, latent_dim=z_dim).to(device)
    sn = SN_Model(marginal_prob_std=marginal_prob_std_fn, embed_dim=20, dim=z_dim, drop_p=0.3, device=device)
    vae.load_state_dict(ckpt['vae_state'])
    sn.load_state_dict(ckpt['sn_state'])

# %%
_, (x, _) = next(enumerate(data_loader))
x = x.to(device)

# %%
only_final = False
n_steps = 8
test_size = 4
# dynamic = AnnealedLangevinDynamic(sigma_min, sigma_max, n_steps, annealed_step, sn, device, eps=eps)
# sample = dynamic.sampling(test_size, z_dim, only_final=False)
sample = Euler_Maruyama_sampler(sn, marginal_prob_std_fn, diffusion_coeff_fn, dim=z_dim, batch_size=test_size, num_steps=500, device=device, only_final=False)
diffuse_data = vae.decode(sample).reshape(-1, test_size, 3, 32, 32)

step_size = sample.size(0)

# %%
diffuse_data.shape, sample.shape, step_size
# Out:
# (torch.Size([9, 4, 3, 32, 32]), torch.Size([9, 4, 128]), 9)

# %%
fig, axs = plt.subplots(1, step_size, figsize=(step_size * 6, 6), constrained_layout = True)
for i in range(step_size):
    diff_data = diffuse_data[i].view(-1, 3, 32, 32)
    axs[i].imshow(make_grid(diff_data, nrow=int(np.sqrt(test_size))).permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
    # plt.show()

# %%
from torchvision.utils import make_grid

sample_grid = make_grid(x.view(-1, 3, 32, 32), nrow=int(np.sqrt(x.shape[0])))

select_t = 0.3

plt.figure(figsize=(6,6))
plt.axis('off')
plt.imshow(sample_grid.permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
plt.show()

# %%
mu, log_var = vae.encode(x)
z = vae.reparameterize(mu, log_var)
z_ = forward_process(z, marginal_prob_std_fn, 100, device=device, end_t=select_t, only_final=True)

# %%
sample = Euler_Maruyama_sampler(sn, marginal_prob_std_fn, diffusion_coeff_fn, dim=z_dim, batch_size=z_.shape[0], num_steps=100, device=device, start_t=select_t, only_final=True, init_x=z_)

diffuse_data = vae.decode(sample)

from torchvision.utils import make_grid

sample_grid = make_grid(diffuse_data.view(-1, 3, 32, 32), nrow=int(np.sqrt(x.shape[0])))

plt.figure(figsize=(6,6))
plt.axis('off')
plt.imshow(sample_grid.permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
plt.show()

# %%
## ODE sampler

sampler = ode_sampler #@param ['Euler_Maruyama_sampler', 'pc_sampler', 'ode_sampler'] {'type': 'raw'}

## Generate samples using the specified sampler.
z_ode = sampler(sn,
            marginal_prob_std_fn,
            diffusion_coeff_fn,
            batch_size=128,
            device=device,
            z=z_,
            start_t=select_t)
samples = vae.decode(z_ode.float()).view(-1, 3, 32, 32)
## Sample visualization.
samples = samples.clamp(0.0, 1.0)
# %matplotlib inline
import matplotlib.pyplot as plt
sample_grid = make_grid(samples, nrow=int(np.sqrt(batch_size)))

plt.figure(figsize=(6,6))
plt.axis('off')
plt.imshow(sample_grid.permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
plt.show()
# Out:
# Number of function evaluations: 5186

# %% [markdown]
# ### The changes of one sample

# %%
recon_x, _, _, _ = vae(x[0:2])

# %%
fig, axs = plt.subplots(1, 2, figsize=(4 * 2, 2), constrained_layout = True)
axs[0].imshow(make_grid(x[0:2], nrow=2).permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
axs[1].imshow(make_grid(recon_x[0:2], nrow=2).permute(1, 2, 0).cpu(), vmin=0., vmax=1.)

# %%
mu, log_var = vae.encode(x[0:2])
z = vae.reparameterize(mu, log_var)

z_ = forward_process(z, marginal_prob_std_fn, num_steps=10, device=device, end_t=1., only_final=False)
recon_x_seq = vae.decode(z_).clamp(0.0, 1.0).reshape(-1, 2, 3, 32, 32)

# %%
fig, axs = plt.subplots(1, recon_x_seq.shape[0], figsize=(recon_x_seq.shape[0] * 6, 6), constrained_layout = True)
for i in range(recon_x_seq.shape[0]):
    diff_data = recon_x_seq[i]
    axs[i].imshow(make_grid(diff_data, nrow=2).permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
plt.title('Forward process in latent space and its reconstruction')
# Out:
# Text(0.5, 1.0, 'Forward process in latent space and its reconstruction')

# %%
sample = Euler_Maruyama_sampler(sn, marginal_prob_std_fn, diffusion_coeff_fn, dim=z_dim, batch_size=1, num_steps=500, device=device, save_times=10, start_t=1., only_final=False, init_x=z_[-1])
# sample = Euler_Maruyama_sampler(sn, marginal_prob_std_fn, diffusion_coeff_fn, dim=z_dim, batch_size=1, num_steps=500, device=device, save_times=10, start_t=1., only_final=False)
diffuse_data = vae.decode(sample).clamp(0.0, 1.0).reshape(-1, 2, 3, 32, 32)

# %%
step_size = diffuse_data.shape[0]
fig, axs = plt.subplots(1, step_size, figsize=(step_size * 6, 6), constrained_layout = True)
for i in range(step_size):
    diff_data = diffuse_data[i]
    axs[i].imshow(make_grid(diff_data, nrow=2).permute(1, 2, 0).cpu(), vmin=0., vmax=1.)
plt.title('Reverse process in latent space and its reconstruction')
# Out:
# Text(0.5, 1.0, 'Reverse process in latent space and its reconstruction')
